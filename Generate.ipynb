# %%
import torch
import numpy as np
import gymnasium as gym
import mujoco
from Diffusion import PoseDiffusion, QuadrupedMorphDiffusionDataset


def load_diffusion(
    weights_path="quadruped_morph_diffusion_weights.pt",
    traj_file="quadruped_morph_trajectories.npz",
    device=None ):

    if device is None:
        device = "cuda" if torch.cuda.is_available() else "cpu"
    print("Using device:", device)

    # Load checkpoint and config
    ckpt = torch.load(weights_path, map_location=device)
    cfg = ckpt["config"]

    past_len   = cfg["past_len"]
    future_len = cfg["future_len"]
    n_steps    = cfg["n_steps"]
    hidden     = cfg["hidden"]
    imitation_obs_indices = cfg.get("imitation_obs_indices", None)

    print("Loaded config from checkpoint:")
    print("  traj_file :", traj_file)
    print("  past_len  :", past_len)
    print("  future_len:", future_len)
    print("  n_steps   :", n_steps)
    print("  hidden    :", hidden)
    print("  imitation_obs_indices:", imitation_obs_indices)


    # Rebuild dataset to get obs_dim / cond_dim
    dataset = QuadrupedMorphDiffusionDataset(
        traj_path=traj_file,
        past_len=past_len,
        future_len=future_len,
        imitation_obs_indices=imitation_obs_indices,
        device=device
    )

    D_target = dataset.D_target   # obs_dim per time step
    D_cond   = dataset.D_cond     # past_len*obs_dim + morph_dim

    print("Reconstructed diffusion dims:")
    print("  D_target (obs_dim) =", D_target)
    print("  D_cond             =", D_cond)

    diff_model = PoseDiffusion(
        D_target=D_target,
        D_cond=D_cond,
        future_len=future_len,
        n_steps=n_steps,
        hidden=hidden,
    ).to(device)

    diff_model.load_state_dict(ckpt["state_dict"])
    diff_model.eval()

    print("Loaded diffusion model.")

    # Return metadata for sampling
    meta = {
        "past_len": past_len,
        "future_len": future_len,
        "obs_dim": D_target,
        "morph_dim": dataset.morph_dim,
        "D_target": D_target,
        "D_cond": D_cond,
        "imitation_obs_indices": imitation_obs_indices,
    }

    return diff_model, meta, device

def make_cond_from_past_and_morph(past_obs, morph_vec, ckpt, device):
    """
    past_obs: (past_len, obs_dim)
    morph_vec: (morph_dim,)
    """
    past_len = ckpt["past_len"]
    obs_dim  = ckpt["obs_dim"]

    past_obs = np.asarray(past_obs, dtype=np.float32)
    morph_vec = np.asarray(morph_vec, dtype=np.float32)

    assert past_obs.shape == (past_len, obs_dim), (
        f"past_obs shape {past_obs.shape} != ({past_len}, {obs_dim})"
    )

    past_flat = past_obs.reshape(-1)                # (past_len * obs_dim,)
    cond_np   = np.concatenate([past_flat, morph_vec], axis=0)

    cond = torch.tensor(cond_np, device=device, dtype=torch.float32).unsqueeze(0)
    # shape: (1, D_cond)
    return cond

def sample_future_obs(diff_model, cond, meta):
    future_len = meta["future_len"]
    obs_dim    = meta["obs_dim"]

    with torch.no_grad():
        x0_seq = diff_model.sample(cond)   # (1, future_len, obs_dim)

    future_obs = x0_seq[0].cpu().numpy()   # (future_len, obs_dim)
    return future_obs

def pred_to_qpos_from_diffusion(pred, env):
    pred = np.asarray(pred, dtype=np.float32)
    qpos = env.unwrapped.data.qpos.copy()

    nq = env.unwrapped.model.nq  # 15 for Ant
    max_joints = nq - 2          # number of slots after x,y

    L = min(pred.shape[0], max_joints)
    qpos[2:2+L] = pred[:L]

    return qpos

def obs_to_qpos_from_augmented(obs_aug, env, morph_dim=8):
    obs_aug = np.asarray(obs_aug, dtype=np.float32)

    nq = env.unwrapped.model.nq  # 15
    base_obs_dim = obs_aug.shape[0] - (morph_dim + 2)  # 97 - 10 = 87

    base_obs = obs_aug[:base_obs_dim]   # (87,)
    qpos = env.unwrapped.data.qpos.copy()   

    # Assume base_obs[0 : nq-2] == qpos[2:]
    qpos[2:] = base_obs[: (nq - 2)]  
    return qpos

# freeze frame simulated gait cycle
def make_diffusion_video(full_cycle, xml_path, save_dir="diff_video", fps=30):
    env = gym.make("Ant-v5", xml_file=xml_path, render_mode="rgb_array" )

    env = gym.wrappers.RecordVideo( env, video_folder=save_dir, 
                                    name_prefix="diffusion_gait",
                                    episode_trigger=lambda ep: True )

    obs, info = env.reset()
    model = env.unwrapped.model
    data = env.unwrapped.data
    T = full_cycle.shape[0]
    morph_dim=8
    frame_count = 0        

    for t in range(T):
        pred = full_cycle[t] 

        qpos = pred_to_qpos_from_diffusion(pred, env)
        data.qpos[:] = qpos
        mujoco.mj_forward(model, data)

        # Take astep just to trigger render & RecordVideo
        zero_action = np.zeros(env.action_space.shape, dtype=np.float32)
        obs, reward, done, truncated, info = env.step(zero_action)
        frame_count += 1 

    env.close()
    print(f"Frames rendered: {frame_count}")
    print(f"Video saved to {save_dir}")

# %%
### Diff Video ###

import Diffusion as diff
from Diffusion import DiffusionPoseTemplate



quad_morph = [
    0.141421, 0.282843,  # FR leg, FR ankle
    0.141421, 0.282843,  # FL leg, FL ankle
    0.141421, 0.282843,  # BL leg, BL ankle
    0.141421, 0.282843,  # BR leg, BR ankle
]

diff_model, meta, device = load_diffusion(
    weights_path="quadruped_morph_diffusion_weights.pt",
    traj_file="quadruped_morph_trajectories.npz",)


full_cycle = diff.sample_full_cycle_from_morph(
    diff_model,
    meta,
    quad_morph,
    cycle_steps=200,
    device="cuda",
)

print(full_cycle.shape)
print(full_cycle[0])


make_diffusion_video(full_cycle, "./quadruped.xml")
# Out:
# Using device: cuda
# Loaded config from checkpoint:
#   traj_file : quadruped_morph_trajectories.npz
#   past_len  : 10
#   future_len: 200
#   n_steps   : 100
#   hidden    : 256
#   imitation_obs_indices: [5, 6, 7, 8, 9, 10, 11, 12]
# [QuadrupedDataset] obs_dim=97, morph_dim=8
# [QuadrupedDataset] target_dim=8
# [QuadrupedDataset] total samples possible=71087
# Reconstructed diffusion dims:
#   D_target (obs_dim) = 8
#   D_cond             = 88
# Loaded diffusion model.
# (200, 8)
# [ 0.20517375  0.6367862   0.34641522 -1.3149067   0.33477023 -0.52083486
#  -0.31458032  0.7027811 ]
# C:\Users\Lep\miniconda3\Lib\site-packages\gymnasium\wrappers\rendering.py:293: UserWarning: WARN: Overwriting existing videos at C:\Users\Lep\OneDrive\Documents\Course Work\CS 525 Brain In Comp\Project\genloco\diff_video folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Frames rendered: 200
# Video saved to diff_video

# %%
#Train the Cycle with Imitation

import Reinforcement as re

#standard obs indices for Ant joints
imitation_obs_indices = list(range(5, 13))

# Morph of interest
quad_morph = [
    0.141421, 0.282843,
    0.141421, 0.282843,
    0.141421, 0.282843,
    0.141421, 0.282843,
]


pose_template = DiffusionPoseTemplate(full_cycle)

re.train_ppo_with_pose_template(
    run_name="ppo_with_imitation",
    pose_generator=pose_template,
    morph_vec=quad_morph,  
    xml_path="./quadruped.xml",
    timesteps=300_000,
    parallel_envs=1,
    initial_learning_rate=3e-4,
    imitation_w=4,
    imitation_obs_indices=imitation_obs_indices
)
# Out:
# Logging to ./logs_ppo_with_imitation
# Using cuda device
# C:\Users\Lep\miniconda3\Lib\site-packages\stable_baselines3\common\policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# C:\Users\Lep\miniconda3\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# 🚀 Training PPO with pose templates for ppo_with_imitation ...
# [env 0] ep_len=  20 | R_mean=-1.050 | fwd=-0.395 | vel=-1.284 | imitat=-0.816 | alive= 0.100 | energy_p= 0.027 | fail= 0.750 | var=unknown
# [env 0] ep_len=  40 | R_mean=-0.105 | fwd=-0.111 | vel=-0.430 | imitat=-0.683 | alive= 0.100 | energy_p= 0.028 | fail= 0.375 | var=unknown
# [env 0] ep_len=  41 | R_mean=-0.181 | fwd=-0.442 | vel=-1.386 | imitat=-0.890 | alive= 0.100 | energy_p= 0.031 | fail= 0.366 | var=unknown
# [env 0] ep_len=  32 | R_mean=-0.133 | fwd=-0.369 | vel=-1.298 | imitat=-0.762 | alive= 0.100 | energy_p= 0.028 | fail= 0.469 | var=unknown
# [env 0] ep_len=  20 | R_mean=-0.130 | fwd=-0.271 | vel=-0.797 | imitat=-1.098 | alive= 0.100 | energy_p= 0.029 | fail= 0.750 | var=unknown
# [env 0] ep_len=  36 | R_mean=-0.097 | fwd=-0.194 | vel=-0.657 | imitat=-0.805 | alive= 0.100 | energy_p= 0.028 | fail= 0.417 | var=unknown
# [env 0] ep_len=  25 | R_mean=-0.229 | fwd=-0.863 | vel=-2.886 | imitat=-0.698 | alive= 0.100 | energy_p= 0.032 | fail= 0.600 | var=unknown
# [env 0] ep_len=  82 | R_mean=-0.073 | fwd=-0.157 | vel=-0.563 | imitat=-0.886 | alive= 0.100 | energy_p= 0.030 | fail= 0.183 | var=unknown
# [env 0] ep_len=  36 | R_mean=-0.062 | fwd=-0.130 | vel=-0.410 | imitat=-0.700 | alive= 0.100 | energy_p= 0.029 | fail= 0.417 | var=unknown
# [env 0] ep_len=  35 | R_mean=-0.060 | fwd=-0.139 | vel=-0.432 | imitat=-0.558 | alive= 0.100 | energy_p= 0.031 | fail= 0.429 | var=unknown
# [env 0] ep_len=  34 | R_mean=-0.150 | fwd=-0.589 | vel=-1.869 | imitat=-1.006 | alive= 0.100 | energy_p= 0.029 | fail= 0.441 | var=unknown
# [env 0] ep_len=  34 | R_mean=-0.064 | fwd=-0.089 | vel=-0.446 | imitat=-0.722 | alive= 0.100 | energy_p= 0.030 | fail= 0.441 | var=unknown
# [env 0] ep_len=  46 | R_mean=-0.078 | fwd=-0.188 | vel=-0.626 | imitat=-0.875 | alive= 0.100 | energy_p= 0.030 | fail= 0.326 | var=unknown
# [env 0] ep_len=  26 | R_mean=-0.105 | fwd=-0.254 | vel=-0.869 | imitat=-1.004 | alive= 0.100 | energy_p= 0.028 | fail= 0.577 | var=unknown
# [env 0] ep_len=  51 | R_mean=-0.072 | fwd=-0.197 | vel=-0.717 | imitat=-0.587 | alive= 0.100 | energy_p= 0.030 | fail= 0.294 | var=unknown
# [env 0] ep_len=  37 | R_mean=-0.103 | fwd=-0.316 | vel=-1.041 | imitat=-0.768 | alive= 0.100 | energy_p= 0.031 | fail= 0.405 | var=unknown
# [env 0] ep_len=  24 | R_mean=-0.105 | fwd=-0.239 | vel=-0.819 | imitat=-0.895 | alive= 0.100 | energy_p= 0.028 | fail= 0.625 | var=unknown
# [env 0] ep_len=  34 | R_mean=-0.074 | fwd=-0.118 | vel=-0.417 | imitat=-0.792 | alive= 0.100 | energy_p= 0.029 | fail= 0.441 | var=unknown
# [env 0] ep_len=  24 | R_mean=-0
| var=unknown
# [env 0] ep_len=  26 | R_mean=-0.098 | fwd=-0.232 | vel=-0.796 | imitat=-0.614 | alive= 0.100 | energy_p= 0.029 | fail= 0.577 | var=unknown
# [env 0] ep_len=  20 | R_mean=-0.137 | fwd=-0.373 | vel=-1.121 | imitat=-0.848 | alive= 0.100 | energy_p= 0.032 | fail= 0.750 | var=unknown
# [env 0] ep_len=  27 | R_mean=-0.088 | fwd=-0.136 | vel=-0.403 | imitat=-0.890 | alive= 0.100 | energy_p= 0.029 | fail= 0.556 | var=unknown
# [env 0] ep_len=  30 | R_mean=-0.072 | fwd=-0.091 | vel=-0.416 | imitat=-0.622 | alive= 0.100 | energy_p= 0.029 | fail= 0.500 | var=unknown
# [env 0] ep_len=  20 | R_mean=-0.159 | fwd=-0.461 | vel=-1.415 | imitat=-0.962 | alive= 0.100 | energy_p= 0.032 | fail= 0.750 | var=unknown
# [env 0] ep_len=  36 | R_mean=-0.120 | fwd=-0.423 | vel=-1.327 | imitat=-0.544 | alive= 0.100 | energy_p= 0.030 | fail= 0.417 | var=unknown
# [env 0] ep_len=  43 | R_mean=-0.058 | fwd=-0.016 | vel=-0.120 | imitat=-0.819 | alive= 0.100 | energy_p= 0.030 | fail= 0.349 | var=unknown
# [env 0] ep_len=  20 | R_mean=-0.268 | fwd=-1.095 | vel=-3.325 | imitat=-0.878 | alive= 0.100 | energy_p= 0.028 | fail= 0.750 | var=unknown
# [env 0] ep_len=  22 | R_mean=-0.095 | fwd=-0.148 | vel=-0.520 | imitat=-0.781 | alive= 0.100 | energy_p= 0.028 | fail= 0.682 | var=unknown
# [env 0] ep_len=  27 | R_mean=-0.081 | fwd=-0.082 | vel=-0.305 | imitat=-0.888 | alive= 0.100 | energy_p= 0.030 | fail= 0.556 | var=unknown
# [env 0] ep_len=  27 | R_mean=-0.116 | fwd=-0.297 | vel=-0.980 | imitat=-0.781 | alive= 0.100 | energy_p= 0.028 | fail= 0.556 | var=unknown
# [env 0] ep_len=  35 | R_mean=-0.081 | fwd=-0.133 | vel=-0.432 | imitat=-0.811 | alive= 0.100 | energy_p= 0.028 | fail= 0.429 | var=unknown
# [env 0] ep_len=  23 | R_mean=-0.143 | fwd=-0.423 | vel=-1.364 | imitat=-0.779 | alive= 0.100 | energy_p= 0.029 | fail= 0.652 | var=unknown
# [env 0] ep_len=  24 | R_mean=-0.121 | fwd=-0.326 | vel=-1.059 | imitat=-0.705 | alive= 0.100 | energy_p= 0.030 | fail= 0.625 | var=unknown
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.7        |
# |    ep_rew_mean          | -3.23       |
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 2           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.003207341 |
# |    clip_fraction        | 0.00557     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.4       |
# |    explained_variance   | 0.00291     |
# |    learning_rate        | 0.000298    |
# |    loss                 | 0.699       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0078     |
# |    std                  | 1           |
# |    value_loss           | 1.84        |
# -----------------------------------------
# [env 0] ep_len=  20 | R_mean=-0.146 | fwd=-0.452 | vel=-1.380 | imitat=-0.690 | alive= 0.100 | energy_p= 0.027 | fail= 0.750 | var=unknown
# [env 0] ep_len=  25 | R_mean=-0.116 | fwd=-0.275 | vel=-0.885 | imitat=-0.827 | alive= 0.100 | energy_p= 0.030 | fail= 0.600 | var=unknown
# [env 0] ep_len= 112 | R_mean=-0.050 | fwd=-0.067 | vel=-0.264 | imitat=-0.641 | alive= 0.100 | energy_p= 0.029 | fail= 0.134 | var=unknown
# [env 0] ep_len=  38 | R_mean=-0.055 | fwd=-0.027 | vel=-0.117 | imitat=-0.684 | alive= 0.100 | energy_p= 0.032 | fail= 0.395 | var=unknown
# [env 0] ep_len=  22 | R_mean=-0.117 | fwd=-0.300 | vel=-0.902 | imitat=-0.720 | alive= 0.100 | energy_p= 0.029 | fail= 0.682 | var=unknown
# [env 0] ep_len=  54 | R_mean=-0.084 | fwd=-0.190 | vel=-0.630 | imitat=-0.768 | alive= 0.100 | energy_p= 0.028 | fail= 0.278 | var=unknown
# [env 0] ep_len=  61 | R_mean=-0.078 | fwd=-0.174 | vel=-0.627 | imitat=-0.693 | alive= 0.100 | energy_p= 0.030 | fail= 0.246 | var=unknown
# [env 0] ep_len=  25 | R_mean=-0
| var=unknown
# [env 0] ep_len=  33 | R_mean=-0.137 | fwd=-0.407 | vel=-1.389 | imitat=-0.846 | alive= 0.100 | energy_p= 0.029 | fail= 0.455 | var=unknown
# [env 0] ep_len=  40 | R_mean=-0.078 | fwd=-0.152 | vel=-0.570 | imitat=-0.669 | alive= 0.100 | energy_p= 0.029 | fail= 0.375 | var=unknown
# [env 0] ep_len=  79 | R_mean=-0.064 | fwd=-0.118 | vel=-0.497 | imitat=-0.630 | alive= 0.100 | energy_p= 0.030 | fail= 0.190 | var=unknown
# [env 0] ep_len=  24 | R_mean=-0.178 | fwd=-0.667 | vel=-2.086 | imitat=-0.625 | alive= 0.100 | energy_p= 0.028 | fail= 0.625 | var=unknown
# [env 0] ep_len=  60 | R_mean=-0.066 | fwd=-0.078 | vel=-0.357 | imitat=-0.798 | alive= 0.100 | energy_p= 0.029 | fail= 0.250 | var=unknown
# [env 0] ep_len=  24 | R_mean=-0.085 | fwd=-0.136 | vel=-0.489 | imitat=-0.642 | alive= 0.100 | energy_p= 0.029 | fail= 0.625 | var=unknown
# [env 0] ep_len=  84 | R_mean=-0.063 | fwd=-0.102 | vel=-0.379 | imitat=-0.739 | alive= 0.100 | energy_p= 0.027 | fail= 0.179 | var=unknown
# [env 0] ep_len=  68 | R_mean=-0.082 | fwd=-0.204 | vel=-0.697 | imitat=-0.700 | alive= 0.100 | energy_p= 0.027 | fail= 0.221 | var=unknown
# [env 0] ep_len=  26 | R_mean=-0.159 | fwd=-0.533 | vel=-1.748 | imitat=-0.718 | alive= 0.100 | energy_p= 0.029 | fail= 0.577 | var=unknown
# [env 0] ep_len=  56 | R_mean=-0.085 | fwd=-0.162 | vel=-0.618 | imitat=-0.864 | alive= 0.100 | energy_p= 0.029 | fail= 0.268 | var=unknown
# [env 0] ep_len=  26 | R_mean=-0.099 | fwd=-0.209 | vel=-0.722 | imitat=-0.729 | alive= 0.100 | energy_p= 0.026 | fail= 0.577 | var=unknown
# [env 0] ep_len=  52 | R_mean=-0.059 | fwd=-0.056 | vel=-0.317 | imitat=-0.668 | alive= 0.100 | energy_p= 0.029 | fail= 0.288 | var=unknown
# [env 0] ep_len=  92 | R_mean=-0.047 | fwd=-0.024 | vel=-0.176 | imitat=-0.684 | alive= 0.100 | energy_p= 0.027 | fail= 0.163 | var=unknown
# [env 0] ep_len=  80 | R_mean=-0.076 | fwd=-0.181 | vel=-0.623 | imitat=-0.693 | alive= 0.100 | energy_p= 0.029 | fail= 0.188 | var=unknown
# [env 0] ep_len=  44 | R_mean=-0.081 | fwd=-0.164 | vel=-0.622 | imitat=-0.692 | alive= 0.100 | energy_p= 0.029 | fail= 0.341 | var=unknown
# [env 0] ep_len=  20 | R_mean=-0.146 | fwd=-0.385 | vel=-1.179 | imitat=-0.930 | alive= 0.100 | energy_p= 0.029 | fail= 0.750 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 37.8         |
# |    ep_rew_mean          | -3.47        |
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 3            |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0071486235 |
# |    clip_fraction        | 0.0257       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11.4        |
# |    explained_variance   | 0.0208       |
# |    learning_rate        | 0.000296     |
# |    loss                 | 0.353        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0122      |
# |    std                  | 1.01         |
# |    value_loss           | 1.13         |
# ------------------------------------------
# [env 0] ep_len=  76 | R_mean=-0.085 | fwd=-0.220 | vel=-0.760 | imitat=-0.712 | alive= 0.100 | energy_p= 0.028 | fail= 0.197 | var=unknown
# [env 0] ep_len=  54 | R_mean=-0.063 | fwd=-0.061 | vel=-0.232 | imitat=-0.840 | alive= 0.100 | energy_p= 0.029 | fail= 0.278 | var=unknown
# [env 0] ep_len=  32 | R_mean=-0.071 | fwd=-0.111 | vel=-0.383 | imitat=-0.625 | alive= 0.100 | energy_p= 0.030 | fail= 0.469 | var=unknown
# [env 0] ep_len=  24 | R_mean=-0
| var=unknown
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.4        |
# |    ep_rew_mean          | -3.77       |
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 4           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007407803 |
# |    clip_fraction        | 0.0388      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.4       |
# |    explained_variance   | 0.0633      |
# |    learning_rate        | 0.000294    |
# |    loss                 | 0.124       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 1.01        |
# |    value_loss           | 0.785       |
# -----------------------------------------
# [env 0] ep_len=  49 | R_mean=-0.095 | fwd=-0.263 | vel=-0.929 | imitat=-0.623 | alive= 0.100 | energy_p= 0.028 | fail= 0.306 | var=unknown
# [env 0] ep_len=  78 | R_mean=-0.064 | fwd=-0.123 | vel=-0.442 | imitat=-0.661 | alive= 0.100 | energy_p= 0.030 | fail= 0.192 | var=unknown
# [env 0] ep_len=  53 | R_mean=-0.070 | fwd=-0.151 | vel=-0.536 | imitat=-0.568 | alive= 0.100 | energy_p= 0.031 | fail= 0.283 | var=unknown
# [env 0] ep_len=  87 | R_mean=-0.054 | fwd=-0.067 | vel=-0.272 | imitat=-0.691 | alive= 0.100 | energy_p= 0.029 | fail= 0.172 | var=unknown
# [env 0] ep_len= 112 | R_mean=-0.056 | fwd=-0.062 | vel=-0.302 | imitat=-0.739 | alive= 0.100 | energy_p= 0.028 | fail= 0.134 | var=unknown
# [env 0] ep_len=  38 | R_mean=-0.058 | fwd=-0.065 | vel=-0.266 | imitat=-0.573 | alive= 0.100 | energy_p= 0.030 | fail= 0.395 | var=unknown
# [env 0] ep_len=  43 | R_mean=-0.074 | fwd=-0.181 | vel=-0.616 | imitat=-0.508 | alive= 0.100 | energy_p= 0.029 | fail= 0.349 | var=unknown
# [env 0] ep_len=  39 | R_mean=-0.082 | fwd=-0.151 | vel=-0.567 | imitat=-0.716 | alive= 0.100 | energy_p= 0.029 | fail= 0.385 | var=unknown
# [env 0] ep_len=  28 | R_mean=-0.075 | fwd=-0.046 | vel=-0.178 | imitat=-0.908 | alive= 0.100 | energy_p= 0.030 | fail= 0.536 | var=unknown
# [env 0] ep_len=  24 | R_mean=-0.081 | fwd=-0.054 | vel=-0.207 | imitat=-0.923 | alive= 0.100 | energy_p= 0.028 | fail= 0.625 | var=unknown
# [env 0] ep_len=  50 | R_mean=-0.067 | fwd=-0.099 | vel=-0.384 | imitat=-0.694 | alive= 0.100 | energy_p= 0.029 | fail= 0.300 | var=unknown
# [env 0] ep_len= 131 | R_mean=-0.057 | fwd=-0.091 | vel=-0.349 | imitat=-0.707 | alive= 0.100 | energy_p= 0.029 | fail= 0.115 | var=unknown
# [env 0] ep_len=  23 | R_mean=-0.075 | fwd=-0.076 | vel=-0.252 | imitat=-0.692 | alive= 0.100 | energy_p= 0.029 | fail= 0.652 | var=unknown
# [env 0] ep_len=  23 | R_mean=-0.095 | fwd=-0.236 | vel=-0.826 | imitat=-0.402 | alive= 0.100 | energy_p= 0.029 | fail= 0.652 | var=unknown
# [env 0] ep_len=  35 | R_mean=-0.083 | fwd=-0.172 | vel=-0.571 | imitat=-0.683 | alive= 0.100 | energy_p= 0.028 | fail= 0.429 | var=unknown
# [env 0] ep_len=  37 | R_mean=-0.045 | fwd= 0.014 | vel=-0.111 | imitat=-0.521 | alive= 0.100 | energy_p= 0.028 | fail= 0.405 | var=unknown
# [env 0] ep_len=  37 | R_mean=-0.076 | fwd=-0.118 | vel=-0.442 | imitat=-0.730 | alive= 0.100 | energy_p= 0.030 | fail= 0.405 | var=unknown
# [env 0] ep_len=  43 | R_mean=-0.054 | fwd=-0.029 | vel=-0.205 | imitat=-0.602 | alive= 0.100 | energy_p= 0.030 | fail= 0.349 | var=unknown
# [env 0] ep_len=  20 | R_mean=-0.131 | fwd=-0.296 | vel=-0.936 | imitat=-0.923 | alive= 0.100 | energy_p= 0.027 | fail= 0.750 | var=unknown
# [env 0] ep_len=  20 | R_mean=-0.097 | fwd=-0.171 | vel=-0.532 | imitat=-0.694 | alive= 0.100 | energy_p= 0.029 | fail= 0.750 | var=unknown
# [env 0] ep_len=  42 | R_mean=-0.083 | fwd=-0.156 | vel=-0.552 | imitat=-0.775 | alive= 0.100 | energy_p= 0.029 | fail= 0.357 | var=unknown
# [env 0] ep_len=  23 | R_mean=-0.073 | fwd=-0.035 | vel=-0.168 | imitat=-0.772 | alive= 0.100 | energy_p= 0.026 | fail= 0.652 | var=unknown
# [env 0] ep_len=  28 | R_mean=-0.125 | fwd=-0.389 | vel=-1.322 | imitat=-0.536 | alive= 0.100 | energy_p= 0.029 | fail= 0.536 | var=unknown
# [env 0] ep_len=  62 | R_mean=-0.058 | fwd=-0.058 | vel=-0.263 | imitat=-0.727 | alive= 0.100 | energy_p= 0.029 | fail= 0.242 | var=unknown
# [env 0] ep_len=  56 | R_mean=-0.072 | fwd=-0.100 | vel=-0.389 | imitat=-0.851 | alive= 0.100 | energy_p= 0.028 | fail= 0.268 | var=unknown
# [env 0] ep_len=  22 | R_mean=-0.170 | fwd=-0.580 | vel=-1.869 | imitat=-0.635 | alive= 0.100 | energy_p= 0.032 | fail= 0.682 | var=unknown
#
# 🎥 Recording episode 250...
# C:\Users\Lep\miniconda3\Lib\site-packages\gymnasium\wrappers\rendering.py:293: UserWarning: WARN: Overwriting existing videos at C:\Users\Lep\OneDrive\Documents\Course Work\CS 525 Brain In Comp\Project\genloco\quad_videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Video recording complete.
# [env 0] ep_len=  38 | R_mean=-0.050 | fwd=-0.032 | vel=-0.201 | imitat=-0.486 | alive= 0.100 | energy_p= 0.026 | fail= 0.395 | var=unknown
# [env 0] ep_len=  25 | R_mean=-0.100 | fwd=-0.182 | vel=-0.634 | imitat=-0.806 | alive= 0.100 | energy_p= 0.028 | fail= 0.600 | var=unknown
# [env 0] ep_len=  60 | R_mean=-0.049 | fwd=-0.016 | vel=-0.130 | imitat=-0.698 | alive= 0.100 | energy_p= 0.028 | fail= 0.250 | var=unknown
# [env 0] ep_len=  44 | R_mean=-0.094 | fwd=-0.225 | vel=-0.768 | imitat=-0.744 | alive= 0.100 | energy_p= 0.028 | fail= 0.341 | var=unknown
# [env 0] ep_len=  63 | R_mean=-0.092 | fwd=-0.214 | vel=-0.715 | imitat=-0.853 | alive= 0.100 | energy_p= 0.029 | fail= 0.238 | var=unknown
# [env 0] ep_len=  64 | R_mean=-0.065 | fwd=-0.149 | vel=-0.508 | imitat=-0.540 | alive= 0.100 | energy_p= 0.029 | fail= 0.234 | var=unknown
# [env 0] ep_len=  59 | R_mean=-0.053 | fwd=-0.002 | vel=-0.201 | imitat=-0.727 | alive= 0.100 | energy_p= 0.031 | fail= 0.254 | var=unknown
# [env 0] ep_len=  35 | R_mean=-0.100 | fwd=-0.273 | vel=-0.915 | imitat=-0.602 | alive= 0.100 | energy_p= 0.028 | fail= 0.429 | var=unknown
# [env 0] ep_len=  73 | R_mean=-0.042 | fwd= 0.001 | vel=-0.072 | imitat=-0.641 | alive= 0.100 | energy_p= 0.029 | fail= 0.205 | var=unknown
# [env 0] ep_len=  43 | R_mean=-0.068 | fwd=-0.105 | vel=-0.413 | imitat=-0.633 | alive= 0.100 | energy_p= 0.029 | fail= 0.349 | var=unknown
# [env 0] ep_len=  92 | R_mean=-0.070 | fwd=-0.166 | vel=-0.566 | imitat=-0.648 | alive= 0.100 | energy_p= 0.029 | fail= 0.163 | var=unknown
# [env 0] ep_len= 121 | R_mean=-0.079 | fwd=-0.171 | vel=-0.609 | imitat=-0.833 | alive= 0.100 | energy_p= 0.028 | fail= 0.124 | var=unknown
# [env 0] ep_len=  22 | R_mean=-0.123 | fwd=-0.302 | vel=-0.972 | imitat=-0.791 | alive= 0.100 | energy_p= 0.026 | fail= 0.682 | var=unknown
# [env 0] ep_len=  22 | R_mean=-0.118 | fwd=-0.289 | vel=-0.963 | imitat=-0.703 | alive= 0.100 | energy_p= 0.029 | fail= 0.682 | var=unknown
# [env 0] ep_len=  28 | R_mean=-0.137 | fwd=-0.451 | vel=-1.532 | imitat=-0.569 | alive= 0.100 | energy_p= 0.030 | fail= 0.536 | var=unknown
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.7        |
# |    ep_rew_mean          | -3.68       |
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 5           |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008068427 |
# |    clip_fraction        | 0.0607      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.4       |
# |    explained_variance   | -0.00954    |
# |    learning_rate        | 0.000292    |
# |    loss                 | 0.00634     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 1.01        |
# |    value_loss           | 0.566       |
# -----------------------------------------
# [env 0] ep_len= 111 | R_mean=-0.045 | fwd= 0.009 | vel=-0.085 | imitat=-0.811 | alive= 0.100 | energy_p= 0.028 | fail= 0.135 | var=unknown
# [env 0] ep_len=  93 | R_mean=-0.057 | fwd=-0.087 | vel=-0.352 | imitat=-0.656 | alive= 0.100 | energy_p= 0.030 | fail= 0.161 | var=unknown
# [env 0] ep_len=  71 | R_mean=-0.080 | fwd=-0.187 | vel=-0.684 | imitat=-0.709 | alive= 0.100 | energy_p= 0.028 | fail= 0.211 | var=unknown
# [env 0] ep_len=  33 | R_mean=-0.076 | fwd=-0.115 | vel=-0.378 | imitat=-0.744 | alive= 0.100 | energy_p= 0.029 | fail= 0.455 | var=unknown
# [env 0] ep_len=  39 | R_mean=-0.064 | fwd=-0.072 | vel=-0.348 | imitat=-0.625 | alive= 0.100 | energy_p= 0.029 | fail= 0.385 | var=unknown
# [env 0] ep_len=  23 | R_mean=-0.070 | fwd=-0.083 | vel=-0.320 | imitat=-0.490 | alive= 0.100 | energy_p= 0.030 | fail= 0.652 | var=unknown
# [env 0] ep_len=  47 | R_mean=-0.046 | fwd= 0.006 | vel=-0.025 | imitat=-0.677 | alive= 0.100 | energy_p= 0.031 | fail= 0.319 | var=unknown
# [env 0] ep_len=  44 | R_mean=-0.072 | fwd=-0.131 | vel=-0.441 | imitat=-0.674 | alive= 0.100 | energy_p= 0.030 | fail= 0.341 | var=unknown
# [env 0] ep_len=  26 | R_mean=-0.118 | fwd=-0.256 | vel=-0.874 | imitat=-0.927 | alive= 0.100 | energy_p= 0.031 | fail= 0.577 | var=unknown
# [env 0] ep_len=  36 | R_mean=-0.058 | fwd=-0.052 | vel=-0.223 | imitat=-0.591 | alive= 0.100 | energy_p= 0.030 | fail= 0.417 | var=unknown
# [env 0] ep_len=  48 | R_mean=-0.074 | fwd=-0.125 | vel=-0.491 | imitat=-0.724 | alive= 0.100 | energy_p= 0.029 | fail= 0.312 | var=unknown
# [env 0] ep_len=  50 | R_mean=-0.068 | fwd=-0.125 | vel=-0.458 | imitat=-0.617 | alive= 0.100 | energy_p= 0.030 | fail= 0.300 | var=unknown
# [env 0] ep_len=  24 | R_mean=-0
| var=unknown
# [env 0] ep_len=  25 | R_mean=-0.109 | fwd=-0.047 | vel=-0.211 | imitat=-0.537 | alive= 0.100 | energy_p= 0.036 | fail= 0.600 | var=unknown
# [env 0] ep_len=  39 | R_mean=-0.070 | fwd= 0.056 | vel= 0.096 | imitat=-0.660 | alive= 0.100 | energy_p= 0.037 | fail= 0.385 | var=unknown
# [env 0] ep_len=  49 | R_mean=-0.065 | fwd= 0.044 | vel= 0.073 | imitat=-0.648 | alive= 0.100 | energy_p= 0.035 | fail= 0.306 | var=unknown
# [env 0] ep_len=  30 | R_mean=-0.069 | fwd= 0.077 | vel= 0.107 | imitat=-0.575 | alive= 0.100 | energy_p= 0.035 | fail= 0.500 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 35.7         |
# |    ep_rew_mean          | -2.51        |
# | time/                   |              |
# |    fps                  | 130          |
# |    iterations           | 146          |
# |    time_elapsed         | 2285         |
# |    total_timesteps      | 299008       |
# | train/                  |              |
# |    approx_kl            | 0.0006369912 |
# |    clip_fraction        | 0.00137      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.9        |
# |    explained_variance   | 0.256        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.0854      |
# |    n_updates            | 1450         |
# |    policy_gradient_loss | -0.00385     |
# |    std                  | 0.956        |
# |    value_loss           | 0.0655       |
# ------------------------------------------
# [env 0] ep_len=  35 | R_mean=-0.064 | fwd= 0.086 | vel= 0.165 | imitat=-0.638 | alive= 0.100 | energy_p= 0.033 | fail= 0.429 | var=unknown
# [env 0] ep_len=  34 | R_mean=-0.078 | fwd= 0.047 | vel= 0.093 | imitat=-0.693 | alive= 0.100 | energy_p= 0.036 | fail= 0.441 | var=unknown
#
# 🎥 Recording episode 7500...
# Video recording complete.
# [env 0] ep_len=  25 | R_mean=-0.126 | fwd=-0.107 | vel=-0.393 | imitat=-0.518 | alive= 0.100 | energy_p= 0.037 | fail= 0.600 | var=unknown
# [env 0] ep_len=  30 | R_mean=-0.067 | fwd= 0.085 | vel= 0.159 | imitat=-0.605 | alive= 0.100 | energy_p= 0.036 | fail= 0.500 | var=unknown
# [env 0] ep_len=  30 | R_mean=-0.064 | fwd= 0.118 | vel= 0.180 | imitat=-0.629 | alive= 0.100 | energy_p= 0.035 | fail= 0.500 | var=unknown
# [env 0] ep_len=  25 | R_mean=-0.106 | fwd=-0.039 | vel=-0.183 | imitat=-0.538 | alive= 0.100 | energy_p= 0.037 | fail= 0.600 | var=unknown
# [env 0] ep_len=  29 | R_mean=-0.070 | fwd= 0.081 | vel= 0.117 | imitat=-0.584 | alive= 0.100 | energy_p= 0.036 | fail= 0.517 | var=unknown
# [env 0] ep_len=  31 | R_mean=-0.079 | fwd= 0.040 | vel= 0.018 | imitat=-0.594 | alive= 0.100 | energy_p= 0.035 | fail= 0.484 | var=unknown
# [env 0] ep_len=  36 | R_mean=-0.068 | fwd= 0.069 | vel= 0.082 | imitat=-0.628 | alive= 0.100 | energy_p= 0.035 | fail= 0.417 | var=unknown
# [env 0] ep_len=  27 | R_mean=-0.091 | fwd=-0.003 | vel=-0.073 | imitat=-0.539 | alive= 0.100 | energy_p= 0.037 | fail= 0.556 | var=unknown
# [env 0] ep_len=  26 | R_mean=-0.086 | fwd= 0.049 | vel=-0.014 | imitat=-0.552 | alive= 0.100 | energy_p= 0.038 | fail= 0.577 | var=unknown
# [env 0] ep_len=  25 | R_mean=-0.107 | fwd=-0.035 | vel=-0.184 | imitat=-0.550 | alive= 0.100 | energy_p= 0.037 | fail= 0.600 | var=unknown
# [env 0] ep_len=  28 | R_mean=-0.067 | fwd= 0.083 | vel= 0.117 | imitat=-0.522 | alive= 0.100 | energy_p= 0.037 | fail= 0.536 | var=unknown
# [env 0] ep_len=  27 | R_mean=-0.066 | fwd= 0.083 | vel= 0.152 | imitat=-0.533 | alive= 0.100 | energy_p= 0.034 | fail= 0.556 | var=unknown
# [env 0] ep_len=  29 | R_mean=-0.079 | fwd= 0.035 | vel=-0.009 | imitat=-0.531 | alive= 0.100 | energy_p= 0.035 | fail= 0.517 | var=unknown
# [env 0] ep_len=  39 | R_mean=-0.065 | fwd= 0.065 | vel= 0.113 | imitat=-0.631 | alive= 0.100 | energy_p= 0.036 | fail= 0.385 | var=unknown
# [env 0] ep_len=  33 | R_mean=-0.064 | fwd= 0.089 | vel= 0.115 | imitat=-0.581 | alive= 0.100 | energy_p= 0.038 | fail= 0.455 | var=unknown
# [env 0] ep_len=  25 | R_mean=-0.104 | fwd=-0.022 | vel=-0.100 | imitat=-0.606 | alive= 0.100 | energy_p= 0.040 | fail= 0.600 | var=unknown
# [env 0] ep_len=  24 | R_mean=-0.100 | fwd= 0.000 | vel=-0.045 | imitat=-0.606 | alive= 0.100 | energy_p= 0.038 | fail= 0.625 | var=unknown
# [env 0] ep_len=  27 | R_mean=-0.066 | fwd= 0.093 | vel= 0.178 | imitat=-0.567 | alive= 0.100 | energy_p= 0.036 | fail= 0.556 | var=unknown
# [env 0] ep_len=  29 | R_mean=-0.093 | fwd=-0.017 | vel=-0.112 | imitat=-0.541 | alive= 0.100 | energy_p= 0.038 | fail= 0.517 | var=unknown
# [env 0] ep_len=  31 | R_mean=-0.077 | fwd= 0.051 | vel= 0.050 | imitat=-0.602 | alive= 0.100 | energy_p= 0.037 | fail= 0.484 | var=unknown
# [env 0] ep_len=  41 | R_mean=-0.071 | fwd= 0.056 | vel= 0.092 | imitat=-0.692 | alive= 0.100 | energy_p= 0.037 | fail= 0.366 | var=unknown
# [env 0] ep_len=  53 | R_mean=-0.060 | fwd= 0.064 | vel= 0.104 | imitat=-0.653 | alive= 0.100 | energy_p= 0.036 | fail= 0.283 | var=unknown
# [env 0] ep_len=  32 | R_mean=-0.091 | fwd=-0.002 | vel=-0.050 | imitat=-0.639 | alive= 0.100 | energy_p= 0.038 | fail= 0.469 | var=unknown
# [env 0] ep_len=  31 | R_mean=-0.076 | fwd= 0.060 | vel= 0.083 | imitat=-0.640 | alive= 0.100 | energy_p= 0.036 | fail= 0.484 | var=unknown
# [env 0] ep_len=  34 | R_mean=-0.063 | fwd= 0.098 | vel= 0.178 | imitat=-0.652 | alive= 0.100 | energy_p= 0.038 | fail= 0.441 | var=unknown
# [env 0] ep_len=  51 | R_mean=-0.065 | fwd= 0.058 | vel= 0.120 | imitat=-0.712 | alive= 0.100 | energy_p= 0.036 | fail= 0.294 | var=unknown
# [env 0] ep_len=  29 | R_mean=-0.071 | fwd= 0.073 | vel= 0.177 | imitat=-0.631 | alive= 0.100 | energy_p= 0.035 | fail= 0.517 | var=unknown
# [env 0] ep_len=  39 | R_mean=-0.078 | fwd= 0.028 | vel=-0.029 | imitat=-0.629 | alive= 0.100 | energy_p= 0.036 | fail= 0.385 | var=unknown
# [env 0] ep_len=  30 | R_mean=-0.070 | fwd= 0.068 | vel= 0.104 | imitat=-0.572 | alive= 0.100 | energy_p= 0.038 | fail= 0.500 | var=unknown
# [env 0] ep_len=  29 | R_mean=-0.072 | fwd= 0.064 | vel= 0.078 | imitat=-0.554 | alive= 0.100 | energy_p= 0.036 | fail= 0.517 | var=unknown
# [env 0] ep_len=  28 | R_mean=-0.076 | fwd= 0.054 | vel= 0.055 | imitat=-0.547 | alive= 0.100 | energy_p= 0.038 | fail= 0.536 | var=unknown
# [env 0] ep_len=  49 | R_mean=-0.061 | fwd= 0.071 | vel= 0.146 | imitat=-0.680 | alive= 0.100 | energy_p= 0.038 | fail= 0.306 | var=unknown
# [env 0] ep_len=  26 | R_mean=-0.082 | fwd= 0.039 | vel= 0.060 | imitat=-0.565 | alive= 0.100 | energy_p= 0.036 | fail= 0.577 | var=unknown
# [env 0] ep_len=  44 | R_mean=-0.061 | fwd= 0.076 | vel= 0.123 | imitat=-0.639 | alive= 0.100 | energy_p= 0.036 | fail= 0.341 | var=unknown
# [env 0] ep_len=  30 | R_mean=-0.084 | fwd= 0.019 | vel=-0.035 | imitat=-0.566 | alive= 0.100 | energy_p= 0.034 | fail= 0.500 | var=unknown
# [env 0] ep_len=  33 | R_mean=-0.060 | fwd= 0.109 | vel= 0.147 | imitat=-0.579 | alive= 0.100 | energy_p= 0.038 | fail= 0.455 | var=unknown
# [env 0] ep_len=  34 | R_mean=-0.071 | fwd= 0.072 | vel= 0.118 | imitat=-0.661 | alive= 0.100 | energy_p= 0.038 | fail= 0.441 | var=unknown
# [env 0] ep_len=  27 | R_mean=-0.120 | fwd=-0.096 | vel=-0.380 | imitat=-0.508 | alive= 0.100 | energy_p= 0.036 | fail= 0.556 | var=unknown
# [env 0] ep_len=  20 | R_mean=-0.211 | fwd=-0.329 | vel=-1.044 | imitat=-0.591 | alive= 0.100 | energy_p= 0.035 | fail= 0.750 | var=unknown
# [env 0] ep_len=  33 | R_mean=-0.070 | fwd= 0.066 | vel= 0.114 | imitat=-0.628 | alive= 0.100 | energy_p= 0.036 | fail= 0.455 | var=unknown
# [env 0] ep_len=  34 | R_mean=-0.064 | fwd= 0.079 | vel= 0.161 | imitat=-0.621 | alive= 0.100 | energy_p= 0.036 | fail= 0.441 | var=unknown
# [env 0] ep_len=  34 | R_mean=-0.066 | fwd= 0.067 | vel= 0.137 | imitat=-0.609 | alive= 0.100 | energy_p= 0.033 | fail= 0.441 | var=unknown
# [env 0] ep_len=  63 | R_mean=-0.061 | fwd= 0.047 | vel= 0.107 | imitat=-0.686 | alive= 0.100 | energy_p= 0.035 | fail= 0.238 | var=unknown
# [env 0] ep_len=  28 | R_mean=-0.071 | fwd= 0.057 | vel= 0.102 | imitat=-0.528 | alive= 0.100 | energy_p= 0.036 | fail= 0.536 | var=unknown
# [env 0] ep_len=  28 | R_mean=-0.077 | fwd= 0.043 | vel= 0.083 | imitat=-0.570 | alive= 0.100 | energy_p= 0.035 | fail= 0.536 | var=unknown
# [env 0] ep_len=  37 | R_mean=-0.077 | fwd= 0.048 | vel= 0.042 | imitat=-0.670 | alive= 0.100 | energy_p= 0.037 | fail= 0.405 | var=unknown
# [env 0] ep_len=  35 | R_mean=-0.080 | fwd= 0.060 | vel= 0.004 | imitat=-0.674 | alive= 0.100 | energy_p= 0.037 | fail= 0.429 | var=unknown
# [env 0] ep_len=  30 | R_mean=-0.079 | fwd= 0.034 | vel=-0.004 | imitat=-0.552 | alive= 0.100 | energy_p= 0.035 | fail= 0.500 | var=unknown
# [env 0] ep_len=  45 | R_mean=-0.076 | fwd= 0.033 | vel= 0.005 | imitat=-0.682 | alive= 0.100 | energy_p= 0.037 | fail= 0.333 | var=unknown
# [env 0] ep_len=  31 | R_mean=-0.052 | fwd= 0.122 | vel= 0.231 | imitat=-0.536 | alive= 0.100 | energy_p= 0.037 | fail= 0.484 | var=unknown
# [env 0] ep_len=  41 | R_mean=-0.078 | fwd= 0.016 | vel=-0.005 | imitat=-0.642 | alive= 0.100 | energy_p= 0.036 | fail= 0.366 | var=unknown
# [env 0] ep_len=  34 | R_mean=-0.072 | fwd= 0.046 | vel= 0.062 | imitat=-0.596 | alive= 0.100 | energy_p= 0.036 | fail= 0.441 | var=unknown
# [env 0] ep_len=  31 | R_mean=-0.067 | fwd= 0.084 | vel= 0.123 | imitat=-0.588 | alive= 0.100 | energy_p= 0.034 | fail= 0.484 | var=unknown
# [env 0] ep_len=  27 | R_mean=-0.066 | fwd= 0.091 | vel= 0.166 | imitat=-0.550 | alive= 0.100 | energy_p= 0.038 | fail= 0.556 | var=unknown
# [env 0] ep_len=  28 | R_mean=-0.069 | fwd= 0.077 | vel= 0.159 | imitat=-0.582 | alive= 0.100 | energy_p= 0.038 | fail= 0.536 | var=unknown
# [env 0] ep_len=  27 | R_mean=-0.089 | fwd= 0.015 | vel=-0.010 | imitat=-0.590 | alive= 0.100 | energy_p= 0.038 | fail= 0.556 | var=unknown
# [env 0] ep_len=  30 | R_mean=-0.070 | fwd= 0.083 | vel= 0.122 | imitat=-0.608 | alive= 0.100 | energy_p= 0.036 | fail= 0.500 | var=unknown
# [env 0] ep_len=  35 | R_mean=-0.065 | fwd= 0.081 | vel= 0.153 | imitat=-0.635 | alive= 0.100 | energy_p= 0.037 | fail= 0.429 | var=unknown
# [env 0] ep_len=  34 | R_mean=-0.095 | fwd= 0.000 | vel=-0.126 | imitat=-0.663 | alive= 0.100 | energy_p= 0.034 | fail= 0.441 | var=unknown
# [env 0] ep_len=  28 | R_mean=-0.060 | fwd= 0.100 | vel= 0.202 | imitat=-0.528 | alive= 0.100 | energy_p= 0.038 | fail= 0.536 | var=unknown
# [env 0] ep_len=  37 | R_mean=-0.064 | fwd= 0.090 | vel= 0.140 | imitat=-0.649 | alive= 0.100 | energy_p= 0.035 | fail= 0.405 | var=unknown
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 34.2          |
# |    ep_rew_mean          | -2.51         |
# | time/                   |               |
# |    fps                  | 131           |
# |    iterations           | 147           |
# |    time_elapsed         | 2295          |
# |    total_timesteps      | 301056        |
# | train/                  |               |
# |    approx_kl            | 0.00075926434 |
# |    clip_fraction        | 0.00171       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -10.9         |
# |    explained_variance   | 0.234         |
# |    learning_rate        | 3e-05         |
# |    loss                 | -0.0774       |
# |    n_updates            | 1460          |
# |    policy_gradient_loss | -0.00387      |
# |    std                  | 0.956         |
# |    value_loss           | 0.0601        |
# -------------------------------------------
# Training complete for ppo_with_imitation

# %%
import numpy as np

data = np.load("quadruped_morph_trajectories.npz")
obs = data["obs"]
morph = data["morph"]

print("obs_dim:", obs.shape[1])
print("morph_dim:", morph.shape[1])
# Out:
# obs_dim: 97
# morph_dim: 8

# %%
import Reinforcement as re
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv, VecNormalize, VecMonitor, VecVideoRecorder
from stable_baselines3.common.utils import LinearSchedule
from stable_baselines3.common.logger import configure

def evaluate_quadruped_ppo(
    ppo_path: str,
    xml_path: str,
    morph_vec,
    episodes: int = 10,
    max_steps_per_ep: int = 1000,
    deterministic: bool = True,
    pose_generator=None,
    imitation_w: float = 0.0,
    imitation_obs_indices=None ):

    print(f"Loading PPO model from {ppo_path} ...")
    model = PPO.load(ppo_path)

    # Base env: same quadruped XML as in training
    base_env = re.make_quadruped_env(seed=0, xml_path=xml_path)

    # Wrap in MorphPhaseEnvWrapper so we get delta_x and energy_penalty in info
    eval_env = re.MorphPhaseEnvWrapper(
        base_env=base_env,
        morph_vec=morph_vec,
        cycle_steps=200,
        settle_steps=5,
        pose_generator=pose_generator,
        imitation_w=imitation_w,
        imitation_obs_indices=imitation_obs_indices,
        xml_path=xml_path,
    )

    episode_forward = []
    episode_energy = []

    for ep in range(episodes):
        obs, info = eval_env.reset()
        done = False
        truncated = False
        ep_forward = 0.0
        ep_energy = 0.0

        for t in range(max_steps_per_ep):
            # stable-baselines3 expects obs shape (n_envs, obs_dim) for VecEnv,
            # but here we have a single Gym env, so squeeze/unsqueeze as needed:
            action, _ = model.predict(obs, deterministic=deterministic)
            obs, reward, done, truncated, info = eval_env.step(action)

            # info fields are populated by MorphPhaseEnvWrapper.step(...)
            ep_forward += float(info.get("delta_x", 0.0))
            ep_energy  += float(info.get("energy_penalty", 0.0))

            if done or truncated:
                break

        episode_forward.append(ep_forward)
        episode_energy.append(ep_energy)
        print(
            f"Episode {ep+1:2d} | "
            f"forward = {ep_forward:.3f} | "
            f"energy = {ep_energy:.3f} | "
            f"steps = {t+1}"
        )

    avg_forward = float(np.mean(episode_forward)) if episode_forward else 0.0
    avg_energy  = float(np.mean(episode_energy)) if episode_energy else 0.0

    print("\n=== PPO evaluation over "
          f"{episodes} episodes ({xml_path}) ===")
    print(f"Average forward motion: {avg_forward:.3f}")
    print(f"Average energy spent:   {avg_energy:.3f}")

    return avg_forward, avg_energy

# %%
quad_morph = [
    0.141421, 0.282843,
    0.141421, 0.282843,
    0.141421, 0.282843,
    0.141421, 0.282843,
]

var1_morph = [
    0.2, 0.25,  # FR leg, FR ankle
    0.2, 0.25,  # FL leg, FL ankle
    0.141421, 0.3,  # BL leg, BL ankle
    0.141421, 0.3,  # BR leg, BR ankle
]

explore_var = "quadrl_m0_ppo.zip"
mlp = "ppo_with_mlp.zip"
generative = "ppo_with_imitation_ppo.zip"

diff_model, meta, device = load_diffusion(
    weights_path="quadruped_morph_diffusion_weights.pt",
    traj_file="quadruped_morph_trajectories.npz",)

full_cycle = diff.sample_full_cycle_from_morph(
    diff_model,
    meta,
    quad_morph,
    cycle_steps=200,
    device="cuda",
)
pose_template = DiffusionPoseTemplate(full_cycle)


avg_fwd1, avg_energy1 = evaluate_quadruped_ppo(
    ppo_path=explore_var,   
    xml_path="./quadruped_var1.xml",
    morph_vec=quad_morph,
    episodes=10,
    max_steps_per_ep=1000,
    deterministic=True,
    pose_generator=None,   
    imitation_w=0.0,    
    imitation_obs_indices=None,
)

avg_fwd2, avg_energy2 = evaluate_quadruped_ppo(
    ppo_path=mlp,   
    xml_path="./quadruped.xml",
    morph_vec=quad_morph,
    episodes=10,
    max_steps_per_ep=1000,
    deterministic=True,
    pose_generator=None,   
    imitation_w=0.0,    
    imitation_obs_indices=None,
)

avg_fwd3, avg_energy3 = evaluate_quadruped_ppo(
    ppo_path=generative,   
    xml_path="./quadruped.xml",
    morph_vec=quad_morph,
    episodes=10,
    max_steps_per_ep=1000,
    deterministic=True,
    pose_generator=pose_template,    # DiffusionPoseTemplate active
    imitation_w=0.0,    
    imitation_obs_indices=None,
)


print(" Quadruped PPO Evaluation Summary")
print("")

header = f"{'Model':<20} | {'Avg Forward':>12} | {'Avg Energy':>12} | {'Notes'}"
print(header)
print("-"*72)

rows = [
    ("Exploration-PPO",  avg_fwd1, avg_energy1, "baseline (explore_var)"),
    ("MLP-PPO",          avg_fwd2, avg_energy2, "baseline (mlp)"),
    ("Generative-PPO",   avg_fwd3, avg_energy3, "diffusion-guided"),
]

for name, fwd, energy, note in rows:
    print(f"{name:<20} | {fwd:12.4f} | {energy:12.4f} | {note}")
# Out:
# Using device: cuda
# Loaded config from checkpoint:
#   traj_file : quadruped_morph_trajectories.npz
#   past_len  : 10
#   future_len: 200
#   n_steps   : 100
#   hidden    : 256
#   imitation_obs_indices: [5, 6, 7, 8, 9, 10, 11, 12]
# [QuadrupedDataset] obs_dim=97, morph_dim=8
# [QuadrupedDataset] target_dim=8
# [QuadrupedDataset] total samples possible=71087
# Reconstructed diffusion dims:
#   D_target (obs_dim) = 8
#   D_cond             = 88
# Loaded diffusion model.
# Loading PPO model from quadrl_m0_ppo.zip ...
# Episode  1 | forward = 8.794 | energy = 14.674 | steps = 309
# Episode  2 | forward = 12.804 | energy = 13.413 | steps = 283
# Episode  3 | forward = 9.673 | energy = 10.576 | steps = 225
# Episode  4 | forward = 4.295 | energy = 19.749 | steps = 419
# Episode  5 | forward = 11.587 | energy = 17.192 | steps = 370
# Episode  6 | forward = 22.788 | energy = 42.143 | steps = 891
# Episode  7 | forward = 8.500 | energy = 10.912 | steps = 230
# Episode  8 | forward = 17.632 | energy = 30.501 | steps = 642
# Episode  9 | forward = 19.867 | energy = 28.555 | steps = 604
# Episode 10 | forward = 8.055 | energy = 21.261 | steps = 450
#
# === PPO evaluation over 10 episodes (./quadruped_var1.xml) ===
# Average forward motion: 12.399
# Average energy spent:   20.898
# Loading PPO model from ppo_with_mlp.zip ...
# Episode  1 | forward = 17.699 | energy = 45.300 | steps = 995
# Episode  2 | forward = 3.593 | energy = 9.974 | steps = 213
# Episode  3 | forward = 19.240 | energy = 45.501 | steps = 995
# Episode  4 | forward = 17.325 | energy = 45.344 | steps = 995
# Episode  5 | forward = 16.208 | energy = 45.204 | steps = 995
# Episode  6 | forward = 15.397 | energy = 45.062 | steps = 993
# Episode  7 | forward = 21.906 | energy = 45.274 | steps = 995
# Episode  8 | forward = 18.952 | energy = 45.611 | steps = 995
# Episode  9 | forward = 19.267 | energy = 45.397 | steps = 995
# Episode 10 | forward = 20.005 | energy = 45.012 | steps = 995
#
# === PPO evaluation over 10 episodes (./quadruped.xml) ===
# Average forward motion: 16.959
# Average energy spent:   41.768
# Loading PPO model from ppo_with_imitation_ppo.zip ...
# Episode  1 | forward = 0.111 | energy = 0.661 | steps = 29
# Episode  2 | forward = 0.332 | energy = 0.821 | steps = 31
# Episode  3 | forward = 0.290 | energy = 0.715 | steps = 27
# Episode  4 | forward = 0.193 | energy = 0.678 | steps = 29
# Episode  5 | forward = 0.225 | energy = 0.840 | steps = 32
# Episode  6 | forward = 0.322 | energy = 0.739 | steps = 28
# Episode  7 | forward = 0.014 | energy = 0.719 | steps = 30
# Episode  8 | forward = 0.132 | energy = 0.797 | steps = 32
# Episode  9 | forward = 0.208 | energy = 0.785 | steps = 30
# Episode 10 | forward = 0.344 | energy = 0.819 | steps = 30
#
# === PPO evaluation over 10 episodes (./quadruped.xml) ===
# Average forward motion: 0.217
# Average energy spent:   0.758
#  Quadruped PPO Evaluation Summary
#
# Model                |  Avg Forward |   Avg Energy | Notes
# ------------------------------------------------------------------------
# Exploration-PPO      |      12.3995 |      20.8975 | baseline (explore_var)
# MLP-PPO              |      16.9594 |      41.7678 | baseline (mlp)
# Generative-PPO       |       0.2172 |       0.7575 | diffusion-guided
