# %%
import torch
import numpy as np
import gymnasium as gym
import mujoco
from Diffusion import PoseDiffusion, QuadrupedMorphDiffusionDataset


def load_diffusion(
    weights_path="quadruped_morph_diffusion_weights.pt",
    traj_file="quadruped_morph_trajectories.npz",
    device=None ):

    if device is None:
        device = "cuda" if torch.cuda.is_available() else "cpu"
    print("Using device:", device)

    # Load checkpoint and config
    ckpt = torch.load(weights_path, map_location=device)
    cfg = ckpt["config"]

    past_len   = cfg["past_len"]
    future_len = cfg["future_len"]
    n_steps    = cfg["n_steps"]
    hidden     = cfg["hidden"]
    imitation_obs_indices = cfg.get("imitation_obs_indices", None)

    print("Loaded config from checkpoint:")
    print("  traj_file :", traj_file)
    print("  past_len  :", past_len)
    print("  future_len:", future_len)
    print("  n_steps   :", n_steps)
    print("  hidden    :", hidden)
    print("  imitation_obs_indices:", imitation_obs_indices)


    # Rebuild dataset to get obs_dim / cond_dim
    dataset = QuadrupedMorphDiffusionDataset(
        traj_path=traj_file,
        past_len=past_len,
        future_len=future_len,
        imitation_obs_indices=imitation_obs_indices,
        device=device
    )

    D_target = dataset.D_target   # obs_dim per time step
    D_cond   = dataset.D_cond     # past_len*obs_dim + morph_dim

    print("Reconstructed diffusion dims:")
    print("  D_target (obs_dim) =", D_target)
    print("  D_cond             =", D_cond)

    diff_model = PoseDiffusion(
        D_target=D_target,
        D_cond=D_cond,
        future_len=future_len,
        n_steps=n_steps,
        hidden=hidden,
    ).to(device)

    diff_model.load_state_dict(ckpt["state_dict"])
    diff_model.eval()

    print("Loaded diffusion model.")

    # Return metadata for sampling
    meta = {
        "past_len": past_len,
        "future_len": future_len,
        "obs_dim": D_target,
        "morph_dim": dataset.morph_dim,
        "D_target": D_target,
        "D_cond": D_cond,
        "imitation_obs_indices": imitation_obs_indices,
    }

    return diff_model, meta, device

def make_cond_from_past_and_morph(past_obs, morph_vec, ckpt, device):
    """
    past_obs: (past_len, obs_dim)
    morph_vec: (morph_dim,)
    """
    past_len = ckpt["past_len"]
    obs_dim  = ckpt["obs_dim"]

    past_obs = np.asarray(past_obs, dtype=np.float32)
    morph_vec = np.asarray(morph_vec, dtype=np.float32)

    assert past_obs.shape == (past_len, obs_dim), (
        f"past_obs shape {past_obs.shape} != ({past_len}, {obs_dim})"
    )

    past_flat = past_obs.reshape(-1)                # (past_len * obs_dim,)
    cond_np   = np.concatenate([past_flat, morph_vec], axis=0)

    cond = torch.tensor(cond_np, device=device, dtype=torch.float32).unsqueeze(0)
    # shape: (1, D_cond)
    return cond

def sample_future_obs(diff_model, cond, meta):
    future_len = meta["future_len"]
    obs_dim    = meta["obs_dim"]

    with torch.no_grad():
        x0_seq = diff_model.sample(cond)   # (1, future_len, obs_dim)

    future_obs = x0_seq[0].cpu().numpy()   # (future_len, obs_dim)
    return future_obs

def pred_to_qpos_from_diffusion(pred, env):
    pred = np.asarray(pred, dtype=np.float32)
    qpos = env.unwrapped.data.qpos.copy()

    nq = env.unwrapped.model.nq  # 15 for Ant
    root_dim = 7 #root position not needed
    max_joints = nq - root_dim    # number of slots after x,y

    L = min(pred.shape[0], max_joints)
    qpos[root_dim:root_dim+L] = pred[:L]

    return qpos

def obs_to_qpos_from_augmented(obs_aug, env):
    obs_aug = np.asarray(obs_aug, dtype=np.float32)
    root_dim = 7 #root position not needed
    morph_dim = 8
    
    nq = env.unwrapped.model.nq  # 15
    joint_dim = nq - root_dim
    
    base_obs_dim = obs_aug.shape[0] - (morph_dim + 2)  # 97 - 10 = 87
    base_obs = obs_aug[:base_obs_dim]
    qpos = env.unwrapped.data.qpos.copy()   

    qpos[root_dim:] = base_obs[:joint_dim]
    return qpos

# freeze frame simulated gait cycle
def make_diffusion_video(full_cycle, xml_path, save_dir="diff_video", fps=30):
    env = gym.make("Ant-v5", xml_file=xml_path, render_mode="rgb_array" )

    env = gym.wrappers.RecordVideo( env, video_folder=save_dir, 
                                    name_prefix="diffusion_gait",
                                    episode_trigger=lambda ep: True )

    obs, info = env.reset()
    model = env.unwrapped.model
    data = env.unwrapped.data
    T = full_cycle.shape[0]
    morph_dim=8
    frame_count = 0        

    for t in range(T):
        pred = full_cycle[t] 

        qpos = pred_to_qpos_from_diffusion(pred, env)
        data.qpos[:] = qpos
        data.qvel[:] = 0.0
        mujoco.mj_forward(model, data)

        # Take astep just to trigger render & RecordVideo
        zero_action = np.zeros(env.action_space.shape, dtype=np.float32)
        obs, reward, done, truncated, info = env.step(zero_action)
        frame_count += 1 

    env.close()
    print(f"Frames rendered: {frame_count}")
    print(f"Video saved to {save_dir}")

# %%
### Diff Video ###

import Diffusion as diff
from Diffusion import DiffusionPoseTemplate



quad_morph = [
    0.141421, 0.282843,  # FR leg, FR ankle
    0.141421, 0.282843,  # FL leg, FL ankle
    0.141421, 0.282843,  # BL leg, BL ankle
    0.141421, 0.282843,  # BR leg, BR ankle
]

diff_model, meta, device = load_diffusion(
    weights_path="quadruped_morph_diffusion_weights.pt",
    traj_file="quadruped_morph_trajectories.npz",)


full_cycle = diff.sample_full_cycle_from_morph(
    diff_model,
    meta,
    quad_morph,
    cycle_steps=200,
    device="cuda",
)

print(full_cycle.shape)
print(full_cycle[0])


#make_diffusion_video(full_cycle, "./quadruped.xml")
# Out:
# Using device: cuda
# Loaded config from checkpoint:
#   traj_file : quadruped_morph_trajectories.npz
#   past_len  : 10
#   future_len: 200
#   n_steps   : 100
#   hidden    : 256
#   imitation_obs_indices: [5, 6, 7, 8, 9, 10, 11, 12]
# [QuadrupedDataset] obs_dim=97, morph_dim=8
# [QuadrupedDataset] target_dim=8
# [QuadrupedDataset] total samples possible=87182
# Reconstructed diffusion dims:
#   D_target (obs_dim) = 8
#   D_cond             = 88
# Loaded diffusion model.
# (200, 8)
# [ 0.20212217  0.03245725  0.38002956 -0.5836979   0.16443215 -0.4536708
#  -0.20561464  0.53085864]

# %%
#Train the Cycle with Imitation

import Reinforcement as re

#standard obs indices for Ant joints
imitation_obs_indices = list(range(5, 13))

# Morph of interest
quad_morph = [
    0.141421, 0.282843,
    0.141421, 0.282843,
    0.141421, 0.282843,
    0.141421, 0.282843,
]


pose_template = DiffusionPoseTemplate(full_cycle)

re.train_ppo_with_pose_template(
    run_name="ppo_with_imitation",
    pose_generator=pose_template,
    morph_vec=quad_morph,  
    xml_path="./quadruped.xml",
    timesteps=1_000_000,
    parallel_envs=4,
    initial_learning_rate=3e-4,
    imitation_w=1,
    imitation_obs_indices=imitation_obs_indices
)
# Out:
# Logging to ./logs_ppo_with_imitation
# Using cuda device
# C:\Users\Lep\miniconda3\Lib\site-packages\stable_baselines3\common\policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# C:\Users\Lep\miniconda3\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# 🚀 Training PPO with pose templates for ppo_with_imitation ...
# [env 1] ep_len=  51 | R_mean=-0.323 | fwd=-0.608 | vel=-1.982 | imitat=-0.008 | alive= 0.100 | energy_p= 0.005 | fail= 0.294 | phase_spd= 0.044 | var=unknown
# [env 3] ep_len=  57 | R_mean=-0.239 | fwd=-1.230 | vel=-4.005 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.263 | phase_spd= 0.042 | var=unknown
# [env 0] ep_len=  61 | R_mean= 0.012 | fwd=-0.200 | vel=-0.684 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.246 | phase_spd= 0.047 | var=unknown
# [env 2] ep_len=  90 | R_mean=-0.136 | fwd=-0.660 | vel=-2.176 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.167 | phase_spd= 0.050 | var=unknown
# [env 1] ep_len=  51 | R_mean=-0.075 | fwd=-0.886 | vel=-2.860 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.294 | phase_spd= 0.038 | var=unknown
# [env 3] ep_len=  54 | R_mean=-0.028 | fwd=-0.284 | vel=-0.938 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.278 | phase_spd= 0.048 | var=unknown
# [env 0] ep_len=  51 | R_mean=-0.025 | fwd=-0.245 | vel=-0.811 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.294 | phase_spd= 0.046 | var=unknown
# [env 1] ep_len=  57 | R_mean=-0.029 | fwd=-0.268 | vel=-0.906 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.263 | phase_spd= 0.043 | var=unknown
# [env 0] ep_len=  57 | R_mean=-0.022 | fwd=-0.181 | vel=-0.643 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.263 | phase_spd= 0.042 | var=unknown
# [env 2] ep_len= 111 | R_mean=-0.037 | fwd=-0.367 | vel=-1.236 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.135 | phase_spd= 0.042 | var=unknown
# [env 3] ep_len=  99 | R_mean=-0.042 | fwd=-0.396 | vel=-1.378 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.152 | phase_spd= 0.047 | var=unknown
# [env 0] ep_len=  53 | R_mean=-0.093 | fwd=-0.947 | vel=-3.043 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.283 | phase_spd= 0.041 | var=unknown
# [env 1] ep_len=  98 | R_mean=-0.036 | fwd=-0.354 | vel=-1.169 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.153 | phase_spd= 0.045 | var=unknown
# [env 2] ep_len=  59 | R_mean=-0.040 | fwd=-0.370 | vel=-1.240 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.254 | phase_spd= 0.045 | var=unknown
# [env 0] ep_len=  60 | R_mean=-0.044 | fwd=-0.400 | vel=-1.333 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.250 | phase_spd= 0.047 | var=unknown
# [env 3] ep_len=  95 | R_mean=-0.026 | fwd=-0.232 | vel=-0.790 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.158 | phase_spd= 0.044 | var=unknown
# [env 2] ep_len=  69 | R_mean=-0.050 | fwd=-0.452 | vel=-1.488 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.217 | phase_spd= 0.044 | var=unknown
# [env 0] ep_len=  51 | R_mean=-0.049 | fwd=-0.434 | vel=-1.399 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.294 | phase_spd= 0.040 | var=unknown
# [env 1] ep_len=  77 | R_mean=-0.030 | fwd=-0.261 | vel=-0.858 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.195 | phase_spd= 0.046 | var=unknown
# [env 3] ep_len=  60 | R_mean=-0.131 | fwd=-1.292 | vel=-4.207 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.250 | phase_spd= 0.038 | var=unknown
# [env 1] ep_len=  75 | R_mean=-0.063 | fwd=-0.613 | vel=-2.092 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.200 | phase_spd= 0.047 | var=unknown
# [env 2] ep_len= 119 | R_mean=-0.045 | fwd=-0.453 | vel=-1.523 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.126 | phase_spd= 0.043 | var=unknown
# [env 3] ep_len=  87 | R_mean=-0.072 | fwd=-0.735 | vel=-2.434 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.172 | phase_spd= 0.048 | var=unknown
# [env 1] ep_len=  80 | R_mean=-0.032 | fwd=-0.310 | vel=-1.028 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.188 | phase_spd= 0.045 | var=unknown
# [env 0] ep_len= 161 | R_mean=-0.024 | fwd=-0.229 | vel=-0.824 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.093 | phase_spd= 0.045 | var=unknown
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.3     |
# |    ep_rew_mean     | -4.58    |
# | time/              |          |
# |    fps             | 1007     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# [env 3] ep_len=  82 | R_mean=-0.021 | fwd=-0.189 | vel=-0.646 | imitat=-0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.183 | phase_spd= 0.048 | var=unknown
# [env 1] ep_len=  70 | R_mean=-0.040 | fwd=-0.382 | vel=-1.260 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.214 | phase_spd= 0.042 | var=unknown
# [env 2] ep_len= 187 | R_mean=-0.020 | fwd=-0.198 | vel=-0.667 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.080 | phase_spd= 0.047 | var=unknown
# [env 3] ep_len= 101 | R_mean=-0.048 | fwd=-0.474 | vel=-1.588 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.149 | phase_spd= 0.043 | var=unknown
# [env 3] ep_len=  78 | R_mean=-0.092 | fwd=-0.925 | vel=-3.048 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.192 | phase_spd= 0.045 | var=unknown
# [env 2] ep_len=  89 | R_mean=-0.028 | fwd=-0.257 | vel=-0.852 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.169 | phase_spd= 0.043 | var=unknown
# [env 3] ep_len=  51 | R_mean=-0.102 | fwd=-1.030 | vel=-3.371 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.294 | phase_spd= 0.055 | var=unknown
# [env 0] ep_len= 304 | R_mean=-0.024 | fwd=-0.234 | vel=-0.819 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.049 | phase_spd= 0.045 | var=unknown
# [env 1] ep_len= 244 | R_mean=-0.026 | fwd=-0.253 | vel=-0.904 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.061 | phase_spd= 0.047 | var=unknown
# [env 1] ep_len=  54 | R_mean=-0.062 | fwd=-0.601 | vel=-1.978 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.278 | phase_spd= 0.047 | var=unknown
# [env 0] ep_len=  64 | R_mean=-0.088 | fwd=-0.888 | vel=-2.930 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.234 | phase_spd= 0.047 | var=unknown
# [env 1] ep_len=  53 | R_mean=-0.056 | fwd=-0.541 | vel=-1.734 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.283 | phase_spd= 0.052 | var=unknown
# [env 0] ep_len=  80 | R_mean=-0.037 | fwd=-0.346 | vel=-1.178 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.188 | phase_spd= 0.047 | var=unknown
# [env 2] ep_len= 221 | R_mean=-0.038 | fwd=-0.388 | vel=-1.320 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.068 | phase_spd= 0.048 | var=unknown
# [env 3] ep_len= 212 | R_mean=-0.022 | fwd=-0.214 | vel=-0.750 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.071 | phase_spd= 0.046 | var=unknown
# [env 1] ep_len=  94 | R_mean=-0.035 | fwd=-0.338 | vel=-1.137 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.160 | phase_spd= 0.044 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94.3         |
# |    ep_rew_mean          | -4.58        |
# | time/                   |              |
# |    fps                  | 469          |
# |    iterations           | 2            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0020337286 |
# |    clip_fraction        | 0.00146      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.8        |
# |    explained_variance   | -0.00193     |
# |    learning_rate        | 0.000299     |
# |    loss                 | 0.292        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00514     |
# |    std                  | 1.01         |
# |    value_loss           | 1.3          |
# ------------------------------------------
# [env 0] ep_len=  95 | R_mean=-0.052 | fwd=-0.518 | vel=-1.743 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.158 | phase_spd= 0.045 | var=unknown
# [env 3] ep_len=  71 | R_mean=-0.035 | fwd=-0.322 | vel=-1.099 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.211 | phase_spd= 0.046 | var=unknown
# [env 1] ep_len=  51 | R_mean=-0.039 | fwd=-0.346 | vel=-1.151 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.294 | phase_spd= 0.049 | var=unknown
# [env 2] ep_len= 112 | R_mean=-0.043 | fwd=-0.429 | vel=-1.426 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.134 | phase_spd= 0.048 | var=unknown
# [env 3] ep_len=  51 | R_mean=-0.074 | fwd=-0.726 | vel=-2.381 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.294 | phase_spd= 0.048 | var=unknown
# [env 0] ep_len=  64 | R_mean=-0.040 | fwd=-0.374 | vel=-1.249 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.234 | phase_spd= 0.044 | var=unknown
# [env 1] ep_len=  58 | R_mean=-0.053 | fwd=-0.505 | vel=-1.691 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.259 | phase_spd= 0.046 | var=unknown
# [env 2] ep_len=  60 | R_mean=-0.034 | fwd=-0.303 | vel=-1.014 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.250 | phase_spd= 0.044 | var=unknown
# [env 1] ep_len=  56 | R_mean=-0.084 | fwd=-0.840 | vel=-2.752 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.268 | phase_spd= 0.044 | var=unknown
# [env 0] ep_len= 111 | R_mean=-0.028 | fwd=-0.264 | vel=-0.899 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.135 | phase_spd= 0.048 | var=unknown
# [env 2] ep_len= 109 | R_mean=-0.027 | fwd=-0.240 | vel=-0.857 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.138 | phase_spd= 0.051 | var=unknown
# [env 3] ep_len= 155 | R_mean=-0.033 | fwd=-0.318 | vel=-1.070 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.097 | phase_spd= 0.042 | var=unknown
# [env 3] ep_len=  51 | R_mean=-0.064 | fwd=-0.615 | vel=-1.990 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.294 | phase_spd= 0.044 | var=unknown
# [env 2] ep_len=  84 | R_mean=-0.014 | fwd=-0.098 | vel=-0.373 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.179 | phase_spd= 0.044 | var=unknown
# [env 1] ep_len= 168 | R_mean=-0.035 | fwd=-0.340 | vel=-1.151 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.089 | phase_spd= 0.050 | var=unknown
# [env 3] ep_len=  60 | R_mean=-0.066 | fwd=-0.623 | vel=-2.101 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.250 | phase_spd= 0.045 | var=unknown
# [env 0] ep_len= 162 | R_mean=-0.041 | fwd=-0.410 | vel=-1.358 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.093 | phase_spd= 0.045 | var=unknown
# [env 1] ep_len=  55 | R_mean=-0.045 | fwd=-0.407 | vel=-1.376 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.273 | phase_spd= 0.051 | var=unknown
# [env 2] ep_len= 103 | R_mean=-0.032 | fwd=-0.299 | vel=-1.020 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.146 | phase_spd= 0.050 | var=unknown
# [env 0] ep_len=  51 | R_mean=-0.036 | fwd=-0.314 | vel=-1.034 | imitat=-0.002 | alive= 0.100 | energy_p= 0.005 | fail= 0.294 | phase_spd= 0.045 | var=unknown
# [env 3] ep_len=  68 | R_mean=-0.023 | fwd=-0.180 | vel=-0.644 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.221 | phase_spd= 0.045 | var=unknown
# [env 1] ep_len=  67 | R_mean=-0.021 | fwd=-0.168 | vel=-0.577 | imitat=-0.001 | alive= 0.100 | energy_p= 0.004 | fail= 0.224 | phase_spd= 0.043 | var=unknown
# [env 0] ep_len=  51 | R_mean=-0.057 | fwd=-0.533 | vel=-1.754 | imitat=-0.002 | alive= 0.100 | energy_p= 0.005 | fail= 0.294 | phase_spd= 0.048 | var=unknown
# [env 3] ep_len=  66 | R_mean=-0.034 | fwd=-0.310 | vel=-1.020 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.227 | phase_spd= 0.043 | var=unknown
# [env 2] ep_len= 101 | R_mean=-0.052 | fwd=-0.499 | vel=-1.699 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.149 | phase_spd= 0.046 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90.1         |
# |    ep_rew_mean          | -4.11        |
# | time/                   |              |
# |    fps                  | 448          |
# |    iterations           | 3            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0038321565 |
# |    clip_fraction        | 0.00684      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.9        |
# |    explained_variance   | 0.0105       |
# |    learning_rate        | 0.000299     |
# |    loss                 | 0.0178       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00759     |
# |    std                  | 1.01         |
# |    value_loss           | 0.413        |
# ------------------------------------------
# [env 1] ep_len=  84 | R_mean=-0.024 | fwd=-0.209 | vel=-0.695 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.179 | phase_spd= 0.050 | var=unknown
# [env 3] ep_len= 116 | R_mean=-0.038 | fwd=-0.362 | vel=-1.207 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.129 | phase_spd= 0.050 | var=unknown
# [env 2] ep_len= 104 | R_mean=-0.055 | fwd=-0.534 | vel=-1.763 | imitat=-0.003 | alive= 0.100 | energy_p= 0.004 | fail= 0.144 | phase_spd= 0.044 | var=unknown
# [env 1] ep_len= 108 | R_mean=-0.031 | fwd=-0.280 | vel=-0.971 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.139 | phase_spd= 0.045 | var=unknown
# [env 2] ep_len=  51 | R_mean=-0.120 | fwd=-1.196 | vel=-3.870 | imitat=-0.003 | alive= 0.100 | energy_p= 0.004 | fail= 0.294 | phase_spd= 0.044 | var=unknown
# [env 3] ep_len=  62 | R_mean=-0.117 | fwd=-1.158 | vel=-3.864 | imitat=-0.003 | alive= 0.100 | energy_p= 0.004 | fail= 0.242 | phase_spd= 0.051 | var=unknown
# [env 2] ep_len=  61 | R_mean=-0.130 | fwd=-1.355 | vel=-4.426 | imitat=-0.003 | alive= 0.100 | energy_p= 0.005 | fail= 0.246 | phase_spd= 0.040 | var=unknown
# [env 3] ep_len=  68 | R_mean=-0.028 | fwd=-0.244 | vel=-0.856 | imitat=-0.002 | alive= 0.100 | energy_p= 0.005 | fail= 0.221 | phase_spd= 0.044 | var=unknown
# [env 0] ep_len= 328 | R_mean=-0.031 | fwd=-0.312 | vel=-1.068 | imitat=-0.003 | alive= 0.100 | energy_p= 0.004 | fail= 0.046 | phase_spd= 0.044 | var=unknown
# [env 1] ep_len= 234 | R_mean=-0.019 | fwd=-0.187 | vel=-0.662 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.064 | phase_spd= 0.045 | var=unknown
# [env 2] ep_len= 163 | R_mean=-0.026 | fwd=-0.249 | vel=-0.884 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.092 | phase_spd= 0.043 | var=unknown
# [env 3] ep_len= 188 | R_mean=-0.022 | fwd=-0.213 | vel=-0.742 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.080 | phase_spd= 0.045 | var=unknown
# [env 0] ep_len= 157 | R_mean=-0.020 | fwd=-0.188 | vel=-0.660 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.096 | phase_spd= 0.046 | var=unknown
# [env 1] ep_len= 113 | R_mean=-0.035 | fwd=-0.334 | vel=-1.156 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.133 | phase_spd= 0.046 | var=unknown
# [env 2] ep_len= 115 | R_mean=-0.036 | fwd=-0.352 | vel=-1.177 | imitat=-0.003 | alive= 0.100 | energy_p= 0.005 | fail= 0.130 | phase_spd= 0.044 | var=unknown
# [env 3] ep_len= 112 | R_mean=-0.037 | fwd=-0.356 | vel=-1.218 | imitat=-0.002 | alive= 0.100 | energy_p= 0.004 | fail= 0.134 | phase_spd= 0.045 | var=unknown
# [sched] imitation_w=0.015, energy_w=0.00106
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 97.7       |
# |    ep_rew_mean          | -4.25      |
# | time/                   |            |
# |    fps                  | 474        |
# |    iterations           | 4          |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00678894 |
# |    clip_fraction        | 0.0272     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.9      |
# |    explained_variance   | 0.0275     |
# |    learning_rate        | 0.000298   |
# |    loss                 | -0.0363    |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0136    |
# |    std                  | 1.01       |
# |    value_loss           | 0.263      |
# ----------------------------------------
# [env 0] ep_len= 112 | R_mean=-0.040 | fwd=-0.392 | vel=-1.313 | imitat=-0.003 | alive= 0.100 | energy_p= 0.004 | fail= 0.134 | phase_spd= 0.046 | var=unknown
# [env 1] ep_len=  77 | R_mean=-0.060 | fwd=-0.586 | vel=-1.983 | imitat=-0.003 | alive= 0.100 | energy_p= 0.004 | fail= 0.195 | phase_spd= 0.041 | var=unknown
# [env 2] ep_len=  67 | R_mean=-0.042 | fwd=-0.383 | vel=-1.319 | imitat=-0.003 | alive= 0.100 | energy_p= 0.004 | fail= 0.224 | phase_spd= 0.042 | var=unknown
# [env 2] ep_len=  68 | R_mean=-0.023 | fwd=-0.187 | vel=-0.636 | imitat=-0.003 | alive= 0.100 | energy_p= 0.004 | fail= 0.221 | phase_spd= 0.043 | var=unknown
# [env 0] ep_len=  71 | R_mean=-0.065 | fwd=-0.653 | vel=-2.153 | imitat=-0.003 | alive= 0.100 | energy_p= 0.005 | fail= 0.211 | phase_spd= 0.043 | var=unknown
# [env 3] ep_len= 157 | R_mean=-0.025 | fwd=-0.238 | vel=-0.821 | imitat=-0.003 | alive= 0.100 | energy_p= 0.004 | fail= 0.096 | phase_spd= 0.046 | var=unknown
# [env 0] ep_len=  88 | R_mean=-0.038 | fwd=-0.365 | vel=-1.221 | imitat=-0.003 | alive= 0.100 | energy_p= 0.004 | fail= 0.170 | phase_spd= 0.044 | var=unknown
# [env 2] ep_len= 128 | R_mean=-0.035 | fwd=-0.331 | vel=-1.143 | imitat=-0.003 | alive= 0.100 | energy_p= 0.004 | fail= 0.117 | phase_spd= 0.043 | var=unknown
# [env 3] ep_len=  75 | R_mean=-0.030 | fwd=-0.271 | vel=-0.891 | imitat=-0.003 | alive= 0.100 | energy_p= 0.005 | fail= 0.200 | phase_spd= 0.045 | var=unknown
# [env 3] ep_len=  54 | R_mean=-0.044 | fwd=-0.405 | vel=-1.299 | imitat=-0.003 | alive= 0.100 | energy_p= 0.004 | fail= 0.278 | phase_spd= 0.046 | var=unknown
# [env 1] ep_len= 321 | R_mean=-0.028 | fwd=-0.278 | vel=-0.964 | imitat=-0.003 | alive= 0.100 | energy_p= 0.005 | fail= 0.047 | phase_spd= 0.043 | var=unknown
# [env 2] ep_len= 125 | R_mean=-0.031 | fwd=-0.295 | vel=-1.003 | imitat=-0.003 | alive= 0.100 | energy_p= 0.005 | fail= 0.120 | phase_spd= 0.045 | var=unknown
# [env 0] ep_len= 174 | R_mean=-0.023 | fwd=-0.216 | vel=-0.759 | imitat=-0.004 | alive= 0.100 | energy_p= 0.004 | fail= 0.086 | phase_spd= 0.041 | var=unknown
# [env 3] ep_len= 124 | R_mean=-0.028 | fwd=-0.257 | vel=-0.897 | imitat=-0.004 | alive= 0.100 | energy_p= 0.004 | fail= 0.121 | phase_spd= 0.044 | var=unknown
# [env 1] ep_len=  86 | R_mean=-0.040 | fwd=-0.377 | vel=-1.278 | imitat=-0.003 | alive= 0.100 | energy_p= 0.004 | fail= 0.174 | phase_spd= 0.049 | var=unknown
# [env 2] ep_len=  97 | R_mean=-0.027 | fwd=-0.237 | vel=-0.864 | imitat=-0.003 | alive= 0.100 | energy_p= 0.005 | fail= 0.155 | phase_spd= 0.045 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -4.17        |
# | time/                   |              |
# |    fps                  | 445          |
# |    iterations           | 5            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0059513915 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.9        |
# |    explained_variance   | 0.0166       |
# |    learning_rate        | 0.000298     |
# |    loss                 | -0.0124      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0113      |
# |    std                  | 1.01         |
# |    value_loss           | 0.348        |
# ------------------------------------------
# [env 2] ep_len=  93 | R_mean=-0.017 | fwd=-0.136 | vel=-0.462 | imitat=-0.004 | alive= 0.100 | energy_p= 0.005 | fail= 0.161 | phase_spd= 0.039 | var=unknown
# [env 0] ep_len= 194 | R_mean=-0.022 | fwd=-0.198 | vel=-0.723 | imitat=-0.003 | alive= 0.100 | energy_p= 0.005 | fail= 0.077 | phase_spd= 0.046 | var=unknown
# [env 1] ep_len= 147 | R_mean=-0.019 | fwd=-0.167 | vel=-0.566 | imitat=-0.004 | alive= 0.100 | energy_p= 0.004 | fail= 0.102 | phase_spd= 0.048 | var=unknown
# [env 2] ep_len=  63 | R_mean=-0.053 | fwd=-0.497 | vel=-1.636 | imitat=-0.004 | alive= 0.100 | energy_p= 0.005 | fail= 0.238 | phase_spd= 0.045 | var=unknown
# [env 3] ep_len= 203 | R_mean=-0.019 | fwd=-0.166 | vel=-0.613 | imitat=-0.003 | alive= 0.100 | energy_p= 0.005 | fail= 0.074 | phase_spd= 0.044 | var=unknown
# [env 1] ep_len=  51 | R_mean=-0.067 | fwd=-0.624 | vel=-2.063 | imitat=-0.004 | alive= 0.100 | energy_p= 0.005 | fail= 0.294 | phase_spd= 0.049 | var=unknown
# [env 2] ep_len=  74 | R_mean=-0.039 | fwd=-0.354 | vel=-1.182 | imitat=-0.004 | alive= 0.100 | energy_p= 0.005 | fail= 0.203 | phase_spd= 0.050 | var=unknown
# [env 0] ep_len= 166 | R_mean=-0.022 | fwd=-0.194 | vel=-0.676 | imitat=-0.004 | alive= 0.100 | energy_p= 0.004 | fail= 0.090 | phase_spd= 0.043 | var=unknown
# [env 3] ep_len= 137 | R_mean=-0.019 | fwd=-0.160 | vel=-0.596 | imitat=-0.003 | alive= 0.100 | energy_p= 0.005 | fail= 0.109 | phase_spd= 0.046 | var=unknown
# [env 1] ep_len= 125 | R_mean=-0.037 | fwd=-0.343 | vel=-1.168 | imitat=-0.004 | alive= 0.100 | energy_p= 0.005 | fail= 0.120 | phase_spd= 0.048 | var=unknown
# [env 0] ep_len=  66 | R_mean=-0.047 | fwd=-0.433 | vel=-1.431 | imitat=-0.004 | alive= 0.100 | energy_p= 0.005 | fail= 0.227 | phase_spd= 0.047 | var=unknown
# [env 2] ep_len= 120 | R_mean=-0.022 | fwd=-0.187 | vel=-0.642 | imitat=-0.004 | alive= 0.100 | energy_p= 0.005 | fail= 0.125 | phase_spd= 0.045 | var=unknown
# [env 3] ep_len=  77 | R_mean=-0.024 | fwd=-0.200 | vel=-0.675 | imitat=-0.004 | alive= 0.100 | energy_p= 0.005 | fail= 0.195 | phase_spd= 0.046 | var=unknown
# [env 1] ep_len= 126 | R_mean=-0.016 | fwd=-0.124 | vel=-0.459 | imitat=-0.004 | alive= 0.100 | energy_p= 0.005 | fail= 0.119 | phase_spd= 0.043 | var=unknown
# [env 3] ep_len= 102 | R_mean=-0.051 | fwd=-0.487 | vel=-1.608 | imitat=-0.004 | alive= 0.100 | energy_p= 0.005 | fail= 0.147 | phase_spd= 0.044 | var=unknown
# [env 1] ep_len=  57 | R_mean=-0.232 | fwd=-2.350 | vel=-7.667 | imitat=-0.005 | alive= 0.100 | energy_p= 0.005 | fail= 0.263 | phase_spd= 0.046 | var=unknown
# [env 0] ep_len= 184 | R_mean=-0.024 | fwd=-0.221 | vel=-0.764 | imitat=-0.004 | alive= 0.100 | energy_p= 0.005 | fail= 0.082 | phase_spd= 0.046 | var=unknown
# [env 2] ep_len= 192 | R_mean=-0.022 | fwd=-0.212 | vel=-0.720 | imitat=-0.005 | alive= 0.100 | energy_p= 0.005 | fail= 0.078 | phase_spd= 0.046 | var=unknown
# [env 0] ep_len=  55 | R_mean=-0.031 | fwd=-0.265 | vel=-0.886 | imitat=-0.003 | alive= 0.100 | energy_p= 0.005 | fail= 0.273 | phase_spd= 0.047 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 109          |
# |    ep_rew_mean          | -4.01        |
# | time/                   |              |
# |    fps                  | 432          |
# |    iterations           | 6            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0065429197 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.9        |
# |    explained_variance   | -0.12        |
# |    learning_rate        | 0.000297     |
# |    loss                 | -0.0887      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0148      |
# |    std                  | 1.02         |
# |    value_loss           | 0.157        |
# ------------------------------------------
# [env 3] ep_len= 133 | R_mean=-0.018 | fwd=-0.146 | vel=-0.565 | imitat=-0.004 | alive= 0.100 | energy_p= 0.005 | fail= 0.113 | phase_spd= 0.041 | var=unknown
# [env 0] ep_len=  65 | R_mean=-0.019 | fwd=-0.143 | vel=-0.471 | imitat=-0.005 | alive= 0.100 | energy_p= 0.005 | fail= 0.231 | phase_spd= 0.047 | var=unknown
# [env 2] ep_len= 117 | R_mean=-0.025 | fwd=-0.233 | vel=-0.795 | imitat=-0.004 | alive= 0.100 | energy_p= 0.005 | fail= 0.128 | phase_spd= 0.046 | var=unknown
# [env 1] ep_len= 174 | R_mean=-0.025 | fwd=-0.233 | vel=-0.823 | imitat=-0.004 | alive= 0.100 | energy_p= 0.005 | fail= 0.086 | phase_spd= 0.046 | var=unknown
# [env 0] ep_len= 160 | R_mean=-0.018 | fwd=-0.161 | vel=-0.578 | imitat=-0.004 | alive= 0.100 | energy_p= 0.005 | fail= 0.094 | phase_spd= 0.047 | var=unknown
# [env 3] ep_len= 211 | R_mean=-0.029 | fwd=-0.275 | vel=-0.940 | imitat=-0.005 | alive= 0.100 | energy_p= 0.005 | fail= 0.071 | phase_spd= 0.051 | var=unknown
# [env 1] ep_len= 180 | R_mean=-0.011 | fwd=-0.085 | vel=-0.329 | imitat=-0.005 | alive= 0.100 | energy_p= 0.005 | fail= 0.083 | phase_spd= 0.047 | var=unknown
# [env 3] ep_len=  69 | R_mean=-0.062 | fwd=-0.592 | vel=-1.973 | imitat=-0.005 | alive= 0.100 | energy_p= 0.005 | fail= 0.217 | phase_spd= 0.045 | var=unknown
# [env 1] ep_len=  83 | R_mean=-0.049 | fwd=-0.462 | vel=-1.551 | imitat=-0.005 | alive= 0.100 | energy_p= 0.005 | fail= 0.181 | phase_spd= 0.040 | var=unknown
# [env 0] ep_len= 148 | R_mean=-0.033 | fwd=-0.309 | vel=-1.047 | imitat=-0.005 | alive= 0.100 | energy_p= 0.005 | fail= 0.101 | phase_spd= 0.041 | var=unknown
# [env 0] ep_len=  73 | R_mean=-0.017 | fwd=-0.123 | vel=-0.447 | imitat=-0.004 | alive= 0.100 | energy_p= 0.005 | fail= 0.205 | phase_spd= 0.044 | var=unknown
# [env 1] ep_len= 125 | R_mean=-0.019 | fwd=-0.162 | vel=-0.569 | imitat=-0.005 | alive= 0.100 | energy_p= 0.005 | fail= 0.120 | phase_spd= 0.046 | var=unknown
# [env 0] ep_len=  57 | R_mean=-0.025 | fwd=-0.192 | vel=-0.659 | imitat=-0.004 | alive= 0.100 | energy_p= 0.005 | fail= 0.263 | phase_spd= 0.047 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 113          |
# |    ep_rew_mean          | -3.86        |
# | time/                   |              |
# |    fps                  | 449          |
# |    iterations           | 7            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0052505895 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.9        |
# |    explained_variance   | 0.0156       |
# |    learning_rate        | 0.000296     |
# |    loss                 | 0.144        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0129      |
# |    std                  | 1.02         |
# |    value_loss           | 0.345        |
# ------------------------------------------
# [env 2] ep_len= 453 | R_mean=-0.022 | fwd=-0.212 | vel=-0.744 | imitat=-0.004 | alive= 0.100 | energy_p= 0.005 | fail= 0.033 | phase_spd= 0.046 | var=unknown
# [env 1] ep_len= 102 | R_mean=-0.024 | fwd=-0.198 | vel=-0.704 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.147 | phase_spd= 0.046 | var=unknown
# [env 0] ep_len= 101 | R_mean=-0.035 | fwd=-0.315 | vel=-1.092 | imitat=-0.005 | alive= 0.100 | energy_p= 0.005 | fail= 0.149 | phase_spd= 0.048 | var=unknown
# [env 3] ep_len= 304 | R_mean=-0.014 | fwd=-0.126 | vel=-0.446 | imitat=-0.005 | alive= 0.100 | energy_p= 0.005 | fail= 0.049 | phase_spd= 0.047 | var=unknown
# [env 2] ep_len= 130 | R_mean=-0.030 | fwd=-0.270 | vel=-0.931 | imitat=-0.005 | alive= 0.100 | energy_p= 0.005 | fail= 0.115 | phase_spd= 0.043 | var=unknown
# [env 3] ep_len=  99 | R_mean=-0.034 | fwd=-0.304 | vel=-1.010 | imitat=-0.007 | alive= 0.100 | energy_p= 0.005 | fail= 0.152 | phase_spd= 0.047 | var=unknown
# [env 2] ep_len=  64 | R_mean=-0.069 | fwd=-0.634 | vel=-2.162 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.234 | phase_spd= 0.047 | var=unknown
# [env 0] ep_len= 128 | R_mean=-0.062 | fwd=-0.604 | vel=-1.984 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.117 | phase_spd= 0.046 | var=unknown
# [env 0] ep_len=  81 | R_mean=-0.061 | fwd=-0.578 | vel=-1.925 | imitat=-0.005 | alive= 0.100 | energy_p= 0.005 | fail= 0.185 | phase_spd= 0.049 | var=unknown
# [env 2] ep_len= 131 | R_mean=-0.033 | fwd=-0.307 | vel=-1.026 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.115 | phase_spd= 0.049 | var=unknown
# [env 3] ep_len= 157 | R_mean=-0.028 | fwd=-0.250 | vel=-0.864 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.096 | phase_spd= 0.045 | var=unknown
# [env 1] ep_len= 296 | R_mean=-0.019 | fwd=-0.168 | vel=-0.599 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.051 | phase_spd= 0.048 | var=unknown
# [env 0] ep_len= 142 | R_mean=-0.025 | fwd=-0.227 | vel=-0.779 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.106 | phase_spd= 0.049 | var=unknown
# [env 1] ep_len=  92 | R_mean=-0.017 | fwd=-0.117 | vel=-0.455 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.163 | phase_spd= 0.047 | var=unknown
# [env 2] ep_len= 134 | R_mean=-0.016 | fwd=-0.135 | vel=-0.470 | imitat=-0.005 | alive= 0.100 | energy_p= 0.005 | fail= 0.112 | phase_spd= 0.047 | var=unknown
# [env 0] ep_len=  60 | R_mean=-0.051 | fwd=-0.452 | vel=-1.515 | imitat=-0.005 | alive= 0.100 | energy_p= 0.005 | fail= 0.250 | phase_spd= 0.049 | var=unknown
# [sched] imitation_w=0.036, energy_w=0.00114
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 119        |
# |    ep_rew_mean          | -3.84      |
# | time/                   |            |
# |    fps                  | 435        |
# |    iterations           | 8          |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00677315 |
# |    clip_fraction        | 0.0366     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -13        |
# |    explained_variance   | 0.0755     |
# |    learning_rate        | 0.000296   |
# |    loss                 | -0.105     |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0164    |
# |    std                  | 1.02       |
# |    value_loss           | 0.109      |
# ----------------------------------------
# [env 3] ep_len= 160 | R_mean=-0.034 | fwd=-0.312 | vel=-1.090 | imitat=-0.005 | alive= 0.100 | energy_p= 0.005 | fail= 0.094 | phase_spd= 0.044 | var=unknown
# [env 0] ep_len= 107 | R_mean=-0.026 | fwd=-0.224 | vel=-0.786 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.140 | phase_spd= 0.048 | var=unknown
# [env 0] ep_len=  61 | R_mean=-0.037 | fwd=-0.317 | vel=-1.049 | imitat=-0.007 | alive= 0.100 | energy_p= 0.005 | fail= 0.246 | phase_spd= 0.045 | var=unknown
# [env 2] ep_len= 221 | R_mean=-0.026 | fwd=-0.230 | vel=-0.817 | imitat=-0.007 | alive= 0.100 | energy_p= 0.005 | fail= 0.068 | phase_spd= 0.046 | var=unknown
# [env 3] ep_len= 230 | R_mean=-0.019 | fwd=-0.169 | vel=-0.595 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.065 | phase_spd= 0.044 | var=unknown
# [env 0] ep_len=  94 | R_mean=-0.047 | fwd=-0.418 | vel=-1.460 | imitat=-0.007 | alive= 0.100 | energy_p= 0.005 | fail= 0.160 | phase_spd= 0.045 | var=unknown
# [env 1] ep_len= 309 | R_mean=-0.010 | fwd=-0.079 | vel=-0.311 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.049 | phase_spd= 0.046 | var=unknown
# [env 2] ep_len=  91 | R_mean=-0.044 | fwd=-0.391 | vel=-1.351 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.165 | phase_spd= 0.048 | var=unknown
# [env 0] ep_len=  65 | R_mean=-0.039 | fwd=-0.330 | vel=-1.098 | imitat=-0.007 | alive= 0.100 | energy_p= 0.005 | fail= 0.231 | phase_spd= 0.044 | var=unknown
# [env 3] ep_len=  78 | R_mean=-0.041 | fwd=-0.350 | vel=-1.203 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.192 | phase_spd= 0.047 | var=unknown
# [env 0] ep_len=  82 | R_mean=-0.043 | fwd=-0.375 | vel=-1.259 | imitat=-0.008 | alive= 0.100 | energy_p= 0.005 | fail= 0.183 | phase_spd= 0.045 | var=unknown
# [env 1] ep_len= 203 | R_mean=-0.030 | fwd=-0.272 | vel=-0.926 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.074 | phase_spd= 0.045 | var=unknown
# [env 2] ep_len= 180 | R_mean=-0.016 | fwd=-0.134 | vel=-0.471 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.083 | phase_spd= 0.045 | var=unknown
# [env 0] ep_len=  62 | R_mean=-0.046 | fwd=-0.385 | vel=-1.328 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.242 | phase_spd= 0.044 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 125          |
# |    ep_rew_mean          | -3.87        |
# | time/                   |              |
# |    fps                  | 429          |
# |    iterations           | 9            |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0075702234 |
# |    clip_fraction        | 0.0529       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.9        |
# |    explained_variance   | 0.0263       |
# |    learning_rate        | 0.000295     |
# |    loss                 | -0.0944      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0166      |
# |    std                  | 1.02         |
# |    value_loss           | 0.212        |
# ------------------------------------------
# [env 0] ep_len=  58 | R_mean=-0.031 | fwd=-0.243 | vel=-0.819 | imitat=-0.005 | alive= 0.100 | energy_p= 0.005 | fail= 0.259 | phase_spd= 0.043 | var=unknown
# [env 1] ep_len=  66 | R_mean=-0.065 | fwd=-0.580 | vel=-1.965 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.227 | phase_spd= 0.045 | var=unknown
# [env 3] ep_len= 256 | R_mean=-0.016 | fwd=-0.131 | vel=-0.469 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.059 | phase_spd= 0.046 | var=unknown
# [env 0] ep_len=  63 | R_mean=-0.050 | fwd=-0.432 | vel=-1.452 | imitat=-0.007 | alive= 0.100 | energy_p= 0.005 | fail= 0.238 | phase_spd= 0.045 | var=unknown
# [env 2] ep_len= 130 | R_mean=-0.009 | fwd=-0.054 | vel=-0.215 | imitat=-0.007 | alive= 0.100 | energy_p= 0.005 | fail= 0.115 | phase_spd= 0.047 | var=unknown
# [env 1] ep_len=  79 | R_mean=-0.023 | fwd=-0.176 | vel=-0.620 | imitat=-0.007 | alive= 0.100 | energy_p= 0.005 | fail= 0.190 | phase_spd= 0.045 | var=unknown
# [env 3] ep_len=  66 | R_mean=-0.032 | fwd=-0.255 | vel=-0.845 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.227 | phase_spd= 0.043 | var=unknown
# [env 0] ep_len=  77 | R_mean=-0.030 | fwd=-0.239 | vel=-0.837 | imitat=-0.008 | alive= 0.100 | energy_p= 0.005 | fail= 0.195 | phase_spd= 0.049 | var=unknown
# [env 0] ep_len= 138 | R_mean=-0.011 | fwd=-0.076 | vel=-0.299 | imitat=-0.007 | alive= 0.100 | energy_p= 0.005 | fail= 0.109 | phase_spd= 0.044 | var=unknown
# [env 1] ep_len= 245 | R_mean=-0.021 | fwd=-0.184 | vel=-0.657 | imitat=-0.006 | alive= 0.100 | energy_p= 0.005 | fail= 0.061 | phase_spd= 0.043 | var=unknown
# [env 3] ep_len= 241 | R_mean=-0.017 | fwd=-0.141 | vel=-0.505 | imitat=-0.008 | alive= 0.100 | energy_p= 0.005 | fail= 0.062 | phase_spd= 0.042 | var=unknown
# [env 0] ep_len=  87 | R_mean=-0.039 | fwd=-0.321 | vel=-1.117 | imitat=-0.007 | alive= 0.100 | energy_p= 0.005 | fail= 0.172 | phase_spd= 0.040 | var=unknown
# [env 2] ep_len= 338 | R_mean=-0.007 | fwd=-0.042 | vel=-0.200 | imitat=-0.007 | alive= 0.100 | energy_p= 0.005 | fail= 0.044 | phase_spd= 0.044 | var=unknown
# [env 3] ep_len=  79 | R_mean=-0.035 | fwd=-0.277 | vel=-1.009 | imitat=-0.007 | alive= 0.100 | energy_p= 0.005 | fail= 0.190 | phase_spd= 0.040 | var=unknown
# [env 0] ep_len= 109 | R_mean=-0.065 | fwd=-0.574 | vel=-1.984 | imitat=-0.008 | alive= 0.100 | energy_p= 0.005 | fail= 0.138 | phase_spd= 0.047 | var=unknown
# [env 2] ep_len=  71 | R_mean=-0.028 | fwd=-0.207 | vel=-0.749 | imitat=-0.007 | alive= 0.100 | energy_p= 0.005 | fail= 0.211 | phase_spd= 0.043 | var=unknown
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | -3.68       |
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 10          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005392052 |
# |    clip_fraction        | 0.0218      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.9       |
# |    explained_variance   | -0.0414     |
# |    learning_rate        | 0.000294    |
# |    loss                 | -0.089      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 1.02        |
# |    value_loss           | 0.126       |
# -----------------------------------------
# [env 1] ep_len= 183 | R_mean=-0.014 | fwd=-0.107 | vel=-0.402 | imitat=-0.007 | alive= 0.100 | energy_p= 0.005 | fail= 0.082 | phase_spd= 0.045 | var=unknown
# [env 3] ep_len=  85 | R_mean=-0.027 | fwd=-0.194 | vel=-0.750 | imitat=-0.007 | alive= 0.100 | energy_p= 0.005 | fail= 0.176 | phase_spd= 0.044 | var=unknown
# [env 0] ep_len=  69 | R_mean=-0.065 | fwd=-0.563 | vel=-1.935 | imitat=-0.009 | alive= 0.100 | energy_p= 0.005 | fail= 0.217 | phase_spd= 0.046 | var=unknown
# [env 2] ep_len= 146 | R_mean=-0.016 | fwd=-0.116 | vel=-0.431 | imitat=-0.008 | alive= 0.100 | energy_p= 0.005 | fail= 0.103 | phase_spd= 0.043 | var=unknown
# [env 0] ep_len=  86 | R_mean=-0.015 | fwd=-0.097 | vel=-0.342 | imitat=-0.007 | alive= 0.100 | energy_p= 0.005 | fail= 0.174 | phase_spd= 0.045 | var=unknown
# [env 3] ep_len= 122 | R_mean=-0.023 | fwd=-0.185 | vel=-0.637 | imitat=-0.008 | alive= 0.100 | energy_p= 0.005 | fail= 0.123 | phase_spd= 0.049 | var=unknown
# [env 2] ep_len=  93 | R_mean=-0.020 | fwd=-0.139 | vel=-0.515 | imitat=-0.007 | alive= 0.100 | energy_p= 0.005 | fail= 0.161 | phase_spd= 0.046 | var=unknown
# [env 0] ep_len=  94 | R_mean=-0.019 | fwd=-0.140 | vel=-0.479 | imitat=-0.009 | alive= 0.100 | energy_p= 0.005 | fail= 0.160 | phase_spd= 0.044 | var=unknown
# [env 2] ep_len= 177 | R_mean=-0.024 | fwd=-0.198 | vel=-0.710 | imitat=-0.009 | alive= 0.100 | energy_p= 0.005 | fail= 0.085 | phase_spd= 0.045 | var=unknown
# [env 3] ep_len= 300 | R_mean=-0.019 | fwd=-0.157 | vel=-0.575 | imitat=-0.008 | alive= 0.100 | energy_p= 0.005 | fail= 0.050 | phase_spd= 0.045 | var=unknown
# [env 0] ep_len= 233 | R_mean=-0.006 | fwd=-0.032 | vel=-0.173 | imitat=-0.008 | alive= 0.100 | energy_p= 0.005 | fail= 0.064 | phase_spd= 0.043 | var=unknown
# [env 2] ep_len=  65 | R_mean=-0.049 | fwd=-0.402 | vel=-1.378 | imitat=-0.007 | alive= 0.100 | energy_p= 0.005 | fail= 0.231 | phase_spd= 0.042 | var=unknown
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 133         |
# |    ep_rew_mean          | -3.56       |
# | time/                   |             |
# |    fps                  | 430         |
# |    iterations           | 11          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005895604 |
# |    clip_fraction        | 0.0268      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.9       |
# |    explained_variance   | 0.00786     |
# |    learning_rate        | 0.000294    |
# |    loss                 | -0.0857     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 1.02        |
# |    value_loss           | 0.152       |
# -----------------------------------------
# [env 3] ep_len=  72 | R_mean=-0.014 | fwd=-0.077 | vel=-0.282 | imitat=-0.008 | alive= 0.100 | energy_p= 0.005 | fail= 0.208 | phase_spd= 0.045 | var=unknown
# [env 1] ep_len= 512 | R_mean=-0.022 | fwd=-0.192 | vel=-0.675 | imitat=-0.008 | alive= 0.100 | energy_p= 0.005 | fail= 0.029 | phase_spd= 0.044 | var=unknown
# [env 0] ep_len= 200 | R_mean=-0.011 | fwd=-0.070 | vel=-0.308 | imitat=-0.009 | alive= 0.100 | energy_p= 0.005 | fail= 0.075 | phase_spd= 0.045 | var=unknown
# [env 1] ep_len= 151 | R_mean=-0.015 | fwd=-0.112 | vel=-0.402 | imitat=-0.008 | alive= 0.100 | energy_p= 0.005 | fail= 0.099 | phase_spd= 0.047 | var=unknown
# [env 0] ep_len=  55 | R_mean=-0.033 | fwd=-0.242 | vel=-0.815 | imitat=-0.009 | alive= 0.100 | energy_p= 0.005 | fail= 0.273 | phase_spd= 0.041 | var=unknown
# [env 2] ep_len= 280 | R_mean=-0.016 | fwd=-0.131 | vel=-0.466 | imitat=-0.009 | alive= 0.100 | energy_p= 0.005 | fail= 0.054 | phase_spd= 0.045 | var=unknown
# [env 3] ep_len= 252 | R_mean=-0.014 | fwd=-0.112 | vel=-0.404 | imitat=-0.009 | alive= 0.100 | energy_p= 0.005 | fail= 0.060 | phase_spd= 0.042 | var=unknown
# [env 2] ep_len=  67 | R_mean=-0.025 | fwd=-0.164 | vel=-0.644 | imitat=-0.009 | alive= 0.100 | energy_p= 0.005 | fail= 0.224 | phase_spd= 0.043 | var=unknown
# [env 1] ep_len= 144 | R_mean=-0.016 | fwd=-0.116 | vel=-0.439 | imitat=-0.008 | alive= 0.100 | energy_p= 0.005 | fail= 0.104 | phase_spd= 0.043 | var=unknown
# [env 0] ep_len= 174 | R_mean=-0.018 | fwd=-0.140 | vel=-0.488 | imitat=-0.009 | alive= 0.100 | energy_p= 0.005 | fail= 0.086 | phase_spd= 0.043 | var=unknown
# [env 2] ep_len= 160 | R_mean=-0.034 | fwd=-0.290 | vel=-0.999 | imitat=-0.008 | alive= 0.100 | energy_p= 0.005 | fail= 0.094 | phase_spd= 0.045 | var=unknown
# [env 1] ep_len= 157 | R_mean=-0.021 | fwd=-0.163 | vel=-0.584 | imitat=-0.008 | alive= 0.100 | energy_p= 0.005 | fail= 0.096 | phase_spd= 0.040 | var=unknown
# [sched] imitation_w=0.056, energy_w=0.00123
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 139          |
# |    ep_rew_mean          | -3.54        |
# | time/                   |              |
# |    fps                  | 420          |
# |    iterations           | 12           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0047541624 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.9        |
# |    explained_variance   | 0.00245      |
# |    learning_rate        | 0.000293     |
# |    loss                 | -0.0849      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0141      |
# |    std                  | 1.02         |
# |    value_loss           | 0.131        |
# ------------------------------------------
# [env 3] ep_len= 273 | R_mean=-0.038 | fwd=-0.336 | vel=-1.132 | imitat=-0.010 | alive= 0.100 | energy_p= 0.005 | fail= 0.055 | phase_spd= 0.042 | var=unknown
# [env 0] ep_len= 219 | R_mean=-0.024 | fwd=-0.197 | vel=-0.704 | imitat=-0.009 | alive= 0.100 | energy_p= 0.005 | fail= 0.068 | phase_spd= 0.042 | var=unknown
# [env 1] ep_len= 133 | R_mean=-0.027 | fwd=-0.215 | vel=-0.742 | imitat=-0.009 | alive= 0.100 | energy_p= 0.005 | fail= 0.113 | phase_spd= 0.048 | var=unknown
# [env 2] ep_len= 182 | R_mean=-0.014 | fwd=-0.097 | vel=-0.369 | imitat=-0.010 | alive= 0.100 | energy_p= 0.005 | fail= 0.082 | phase_spd= 0.043 | var=unknown
# [env 0] ep_len=  57 | R_mean=-0.056 | fwd=-0.461 | vel=-1.527 | imitat=-0.009 | alive= 0.100 | energy_p= 0.006 | fail= 0.263 | phase_spd= 0.047 | var=unknown
# [env 0] ep_len=  72 | R_mean=-0.033 | fwd=-0.251 | vel=-0.860 | imitat=-0.010 | alive= 0.100 | energy_p= 0.005 | fail= 0.208 | phase_spd= 0.047 | var=unknown
# [env 2] ep_len=  91 | R_mean=-0.006 | fwd=-0.010 | vel=-0.077 | imitat=-0.011 | alive= 0.100 | energy_p= 0.005 | fail= 0.165 | phase_spd= 0.048 | var=unknown
# [env 3] ep_len= 287 | R_mean=-0.012 | fwd=-0.090 | vel=-0.351 | imitat=-0.010 | alive= 0.100 | energy_p= 0.005 | fail= 0.052 | phase_spd= 0.046 | var=unknown
# [env 0] ep_len= 105 | R_mean=-0.032 | fwd=-0.262 | vel=-0.891 | imitat=-0.009 | alive= 0.100 | energy_p= 0.005 | fail= 0.143 | phase_spd= 0.045 | var=unknown
# [env 1] ep_len= 231 | R_mean=-0.012 | fwd=-0.082 | vel=-0.323 | imitat=-0.011 | alive= 0.100 | energy_p= 0.005 | fail= 0.065 | phase_spd= 0.044 | var=unknown
# [env 2] ep_len= 107 | R_mean=-0.027 | fwd=-0.213 | vel=-0.731 | imitat=-0.010 | alive= 0.100 | energy_p= 0.005 | fail= 0.140 | phase_spd= 0.046 | var=unknown
# [env 1] ep_len=  61 | R_mean=-0.060 | fwd=-0.487 | vel=-1.648 | imitat=-0.010 | alive= 0.100 | energy_p= 0.005 | fail= 0.246 | phase_spd= 0.046 | var=unknown
# [env 3] ep_len= 118 | R_mean=-0.013 | fwd=-0.064 | vel=-0.318 | imitat=-0.010 | alive= 0.100 | energy_p= 0.005 | fail= 0.127 | phase_spd= 0.040 | var=unknown
# [env 0] ep_len= 162 | R_mean=-0.011 | fwd=-0.072 | vel=-0.283 | imitat=-0.009 | alive= 0.100 | energy_p= 0.005 | fail= 0.093 | phase_spd= 0.049 | var=unknown
# [env 2] ep_len= 166 | R_mean=-0.018 | fwd=-0.134 | vel=-0.476 | imitat=-0.009 | alive= 0.100 | energy_p= 0.005 | fail= 0.090 | phase_spd= 0.045 | var=unknown
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 145         |
# |    ep_rew_mean          | -3.45       |
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 13          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.005360294 |
# |    clip_fraction        | 0.0228      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.9       |
# |    explained_variance   | 0.155       |
# |    learning_rate        | 0.000293    |
# |    loss                 | -0.114      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0152     |
# |    std                  | 1.02        |
# |    value_loss           | 0.0954      |
# -----------------------------------------
# [env 2] ep_len=  66 | R_mean=-0.025 | fwd=-0.169 | vel=-0.613 | imitat=-0.011 | alive= 0.100 | energy_p= 0.006 | fail= 0.227 | phase_spd= 0.046 | var=unknown
# [env 3] ep_len= 140 | R_mean=-0.016 | fwd=-0.105 | vel=-0.412 | imitat=-0.010 | alive= 0.100 | energy_p= 0.005 | fail= 0.107 | phase_spd= 0.043 | var=unknown
# [env 0] ep_len= 158 | R_mean=-0.022 | fwd=-0.171 | vel=-0.604 | imitat=-0.011 | alive= 0.100 | energy_p= 0.005 | fail= 0.095 | phase_spd= 0.040 | var=unknown
# [env 3] ep_len=  72 | R_mean=-0.039 | fwd=-0.305 | vel=-1.023 | imitat=-0.010 | alive= 0.100 | energy_p= 0.005 | fail= 0.208 | phase_spd= 0.049 | var=unknown
# [env 2] ep_len=  95 | R_mean=-0.025 | fwd=-0.168 | vel=-0.651 | imitat=-0.011 | alive= 0.100 | energy_p= 0.005 | fail= 0.158 | phase_spd= 0.044 | var=unknown
# [env 0] ep_len= 125 | R_mean=-0.066 | fwd=-0.579 | vel=-1.914 | imitat=-0.010 | alive= 0.100 | energy_p= 0.005 | fail= 0.120 | phase_spd= 0.043 | var=unknown
# [env 2] ep_len= 146 | R_mean=-0.018 | fwd=-0.130 | vel=-0.479 | imitat=-0.011 | alive= 0.100 | energy_p= 0.005 | fail= 0.103 | phase_spd= 0.044 | var=unknown
# [env 1] ep_len= 458 | R_mean=-0.013 | fwd=-0.098 | vel=-0.371 | imitat=-0.010 | alive= 0.100 | energy_p= 0.005 | fail= 0.033 | phase_spd= 0.048 | var=unknown
# ...
# |    clip_fraction        | 0.00376      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -15.4        |
# |    explained_variance   | 0.616        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.157       |
# |    n_updates            | 4830         |
# |    policy_gradient_loss | -0.00555     |
# |    std                  | 1.44         |
# |    value_loss           | 0.0317       |
# ------------------------------------------
# [env 1] ep_len= 114 | R_mean=-0.017 | fwd= 0.042 | vel= 0.099 | imitat=-0.194 | alive= 0.100 | energy_p= 0.042 | fail= 0.132 | phase_spd= 0.044 | var=unknown
# [env 3] ep_len=  83 | R_mean=-0.026 | fwd= 0.025 | vel= 0.025 | imitat=-0.168 | alive= 0.100 | energy_p= 0.043 | fail= 0.181 | phase_spd= 0.047 | var=unknown
# [env 2] ep_len= 134 | R_mean=-0.014 | fwd= 0.048 | vel= 0.098 | imitat=-0.185 | alive= 0.100 | energy_p= 0.041 | fail= 0.112 | phase_spd= 0.044 | var=unknown
# [env 0] ep_len= 177 | R_mean=-0.014 | fwd= 0.047 | vel= 0.089 | imitat=-0.205 | alive= 0.100 | energy_p= 0.042 | fail= 0.085 | phase_spd= 0.044 | var=unknown
# [env 3] ep_len= 168 | R_mean=-0.009 | fwd= 0.069 | vel= 0.124 | imitat=-0.206 | alive= 0.100 | energy_p= 0.041 | fail= 0.089 | phase_spd= 0.046 | var=unknown
# [env 0] ep_len= 145 | R_mean=-0.014 | fwd= 0.051 | vel= 0.092 | imitat=-0.191 | alive= 0.100 | energy_p= 0.041 | fail= 0.103 | phase_spd= 0.051 | var=unknown
# [env 2] ep_len= 187 | R_mean=-0.011 | fwd= 0.057 | vel= 0.107 | imitat=-0.202 | alive= 0.100 | energy_p= 0.040 | fail= 0.080 | phase_spd= 0.045 | var=unknown
# [env 1] ep_len= 291 | R_mean=-0.006 | fwd= 0.061 | vel= 0.130 | imitat=-0.197 | alive= 0.100 | energy_p= 0.040 | fail= 0.052 | phase_spd= 0.044 | var=unknown
# [env 3] ep_len= 104 | R_mean=-0.014 | fwd= 0.056 | vel= 0.106 | imitat=-0.167 | alive= 0.100 | energy_p= 0.042 | fail= 0.144 | phase_spd= 0.048 | var=unknown
# [env 2] ep_len= 116 | R_mean=-0.017 | fwd= 0.050 | vel= 0.086 | imitat=-0.202 | alive= 0.100 | energy_p= 0.042 | fail= 0.129 | phase_spd= 0.047 | var=unknown
# [env 0] ep_len= 136 | R_mean=-0.010 | fwd= 0.075 | vel= 0.117 | imitat=-0.188 | alive= 0.100 | energy_p= 0.039 | fail= 0.110 | phase_spd= 0.042 | var=unknown
# [env 2] ep_len=  84 | R_mean=-0.038 | fwd= 0.002 | vel=-0.049 | imitat=-0.216 | alive= 0.100 | energy_p= 0.040 | fail= 0.179 | phase_spd= 0.043 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 153          |
# |    ep_rew_mean          | -2.44        |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 485          |
# |    time_elapsed         | 1755         |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0010728035 |
# |    clip_fraction        | 0.00337      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -15.4        |
# |    explained_variance   | 0.653        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.154       |
# |    n_updates            | 4840         |
# |    policy_gradient_loss | -0.0054      |
# |    std                  | 1.44         |
# |    value_loss           | 0.0263       |
# ------------------------------------------
# [env 0] ep_len= 113 | R_mean=-0.026 | fwd= 0.027 | vel= 0.012 | imitat=-0.211 | alive= 0.100 | energy_p= 0.041 | fail= 0.133 | phase_spd= 0.044 | var=unknown
# [env 3] ep_len= 208 | R_mean=-0.010 | fwd= 0.058 | vel= 0.106 | imitat=-0.204 | alive= 0.100 | energy_p= 0.040 | fail= 0.072 | phase_spd= 0.046 | var=unknown
# [env 1] ep_len= 276 | R_mean=-0.012 | fwd= 0.045 | vel= 0.085 | imitat=-0.202 | alive= 0.100 | energy_p= 0.040 | fail= 0.054 | phase_spd= 0.048 | var=unknown
# [env 2] ep_len=  98 | R_mean=-0.024 | fwd= 0.041 | vel= 0.043 | imitat=-0.210 | alive= 0.100 | energy_p= 0.042 | fail= 0.153 | phase_spd= 0.047 | var=unknown
# [env 1] ep_len=  95 | R_mean=-0.017 | fwd= 0.051 | vel= 0.123 | imitat=-0.204 | alive= 0.100 | energy_p= 0.040 | fail= 0.158 | phase_spd= 0.041 | var=unknown
# [env 3] ep_len= 193 | R_mean=-0.017 | fwd= 0.031 | vel= 0.059 | imitat=-0.191 | alive= 0.100 | energy_p= 0.041 | fail= 0.078 | phase_spd= 0.045 | var=unknown
# [env 2] ep_len= 158 | R_mean=-0.013 | fwd= 0.048 | vel= 0.074 | imitat=-0.173 | alive= 0.100 | energy_p= 0.041 | fail= 0.095 | phase_spd= 0.047 | var=unknown
# [env 0] ep_len= 224 | R_mean=-0.006 | fwd= 0.067 | vel= 0.136 | imitat=-0.203 | alive= 0.100 | energy_p= 0.040 | fail= 0.067 | phase_spd= 0.043 | var=unknown
# [env 1] ep_len= 129 | R_mean=-0.009 | fwd= 0.067 | vel= 0.149 | imitat=-0.189 | alive= 0.100 | energy_p= 0.040 | fail= 0.116 | phase_spd= 0.045 | var=unknown
# [env 3] ep_len=  88 | R_mean=-0.023 | fwd= 0.043 | vel= 0.068 | imitat=-0.193 | alive= 0.100 | energy_p= 0.043 | fail= 0.170 | phase_spd= 0.047 | var=unknown
# [env 0] ep_len=  96 | R_mean=-0.024 | fwd= 0.032 | vel= 0.029 | imitat=-0.177 | alive= 0.100 | energy_p= 0.043 | fail= 0.156 | phase_spd= 0.045 | var=unknown
# [env 1] ep_len=  90 | R_mean=-0.012 | fwd= 0.068 | vel= 0.151 | imitat=-0.177 | alive= 0.100 | energy_p= 0.041 | fail= 0.167 | phase_spd= 0.048 | var=unknown
# [env 2] ep_len= 158 | R_mean=-0.012 | fwd= 0.056 | vel= 0.109 | imitat=-0.196 | alive= 0.100 | energy_p= 0.041 | fail= 0.095 | phase_spd= 0.047 | var=unknown
# [env 0] ep_len=  87 | R_mean=-0.016 | fwd= 0.055 | vel= 0.119 | imitat=-0.177 | alive= 0.100 | energy_p= 0.042 | fail= 0.172 | phase_spd= 0.042 | var=unknown
# [env 3] ep_len= 125 | R_mean=-0.022 | fwd= 0.029 | vel= 0.047 | imitat=-0.196 | alive= 0.100 | energy_p= 0.042 | fail= 0.120 | phase_spd= 0.046 | var=unknown
# [env 1] ep_len=  74 | R_mean=-0.020 | fwd= 0.055 | vel= 0.106 | imitat=-0.179 | alive= 0.100 | energy_p= 0.041 | fail= 0.203 | phase_spd= 0.051 | var=unknown
# [env 2] ep_len= 101 | R_mean=-0.015 | fwd= 0.053 | vel= 0.110 | imitat=-0.176 | alive= 0.100 | energy_p= 0.041 | fail= 0.149 | phase_spd= 0.045 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 148          |
# |    ep_rew_mean          | -2.32        |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 486          |
# |    time_elapsed         | 1759         |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0011381442 |
# |    clip_fraction        | 0.00317      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -15.4        |
# |    explained_variance   | 0.667        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.15        |
# |    n_updates            | 4850         |
# |    policy_gradient_loss | -0.00526     |
# |    std                  | 1.44         |
# |    value_loss           | 0.0267       |
# ------------------------------------------
# [env 3] ep_len= 183 | R_mean=-0.016 | fwd= 0.037 | vel= 0.065 | imitat=-0.192 | alive= 0.100 | energy_p= 0.041 | fail= 0.082 | phase_spd= 0.046 | var=unknown
# [env 0] ep_len= 230 | R_mean=-0.014 | fwd= 0.042 | vel= 0.074 | imitat=-0.202 | alive= 0.100 | energy_p= 0.039 | fail= 0.065 | phase_spd= 0.045 | var=unknown
# [env 2] ep_len= 167 | R_mean=-0.012 | fwd= 0.047 | vel= 0.098 | imitat=-0.182 | alive= 0.100 | energy_p= 0.041 | fail= 0.090 | phase_spd= 0.048 | var=unknown
# [env 1] ep_len= 235 | R_mean=-0.013 | fwd= 0.046 | vel= 0.084 | imitat=-0.203 | alive= 0.100 | energy_p= 0.040 | fail= 0.064 | phase_spd= 0.048 | var=unknown
# [env 1] ep_len=  74 | R_mean=-0.069 | fwd=-0.086 | vel=-0.337 | imitat=-0.192 | alive= 0.100 | energy_p= 0.042 | fail= 0.203 | phase_spd= 0.050 | var=unknown
# [env 3] ep_len= 185 | R_mean=-0.024 | fwd= 0.019 | vel= 0.017 | imitat=-0.217 | alive= 0.100 | energy_p= 0.040 | fail= 0.081 | phase_spd= 0.046 | var=unknown
# [env 2] ep_len= 166 | R_mean=-0.019 | fwd= 0.042 | vel= 0.028 | imitat=-0.192 | alive= 0.100 | energy_p= 0.041 | fail= 0.090 | phase_spd= 0.043 | var=unknown
# [env 0] ep_len= 242 | R_mean=-0.012 | fwd= 0.046 | vel= 0.093 | imitat=-0.205 | alive= 0.100 | energy_p= 0.040 | fail= 0.062 | phase_spd= 0.045 | var=unknown
# [env 3] ep_len= 166 | R_mean=-0.011 | fwd= 0.058 | vel= 0.094 | imitat=-0.181 | alive= 0.100 | energy_p= 0.040 | fail= 0.090 | phase_spd= 0.044 | var=unknown
# [env 0] ep_len=  73 | R_mean=-0.041 | fwd=-0.016 | vel=-0.102 | imitat=-0.155 | alive= 0.100 | energy_p= 0.041 | fail= 0.205 | phase_spd= 0.042 | var=unknown
# [env 1] ep_len= 233 | R_mean=-0.011 | fwd= 0.043 | vel= 0.089 | imitat=-0.177 | alive= 0.100 | energy_p= 0.041 | fail= 0.064 | phase_spd= 0.044 | var=unknown
# [env 2] ep_len= 175 | R_mean=-0.003 | fwd= 0.077 | vel= 0.150 | imitat=-0.172 | alive= 0.100 | energy_p= 0.040 | fail= 0.086 | phase_spd= 0.045 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 151          |
# |    ep_rew_mean          | -2.36        |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 487          |
# |    time_elapsed         | 1762         |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0010815987 |
# |    clip_fraction        | 0.00327      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -15.4        |
# |    explained_variance   | 0.65         |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.156       |
# |    n_updates            | 4860         |
# |    policy_gradient_loss | -0.00621     |
# |    std                  | 1.44         |
# |    value_loss           | 0.0242       |
# ------------------------------------------
# [env 3] ep_len=  86 | R_mean=-0.033 | fwd= 0.015 | vel=-0.050 | imitat=-0.179 | alive= 0.100 | energy_p= 0.041 | fail= 0.174 | phase_spd= 0.044 | var=unknown
# [env 2] ep_len= 120 | R_mean=-0.023 | fwd= 0.032 | vel= 0.014 | imitat=-0.190 | alive= 0.100 | energy_p= 0.040 | fail= 0.125 | phase_spd= 0.044 | var=unknown
# [env 1] ep_len= 129 | R_mean=-0.019 | fwd= 0.034 | vel= 0.054 | imitat=-0.176 | alive= 0.100 | energy_p= 0.043 | fail= 0.116 | phase_spd= 0.047 | var=unknown
# [env 3] ep_len=  91 | R_mean=-0.030 | fwd= 0.015 | vel=-0.012 | imitat=-0.187 | alive= 0.100 | energy_p= 0.042 | fail= 0.165 | phase_spd= 0.049 | var=unknown
# [env 0] ep_len= 195 | R_mean=-0.015 | fwd= 0.037 | vel= 0.067 | imitat=-0.189 | alive= 0.100 | energy_p= 0.041 | fail= 0.077 | phase_spd= 0.049 | var=unknown
# [env 1] ep_len= 164 | R_mean=-0.006 | fwd= 0.076 | vel= 0.150 | imitat=-0.200 | alive= 0.100 | energy_p= 0.041 | fail= 0.091 | phase_spd= 0.044 | var=unknown
# [env 3] ep_len= 198 | R_mean=-0.016 | fwd= 0.029 | vel= 0.060 | imitat=-0.186 | alive= 0.100 | energy_p= 0.043 | fail= 0.076 | phase_spd= 0.048 | var=unknown
# [env 0] ep_len= 194 | R_mean=-0.018 | fwd= 0.025 | vel= 0.033 | imitat=-0.182 | alive= 0.100 | energy_p= 0.041 | fail= 0.077 | phase_spd= 0.046 | var=unknown
# [env 2] ep_len= 264 | R_mean=-0.005 | fwd= 0.069 | vel= 0.119 | imitat=-0.189 | alive= 0.100 | energy_p= 0.040 | fail= 0.057 | phase_spd= 0.047 | var=unknown
# [env 3] ep_len=  71 | R_mean=-0.025 | fwd= 0.051 | vel= 0.066 | imitat=-0.192 | alive= 0.100 | energy_p= 0.041 | fail= 0.211 | phase_spd= 0.046 | var=unknown
# [env 2] ep_len=  79 | R_mean=-0.018 | fwd= 0.064 | vel= 0.115 | imitat=-0.191 | alive= 0.100 | energy_p= 0.041 | fail= 0.190 | phase_spd= 0.039 | var=unknown
# [env 1] ep_len= 195 | R_mean=-0.018 | fwd= 0.027 | vel= 0.033 | imitat=-0.183 | alive= 0.100 | energy_p= 0.041 | fail= 0.077 | phase_spd= 0.044 | var=unknown
# [env 0] ep_len= 132 | R_mean=-0.017 | fwd= 0.043 | vel= 0.085 | imitat=-0.197 | alive= 0.100 | energy_p= 0.041 | fail= 0.114 | phase_spd= 0.050 | var=unknown
# [sched] imitation_w=1.000, energy_w=0.00700
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 152          |
# |    ep_rew_mean          | -2.38        |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 488          |
# |    time_elapsed         | 1766         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0009139901 |
# |    clip_fraction        | 0.00269      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -15.4        |
# |    explained_variance   | 0.526        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.146       |
# |    n_updates            | 4870         |
# |    policy_gradient_loss | -0.00481     |
# |    std                  | 1.44         |
# |    value_loss           | 0.061        |
# ------------------------------------------
# [env 3] ep_len= 171 | R_mean=-0.002 | fwd= 0.080 | vel= 0.160 | imitat=-0.172 | alive= 0.100 | energy_p= 0.041 | fail= 0.088 | phase_spd= 0.045 | var=unknown
# [env 1] ep_len= 104 | R_mean=-0.020 | fwd= 0.043 | vel= 0.077 | imitat=-0.195 | alive= 0.100 | energy_p= 0.043 | fail= 0.144 | phase_spd= 0.046 | var=unknown
# [env 0] ep_len= 103 | R_mean=-0.018 | fwd= 0.058 | vel= 0.080 | imitat=-0.204 | alive= 0.100 | energy_p= 0.040 | fail= 0.146 | phase_spd= 0.043 | var=unknown
# [env 2] ep_len= 198 | R_mean=-0.008 | fwd= 0.056 | vel= 0.116 | imitat=-0.182 | alive= 0.100 | energy_p= 0.040 | fail= 0.076 | phase_spd= 0.046 | var=unknown
# [env 3] ep_len=  88 | R_mean=-0.015 | fwd= 0.055 | vel= 0.121 | imitat=-0.170 | alive= 0.100 | energy_p= 0.043 | fail= 0.170 | phase_spd= 0.050 | var=unknown
#
# 🎥 Recording episode 8750...
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Video recording complete.
# [env 1] ep_len=  81 | R_mean=-0.021 | fwd= 0.045 | vel= 0.065 | imitat=-0.171 | alive= 0.100 | energy_p= 0.041 | fail= 0.185 | phase_spd= 0.049 | var=unknown
# [env 2] ep_len=  96 | R_mean=-0.037 | fwd=-0.005 | vel=-0.082 | imitat=-0.187 | alive= 0.100 | energy_p= 0.041 | fail= 0.156 | phase_spd= 0.042 | var=unknown
# [env 0] ep_len= 239 | R_mean=-0.019 | fwd= 0.024 | vel= 0.030 | imitat=-0.198 | alive= 0.100 | energy_p= 0.041 | fail= 0.063 | phase_spd= 0.043 | var=unknown
# [env 3] ep_len= 170 | R_mean=-0.019 | fwd= 0.033 | vel= 0.039 | imitat=-0.195 | alive= 0.100 | energy_p= 0.041 | fail= 0.088 | phase_spd= 0.046 | var=unknown
# [env 1] ep_len= 182 | R_mean=-0.010 | fwd= 0.052 | vel= 0.112 | imitat=-0.185 | alive= 0.100 | energy_p= 0.041 | fail= 0.082 | phase_spd= 0.047 | var=unknown
# [env 2] ep_len= 204 | R_mean=-0.012 | fwd= 0.042 | vel= 0.087 | imitat=-0.179 | alive= 0.100 | energy_p= 0.040 | fail= 0.074 | phase_spd= 0.049 | var=unknown
# [env 0] ep_len= 183 | R_mean=-0.015 | fwd= 0.043 | vel= 0.083 | imitat=-0.207 | alive= 0.100 | energy_p= 0.041 | fail= 0.082 | phase_spd= 0.044 | var=unknown
# [env 1] ep_len= 163 | R_mean=-0.013 | fwd= 0.052 | vel= 0.099 | imitat=-0.205 | alive= 0.100 | energy_p= 0.040 | fail= 0.092 | phase_spd= 0.045 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 153          |
# |    ep_rew_mean          | -2.4         |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 489          |
# |    time_elapsed         | 1770         |
# |    total_timesteps      | 1001472      |
# | train/                  |              |
# |    approx_kl            | 0.0009172344 |
# |    clip_fraction        | 0.00293      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -15.4        |
# |    explained_variance   | 0.665        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.15        |
# |    n_updates            | 4880         |
# |    policy_gradient_loss | -0.00413     |
# |    std                  | 1.44         |
# |    value_loss           | 0.0349       |
# ------------------------------------------
# Training complete for ppo_with_imitation

# %%
import numpy as np

data = np.load("quadruped_morph_trajectories.npz")
obs = data["obs"]
morph = data["morph"]

print("obs_dim:", obs.shape[1])
print("morph_dim:", morph.shape[1])
# Out:
# obs_dim: 97
# morph_dim: 8

# %%
import Reinforcement as re
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv, VecNormalize, VecMonitor, VecVideoRecorder
from stable_baselines3.common.utils import LinearSchedule
from stable_baselines3.common.logger import configure

def evaluate_quadruped_ppo(
    ppo_path: str,
    xml_path: str,
    morph_vec,
    episodes: int = 10,
    max_steps_per_ep: int = 1000,
    deterministic: bool = True,
    pose_generator=None,
    imitation_w: float = 0.0,
    imitation_obs_indices=None ):

    print(f"Loading PPO model from {ppo_path} ...")
    model = PPO.load(ppo_path)

    # Base env: same quadruped XML as in training
    base_env = re.make_quadruped_env(seed=0, xml_path=xml_path)

    # Wrap in MorphPhaseEnvWrapper so we get delta_x and energy_penalty in info
    eval_env = re.MorphPhaseEnvWrapper(
        base_env=base_env,
        morph_vec=morph_vec,
        cycle_steps=200,
        settle_steps=5,
        pose_generator=pose_generator,
        imitation_w=imitation_w,
        imitation_obs_indices=imitation_obs_indices,
        xml_path=xml_path,
    )

    episode_forward = []
    episode_energy = []

    for ep in range(episodes):
        obs, info = eval_env.reset()
        done = False
        truncated = False
        ep_forward = 0.0
        ep_energy = 0.0

        for t in range(max_steps_per_ep):
            # stable-baselines3 expects obs shape (n_envs, obs_dim) for VecEnv,
            # but here we have a single Gym env, so squeeze/unsqueeze as needed:
            action, _ = model.predict(obs, deterministic=deterministic)
            obs, reward, done, truncated, info = eval_env.step(action)

            # info fields are populated by MorphPhaseEnvWrapper.step(...)
            ep_forward += float(info.get("delta_x", 0.0))
            ep_energy  += float(info.get("energy_penalty", 0.0))

            if done or truncated:
                break

        episode_forward.append(ep_forward)
        episode_energy.append(ep_energy)
        print(
            f"Episode {ep+1:2d} | "
            f"forward = {ep_forward:.3f} | "
            f"energy = {ep_energy:.3f} | "
            f"steps = {t+1}"
        )

    avg_forward = float(np.mean(episode_forward)) if episode_forward else 0.0
    avg_energy  = float(np.mean(episode_energy)) if episode_energy else 0.0

    print("\n=== PPO evaluation over "
          f"{episodes} episodes ({xml_path}) ===")
    print(f"Average forward motion: {avg_forward:.3f}")
    print(f"Average energy spent:   {avg_energy:.3f}")

    return avg_forward, avg_energy

# %%
#Metrics Forward movement and energy

quad_morph = [
    0.141421, 0.282843,
    0.141421, 0.282843,
    0.141421, 0.282843,
    0.141421, 0.282843,
]

var1_morph = [
    0.2, 0.25,  # FR leg, FR ankle
    0.2, 0.25,  # FL leg, FL ankle
    0.141421, 0.3,  # BL leg, BL ankle
    0.141421, 0.3,  # BR leg, BR ankle
]

explore_var = "quadrl_var1_ppo.zip"
mlp = "ppo_with_mlp.zip"
generative = "ppo_with_imitation_ppo.zip"

diff_model, meta, device = load_diffusion(
    weights_path="quadruped_morph_diffusion_weights.pt",
    traj_file="quadruped_morph_trajectories.npz",)

full_cycle = diff.sample_full_cycle_from_morph(
    diff_model,
    meta,
    quad_morph,
    cycle_steps=200,
    device="cuda",
)
pose_template = DiffusionPoseTemplate(full_cycle)


avg_fwd1, avg_energy1 = evaluate_quadruped_ppo(
    ppo_path=explore_var,   
    xml_path="./quadruped_var1.xml",
    morph_vec=quad_morph,
    episodes=20,
    max_steps_per_ep=1000,
    deterministic=True,
    pose_generator=None,   
    imitation_w=0.0,    
    imitation_obs_indices=None,
)

avg_fwd2, avg_energy2 = evaluate_quadruped_ppo(
    ppo_path=mlp,   
    xml_path="./quadruped.xml",
    morph_vec=quad_morph,
    episodes=20,
    max_steps_per_ep=1000,
    deterministic=True,
    pose_generator=None,   
    imitation_w=0.0,    
    imitation_obs_indices=None,
)

avg_fwd3, avg_energy3 = evaluate_quadruped_ppo(
    ppo_path=generative,   
    xml_path="./quadruped.xml",
    morph_vec=quad_morph,
    episodes=20,
    max_steps_per_ep=1000,
    deterministic=True,
    pose_generator=pose_template,    # DiffusionPoseTemplate active
    imitation_w=0.0,    
    imitation_obs_indices=None,
)


print(" Quadruped PPO Evaluation Summary")
print("")

header = f"{'Model':<20} | {'Avg Forward':>12} | {'Avg Energy':>12} | {'Notes'}"
print(header)
print("-"*72)

rows = [
    ("Exploration-PPO",  avg_fwd1, avg_energy1, "baseline (explore_var)"),
    ("MLP-PPO",          avg_fwd2, avg_energy2, "baseline (mlp)"),
    ("Generative-PPO",   avg_fwd3, avg_energy3, "diffusion-guided"),
]

for name, fwd, energy, note in rows:
    print(f"{name:<20} | {fwd:12.4f} | {energy:12.4f} | {note}")
# Out:
# Using device: cuda
# Loaded config from checkpoint:
#   traj_file : quadruped_morph_trajectories.npz
#   past_len  : 10
#   future_len: 200
#   n_steps   : 100
#   hidden    : 256
#   imitation_obs_indices: [5, 6, 7, 8, 9, 10, 11, 12]
# [QuadrupedDataset] obs_dim=97, morph_dim=8
# [QuadrupedDataset] target_dim=8
# [QuadrupedDataset] total samples possible=87182
# Reconstructed diffusion dims:
#   D_target (obs_dim) = 8
#   D_cond             = 88
# Loaded diffusion model.
# Loading PPO model from quadrl_var1_ppo.zip ...
# C:\Users\Lep\miniconda3\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  1 | forward = 38.612 | energy = 48.736 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  2 | forward = 0.284 | energy = 2.186 | steps = 54
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  3 | forward = 35.711 | energy = 48.411 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  4 | forward = 38.485 | energy = 48.644 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  5 | forward = 25.945 | energy = 47.835 | steps = 982
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  6 | forward = 0.273 | energy = 2.369 | steps = 57
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  7 | forward = 28.151 | energy = 48.497 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  8 | forward = 38.399 | energy = 48.640 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  9 | forward = 35.326 | energy = 48.429 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 10 | forward = -1.397 | energy = 2.159 | steps = 54
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 11 | forward = 40.130 | energy = 48.756 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 12 | forward = 36.812 | energy = 48.402 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 13 | forward = -9.245 | energy = 25.167 | steps = 512
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 14 | forward = 40.768 | energy = 48.767 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 15 | forward = 0.050 | energy = 3.887 | steps = 97
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 16 | forward = -1.337 | energy = 2.229 | steps = 54
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 17 | forward = 13.844 | energy = 48.235 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 18 | forward = 38.400 | energy = 48.697 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 19 | forward = 40.998 | energy = 48.765 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 20 | forward = -0.100 | energy = 2.377 | steps = 59
#
# === PPO evaluation over 20 episodes (./quadruped_var1.xml) ===
# Average forward motion: 22.006
# Average energy spent:   33.560
# Loading PPO model from ppo_with_mlp.zip ...
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  1 | forward = 19.392 | energy = 45.699 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  2 | forward = 19.955 | energy = 45.891 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  3 | forward = 21.149 | energy = 45.799 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  4 | forward = 20.406 | energy = 45.428 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  5 | forward = 14.212 | energy = 45.071 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  6 | forward = 16.173 | energy = 45.121 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  7 | forward = 19.934 | energy = 45.427 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  8 | forward = 17.653 | energy = 45.175 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  9 | forward = 21.108 | energy = 45.429 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 10 | forward = 17.770 | energy = 45.420 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 11 | forward = 8.434 | energy = 25.607 | steps = 566
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 12 | forward = 20.591 | energy = 45.458 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 13 | forward = 19.043 | energy = 45.449 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 14 | forward = 16.324 | energy = 45.007 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 15 | forward = 21.251 | energy = 45.494 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 16 | forward = 16.199 | energy = 45.439 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 17 | forward = 19.727 | energy = 45.753 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 18 | forward = 22.747 | energy = 45.281 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 19 | forward = 21.902 | energy = 45.462 | steps = 995
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 20 | forward = 20.310 | energy = 45.231 | steps = 995
#
# === PPO evaluation over 20 episodes (./quadruped.xml) ===
# Average forward motion: 18.714
# Average energy spent:   44.432
# Loading PPO model from ppo_with_imitation_ppo.zip ...
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  1 | forward = 0.175 | energy = 4.350 | steps = 99
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  2 | forward = 0.431 | energy = 2.755 | steps = 61
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  3 | forward = 0.425 | energy = 2.895 | steps = 64
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  4 | forward = 0.152 | energy = 2.487 | steps = 61
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  5 | forward = 0.724 | energy = 2.934 | steps = 65
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  6 | forward = 0.756 | energy = 3.851 | steps = 85
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  7 | forward = 0.707 | energy = 4.252 | steps = 97
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  8 | forward = 0.291 | energy = 2.750 | steps = 66
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode  9 | forward = 0.526 | energy = 2.835 | steps = 62
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 10 | forward = 0.777 | energy = 4.064 | steps = 90
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 11 | forward = 0.201 | energy = 3.339 | steps = 81
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 12 | forward = 0.061 | energy = 2.328 | steps = 53
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 13 | forward = 0.480 | energy = 2.415 | steps = 60
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 14 | forward = 0.406 | energy = 3.465 | steps = 76
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 15 | forward = 0.556 | energy = 3.082 | steps = 66
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 16 | forward = 0.366 | energy = 2.844 | steps = 65
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 17 | forward = 0.546 | energy = 2.540 | steps = 62
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 18 | forward = 0.768 | energy = 3.974 | steps = 90
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 19 | forward = 0.687 | energy = 2.777 | steps = 61
# [Env timing] mujoco_dt=0.010000, frame_skip=5, env_dt=0.050000 sec
# Episode 20 | forward = 0.231 | energy = 2.873 | steps = 61
#
# === PPO evaluation over 20 episodes (./quadruped.xml) ===
# Average forward motion: 0.463
# Average energy spent:   3.141
#  Quadruped PPO Evaluation Summary
#
# Model                |  Avg Forward |   Avg Energy | Notes
# ------------------------------------------------------------------------
# Exploration-PPO      |      22.0056 |      33.5595 | baseline (explore_var)
# MLP-PPO              |      18.7139 |      44.4320 | baseline (mlp)
# Generative-PPO       |       0.4632 |       3.1406 | diffusion-guided

# %%
### Metrics Cycle Smoothness
import numpy as np
import Diffusion as diff


def summarize_over_rollouts(list_of_q, angle_dims=None, eps=1e-6):
    acc = []
    jerk = []
    acc_mean = []
    acc_norm = []
    acc_norm_mean = []
    jerk_mean = []
    jerk_norm = []
    jerk_norm_mean = []

    for q in list_of_q:
        q = np.asarray(q, dtype=np.float32)

        # differences
        dq = q[1:] - q[:-1]
        if angle_dims is not None:
            dq[:, angle_dims] = (dq[:, angle_dims] + np.pi) % (2*np.pi) - np.pi

        ddq = dq[1:] - dq[:-1]
        if angle_dims is not None:
            ddq[:, angle_dims] = (ddq[:, angle_dims] + np.pi) % (2*np.pi) - np.pi

        dddq = ddq[1:] - ddq[:-1]
        if angle_dims is not None:
            dddq[:, angle_dims] = (dddq[:, angle_dims] + np.pi) % (2*np.pi) - np.pi

        # Per joint RMS
        rms_vel  = np.sqrt(np.mean(dq**2, axis=0)) 
        rms_acc  = np.sqrt(np.mean(ddq**2, axis=0))  
        rms_jerk = np.sqrt(np.mean(dddq**2, axis=0))  

        acc.append(rms_acc)
        jerk.append(rms_jerk)

        acc_mean.append(float(rms_acc.mean()))
        jerk_mean.append(float(rms_jerk.mean()))


        # Amplitude normalized 
        rms_vel_mean = float(rms_vel.mean())
        
        acc_norm_joint = rms_acc / (rms_vel + eps)
        acc_norm.append(acc_norm_joint)
        acc_norm_mean.append(float(acc_norm_joint.mean()))

        jerk_norm_joint = rms_jerk / (rms_vel + eps)
        jerk_norm.append(jerk_norm_joint)
        jerk_norm_mean.append(float(rms_jerk.mean() / (rms_vel_mean + eps)))

    acc = np.stack(acc, axis=0)
    jerk = np.stack(jerk, axis=0)
    jerk_norm = np.stack(jerk_norm, axis=0)
    acc_norm = np.stack(acc_norm, axis=0)

    return {
        "accel_per_joint_mean": acc.mean(axis=0),
        "accel_per_joint_std":  acc.std(axis=0),
        "jerk_per_joint_mean":  jerk.mean(axis=0),
        "jerk_per_joint_std":   jerk.std(axis=0),
        "accel_global_mean": float(np.mean(acc_mean)),
        "accel_global_std":  float(np.std(acc_mean)),
        "jerk_global_mean":  float(np.mean(jerk_mean)),
        "jerk_global_std":   float(np.std(jerk_mean)),
        "accel_norm_per_joint_mean": acc_norm.mean(axis=0),
        "accel_norm_per_joint_std":  acc_norm.std(axis=0),
        "accel_norm_global_mean": float(np.mean(acc_norm_mean)),
        "accel_norm_global_std":  float(np.std(acc_norm_mean)),
        "jerk_norm_per_joint_mean": jerk_norm.mean(axis=0),
        "jerk_norm_per_joint_std":  jerk_norm.std(axis=0),
        "jerk_norm_global_mean": float(np.mean(jerk_norm_mean)),
        "jerk_norm_global_std":  float(np.std(jerk_norm_mean)),
    }

quad_morph = [
    0.141421, 0.282843,
    0.141421, 0.282843,
    0.141421, 0.282843,
    0.141421, 0.282843,
]

imitation_obs_indices = list(range(5, 13))

data = np.load("quadruped_var1p_trajectories.npz")
obs   = data["obs"]  
ep_id = data["ep_id"]
morph = data["morph"]  

morph_dim = morph.shape[1]
base_start = morph_dim + 2  
base_obs = obs[:, base_start:] 

# only the joint pose dims used for imitation/diffusion:
pose = base_obs[:, imitation_obs_indices].astype(np.float32)  # (T, D_target)

print("base_obs shape:", base_obs.shape)
print("pose shape:", pose.shape)

rollouts = []
for eid in np.unique(ep_id):
    ep_pose = pose[ep_id == eid]

    if ep_pose.shape[0] >= 200:
        rollouts.append(ep_pose[:200])

diff_model, meta, device = load_diffusion(
    weights_path="quadruped_morph_diffusion_weights.pt",
    traj_file="quadruped_morph_trajectories.npz",)

cycles = []
for i in range(10):
    seq = diff.sample_full_cycle_from_morph(
        diff_model=diff_model,
        meta=meta,
        morph_vec=quad_morph,
        cycle_steps=200,
        device=device,
    )
    cycles.append(np.asarray(seq, dtype=np.float32))

stats = summarize_over_rollouts(
    rollouts,
    angle_dims=np.arange(rollouts[0].shape[1]) )
print("var 1 ppo")
print("RMS accel:", stats["accel_global_mean"])
print("RMS jerk :", stats["jerk_global_mean"])
print("RMS norm accel:", stats["accel_global_mean"])
print("RMS nom jerk :", stats["jerk_global_mean"])



D = cycles[0].shape[1]
stats = summarize_over_rollouts(
    cycles,
     angle_dims=np.arange(D) )

print("generative diff")
print("RMS accel:", stats["accel_global_mean"])
print("RMS jerk :", stats["jerk_global_mean"])
print("RMS norm accel:", stats["accel_norm_global_mean"])
print("RMS norm jerk :", stats["jerk_norm_global_mean"])
# Out:
# base_obs shape: (42968, 87)
# pose shape: (42968, 8)
# Using device: cuda
# Loaded config from checkpoint:
#   traj_file : quadruped_morph_trajectories.npz
#   past_len  : 10
#   future_len: 200
#   n_steps   : 100
#   hidden    : 256
#   imitation_obs_indices: [5, 6, 7, 8, 9, 10, 11, 12]
# [QuadrupedDataset] obs_dim=97, morph_dim=8
# [QuadrupedDataset] target_dim=8
# [QuadrupedDataset] total samples possible=87182
# Reconstructed diffusion dims:
#   D_target (obs_dim) = 8
#   D_cond             = 88
# Loaded diffusion model.
# var 1 ppo
# RMS accel: 1.4629671573638916
# RMS jerk : 1.6638646125793457
# RMS norm accel: 1.4629671573638916
# RMS nom jerk : 1.6638646125793457
# generative diff
# RMS accel: 0.13566283732652665
# RMS jerk : 0.20317601263523102
# RMS norm accel: 1.0549116611480713
# RMS norm jerk : 1.546083688735962
