# %%
import torch
import snntorch
import morphSNN as morph
import Reinforcement as re
import numpy as np
import mujoco
import gymnasium as gym

# %%
from mujoco import viewer

model = mujoco.MjModel.from_xml_path("quadruped_var1.xml")

data = mujoco.MjData(model)

viewer.launch(model, data)

# %%
env = gym.make("Ant-v5", xml_file="../quadruped.xml")
model = env.unwrapped.model

print("Number of joints:", model.njnt)

for j in range(model.njnt):
    name = mujoco.mj_id2name(model, mujoco.mjtObj.mjOBJ_JOINT, j)
    qpos_adr = model.jnt_qposadr[j]  # index into data.qpos
    dof_adr = model.jnt_dofadr[j]    # index into data.qvel
    print(f"joint {j:2d} | name={name!r} | qpos index={qpos_adr} | dof index={dof_adr}")
# Out:
# Number of joints: 9
# joint  0 | name='root' | qpos index=0 | dof index=0
# joint  1 | name='hip_1' | qpos index=7 | dof index=6
# joint  2 | name='ankle_1' | qpos index=8 | dof index=7
# joint  3 | name='hip_2' | qpos index=9 | dof index=8
# joint  4 | name='ankle_2' | qpos index=10 | dof index=9
# joint  5 | name='hip_3' | qpos index=11 | dof index=10
# joint  6 | name='ankle_3' | qpos index=12 | dof index=11
# joint  7 | name='hip_4' | qpos index=13 | dof index=12
# joint  8 | name='ankle_4' | qpos index=14 | dof index=13

# %%
model = re.train_ppo_with_pose_template(
    run_name="quad_alif",
    pose_generator=None,
    morph_vec=var1_morph,
    xml_path="./quadruped_var1.xml"
    timesteps=2_000_000,
    parallel_envs=4,
    initial_learning_rate=3e-4
)
# Out:
#   Cell In[3], line 5
#     xml_path="./quadruped_var1.xml"
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
var1_morph = [
    0.141421, 0.282843,  # FR leg, FR ankle
    0.141421, 0.282843,  # FL leg, FL ankle
    0.141421, 0.282843,  # BL leg, BL ankle
    0.141421, 0.282843,  # BR leg, BR ankle
]

var2_morph = [
    0.141421, 0.16,  # FR leg, FR ankle
    0.141421, 0.16,  # FL leg, FL ankle
    0.141421, 0.282843,  # BL leg, BL ankle
    0.141421, 0.282843,  # BR leg, BR ankle
]

var3_morph = [
    0.141421, 0.17,  # FR leg, FR ankle
    0.141421, 0.17,  # FL leg, FL ankle
    0.16, 0.15,  # BL leg, BL ankle
    0.16, 0.15,  # BR leg, BR ankle
]

var4_morph = [
    0.16, 0.3,  # FR leg, FR ankle
    0.141421, 0.28,  # FL leg, FL ankle
    0.141421, 0.28,  # BL leg, BL ankle
    0.141421, 0.28,  # BR leg, BR ankle
]

morph_specs = [
   ("./quadruped_var1.xml", var1_morph),
   # ("./quadruped_var2.xml", var2_morph),
   #("./quadruped_var3.xml", var3_morph),
    #("./quadruped_var4.xml", var4_morph),
]

for i, (xml_path, morph_vec) in enumerate(morph_specs):
    run_name = f"quadrl_m{i+3}"  # e.g. "quad_var_m0", "quad_var_m1", ...

    print(f"\n=== Training policy for morph {i} ===")
    print("  xml_path:", xml_path)
    print("  morph_vec:", morph_vec)

    model = re.train_ppo_with_pose_template(
        run_name=run_name,
        pose_generator=None,  
        morph_vec=morph_vec,
        xml_path=xml_path,
        timesteps=2_000_000,
        parallel_envs=4,
        initial_learning_rate=3e-4 )
# Out:
# === Training policy for morph 0 ===
#   xml_path: ./quadruped_var1.xml
#   morph_vec: [0.141421, 0.282843, 0.141421, 0.282843, 0.141421, 0.282843, 0.141421, 0.282843]
# Logging to ./logs_quadrl_m3
# Using cuda device
# C:\Users\Lep\miniconda3\Lib\site-packages\stable_baselines3\common\policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
| imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.259 | phase_spd= 0.040 | var=unknown
# [env 1] ep_len=  61 | R_mean=-0.068 | fwd=-0.643 | vel=-2.120 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.246 | phase_spd= 0.049 | var=unknown
# [env 3] ep_len=  51 | R_mean=-0.028 | fwd=-0.217 | vel=-0.719 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.294 | phase_spd= 0.047 | var=unknown
# [env 0] ep_len=  84 | R_mean=-0.053 | fwd=-0.497 | vel=-1.674 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.179 | phase_spd= 0.046 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.3         |
# |    ep_rew_mean          | -4.39        |
# | time/                   |              |
# |    fps                  | 732          |
# |    iterations           | 3            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0061813868 |
# |    clip_fraction        | 0.0194       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.8        |
# |    explained_variance   | 0.00605      |
# |    learning_rate        | 0.000299     |
# |    loss                 | 0.03         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0121      |
# |    std                  | 1            |
# |    value_loss           | 0.528        |
# ------------------------------------------
# [env 1] ep_len=  76 | R_mean=-0.053 | fwd=-0.500 | vel=-1.631 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.197 | phase_spd= 0.044 | var=unknown
# [env 3] ep_len=  88 | R_mean=-0.019 | fwd=-0.149 | vel=-0.510 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.170 | phase_spd= 0.047 | var=unknown
# [env 0] ep_len=  70 | R_mean=-0.043 | fwd=-0.379 | vel=-1.275 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.214 | phase_spd= 0.043 | var=unknown
# [env 1] ep_len=  57 | R_mean=-0.048 | fwd=-0.416 | vel=-1.395 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.263 | phase_spd= 0.043 | var=unknown
# [env 3] ep_len=  64 | R_mean=-0.124 | fwd=-1.209 | vel=-4.010 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.234 | phase_spd= 0.046 | var=unknown
# [env 2] ep_len= 171 | R_mean=-0.031 | fwd=-0.289 | vel=-0.975 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.088 | phase_spd= 0.051 | var=unknown
# [env 3] ep_len=   2 | R_mean=-0.006 | fwd=-0.083 | vel=-0.164 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.000 | phase_spd= 0.071 | var=unknown
# [env 0] ep_len=  60 | R_mean=-0.084 | fwd=-0.807 | vel=-2.663 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.250 | phase_spd= 0.048 | var=unknown
# [env 1] ep_len=  62 | R_mean=-0.057 | fwd=-0.531 | vel=-1.779 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.242 | phase_spd= 0.043 | var=unknown
# [env 2] ep_len=  51 | R_mean=-0.209 | fwd=-2.168 | vel=-7.052 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.294 | phase_spd= 0.043 | var=unknown
# [env 0] ep_len=  80 | R_mean=-0.051 | fwd=-0.511 | vel=-1.720 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.188 | phase_spd= 0.046 | var=unknown
# [env 3] ep_len=  90 | R_mean=-0.030 | fwd=-0.280 | vel=-0.968 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.167 | phase_spd= 0.047 | var=unknown
# [env 2] ep_len=  62 | R_mean=-0.038 | fwd=-0.357 | vel=-1.183 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.242 | phase_spd= 0.043 | var=unknown
# [env 0] ep_len=  55 | R_mean=-0.054 | fwd=-0.523 | vel=-1.742 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.273 | phase_spd= 0.049 | var=unknown
# [env 1] ep_len= 123 | R_mean=-0.017 | fwd=-0.150 | vel=-0.534 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.122 | phase_spd= 0.048 | var=unknown
# [env 2] ep_len=  68 | R_mean=-0.053 | fwd=-0.518 | vel=-1.751 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.221 | phase_spd= 0.044 | var=unknown
# [env 0] ep_len=  55 | R_mean=-0.030 | fwd=-0.265 | vel=-0.860 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.273 | phase_spd= 0.049 | var=unknown
# [env 1] ep_len=  72 | R_mean=-0.077 | fwd=-0.793 | vel=-2.583 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.208 | phase_spd= 0.047 | var=unknown
# [env 3] ep_len= 141 | R_mean=-0.021 | fwd=-0.195 | vel=-0.689 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.106 | phase_spd= 0.046 | var=unknown
# [env 2] ep_len=  81 | R_mean=-0.024 | fwd=-0.220 | vel=-0.727 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.185 | phase_spd= 0.042 | var=unknown
# [env 1] ep_len=  82 | R_mean=-0.040 | fwd=-0.389 | vel=-1.271 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.183 | phase_spd= 0.047 | var=unknown
# [env 0] ep_len= 145 | R_mean=-0.043 | fwd=-0.443 | vel=-1.469 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.103 | phase_spd= 0.045 | var=unknown
# [env 2] ep_len=  78 | R_mean=-0.039 | fwd=-0.342 | vel=-1.274 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.192 | phase_spd= 0.050 | var=unknown
# [sched] imitation_w=0.008, energy_w=0.00103
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89          |
# |    ep_rew_mean          | -4.22       |
# | time/                   |             |
# |    fps                  | 718         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007160922 |
# |    clip_fraction        | 0.027       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.8       |
# |    explained_variance   | -0.0182     |
# |    learning_rate        | 0.000299    |
# |    loss                 | -0.0408     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 1           |
# |    value_loss           | 0.302       |
# -----------------------------------------
# [env 2] ep_len= 106 | R_mean=-0.051 | fwd=-0.504 | vel=-1.685 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.142 | phase_spd= 0.048 | var=unknown
# [env 1] ep_
| imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.214 | phase_spd= 0.050 | var=unknown
# [env 1] ep_len=  77 | R_mean=-0.036 | fwd=-0.305 | vel=-1.060 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.195 | phase_spd= 0.050 | var=unknown
# [env 3] ep_len= 100 | R_mean=-0.023 | fwd=-0.186 | vel=-0.636 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.150 | phase_spd= 0.043 | var=unknown
# [env 2] ep_len= 200 | R_mean=-0.032 | fwd=-0.299 | vel=-1.012 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.075 | phase_spd= 0.039 | var=unknown
# [env 0] ep_len=  80 | R_mean=-0.033 | fwd=-0.280 | vel=-0.948 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.188 | phase_spd= 0.051 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 98.1         |
# |    ep_rew_mean          | -3.79        |
# | time/                   |              |
# |    fps                  | 693          |
# |    iterations           | 6            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0072810017 |
# |    clip_fraction        | 0.0474       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.8        |
# |    explained_variance   | -0.213       |
# |    learning_rate        | 0.000298     |
# |    loss                 | -0.0972      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0168      |
# |    std                  | 0.999        |
# |    value_loss           | 0.131        |
# ------------------------------------------
# [env 3] ep_len=  56 | R_mean=-0.056 | fwd=-0.483 | vel=-1.638 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.268 | phase_spd= 0.044 | var=unknown
# [env 0] ep_len=  56 | R_mean=-0.022 | fwd=-0.145 | vel=-0.517 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.268 | phase_spd= 0.048 | var=unknown
# [env 3] ep_len=  65 | R_mean=-0.022 | fwd=-0.158 | vel=-0.555 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.231 | phase_spd= 0.049 | var=unknown
# [env 1] ep_len= 145 | R_mean=-0.022 | fwd=-0.180 | vel=-0.664 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.103 | phase_spd= 0.047 | var=unknown
# [env 1] ep_len=  69 | R_mean=-0.032 | fwd=-0.257 | vel=-0.889 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.217 | phase_spd= 0.050 | var=unknown
# [env 3] ep_len=  76 | R_mean=-0.035 | fwd=-0.295 | vel=-0.994 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.197 | phase_spd= 0.049 | var=unknown
# [env 0] ep_len= 165 | R_mean=-0.018 | fwd=-0.149 | vel=-0.510 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.091 | phase_spd= 0.048 | var=unknown
# [env 2] ep_len= 279 | R_mean=-0.023 | fwd=-0.206 | vel=-0.701 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.054 | phase_spd= 0.048 | var=unknown
# [env 1] ep_len=  94 | R_mean=-0.022 | fwd=-0.173 | vel=-0.600 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.160 | phase_spd= 0.049 | var=unknown
# [env 3] ep_len= 114 | R_mean=-0.047 | fwd=-0.415 | vel=-1.407 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.132 | phase_spd= 0.043 | var=unknown
# [env 2] ep_len=  57 | R_mean=-0.038 | fwd=-0.305 | vel=-1.029 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.263 | phase_spd= 0.045 | var=unknown
# [env 3] ep_len=  68 | R_mean=-0.016 | fwd=-0.094 | vel=-0.353 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.221 | phase_spd= 0.047 | var=unknown
# [env 2] ep_len=  69 | R_mean=-0.033 | fwd=-0.261 | vel=-0.893 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.217 | phase_spd= 0.042 | var=unknown
# [env 0] ep_len= 188 | R_mean=-0.024 | fwd=-0.212 | vel=-0.727 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.080 | phase_spd= 0.045 | var=unknown
# [env 1] ep_len= 185 | R_mean=-0.028 | fwd=-0.246 | vel=-0.844 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.081 | phase_spd= 0.047 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 99.7         |
# |    ep_rew_mean          | -3.5         |
# | time/                   |              |
# |    fps                  | 682          |
# |    iterations           | 7            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0043829205 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.8        |
# |    explained_variance   | 0.0265       |
# |    learning_rate        | 0.000298     |
# |    loss                 | -0.055       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0116      |
# |    std                  | 1            |
# |    value_loss           | 0.175        |
# ------------------------------------------
# [env 1] ep_len= 105 | R_mean=-0.034 | fwd=-0.285 | vel=-0.964 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.143 | phase_spd= 0.047 | var=unknown
# [env 3] ep_len= 241 | R_mean=-0.019 | fwd=-0.159 | vel=-0.575 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.062 | phase_spd= 0.049 | var=unknown
# [env 0] ep_len= 218 | R_mean=-0.023 | fwd=-0.196 | vel=-0.667 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.069 | phase_spd= 0.046 | var=unknown
# [env 3] ep_len=  69 | R_mean=-0.095 | fwd=-0.847 | vel=-2.823 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.217 | phase_spd= 0.049 | var=unknown
# [env 0] ep_len=  57 | R_mean=-0.037 | fwd=-0.283 | vel=-0.968 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.263 | phase_spd= 0.043 | var=unknown
# [env 1] ep_len= 161 | R_mean=-0.011 | fwd=-0.074 | vel=-0.282 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.093 | phase_spd= 0.044 | var=unknown
# [env 3] ep_len= 113 | R_mean=-0.050 | fwd=-0.444 | vel=-1.475 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.133 | phase_spd= 0.041 | var=unknown
# [env 1] ep_len= 149 | R_mean=-0.023 | fwd=-0.193 | vel=-0.669 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.101 | phase_spd= 0.045 | var=unknown
# [env 2] ep_len= 486 | R_mean=-0.014 | fwd=-0.123 | vel=-0.446 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.031 | phase_spd= 0.046 | var=unknown
# [env 3] ep_len=  97 | R_mean=-0.036 | fwd=-0.296 | vel=-1.010 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.155 | phase_spd= 0.049 | var=unknown
# [env 1] ep_len=  95 | R_mean=-0.043 | fwd=-0.366 | vel=-1.203 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.158 | phase_spd= 0.047 | var=unknown
# [env 0] ep_len= 292 | R_mean=-0.012 | fwd=-0.091 | vel=-0.342 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.051 | phase_spd= 0.045 | var=unknown
# [sched] imitation_w=0.018, energy_w=0.00107
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 111         |
# |    ep_rew_mean          | -3.62       |
# | time/                   |             |
# |    fps                  | 685         |
# |    iterations           | 8           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008362551 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.8       |
# |    explained_variance   | -0.37       |
# |    learning_rate        | 0.000298    |
# |    loss                 | -0.104      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0179     |
# |    std                  | 1           |
# |    value_loss           | 0.133       |
# -----------------------------------------
# [env 0] ep_len=  65 | R_mean=-0.036 | fwd=-0.282 | vel=-0.934 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.231 | phase_spd= 0.047 | var=unknown
# [env 3] ep_len= 232 | R_mean=-0.027 | fwd=-0.227 | vel=-0.784 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.065 | phase_spd= 0.047 | var=unknown
# [env 2] ep_len= 288 | R_mean=-0.011 | fwd=-0.083 | vel=-0.314 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.052 | phase_spd= 0.045 | var=unknown
# [env 3] ep_len=  69 | R_mean=-0.069 | fwd=-0.598 | vel=-1.969 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.217 | phase_spd= 0.047 | var=unknown
# [env 2] ep_len= 106 | R_mean=-0.025 | fwd=-0.197 | vel=-0.682 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.142 | phase_spd= 0.044 | var=unknown
# [env 0] ep_len= 217 | R_mean=-0.021 | fwd=-0.169 | vel=-0.593 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.069 | phase_spd= 0.046 | var=unknown
# [env 1] ep_len= 352 | R_mean=-0.010 | fwd=-0.074 | vel=-0.283 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.043 | phase_spd= 0.047 | var=unknown
# [env 2] ep_len=  81 | R_mean=-0.046 | fwd=-0.374 | vel=-1.260 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.185 | phase_spd= 0.044 | var=unknown
# [env 3] ep_len= 182 | R_mean=-0.023 | fwd=-0.193 | vel=-0.654 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.082 | phase_spd= 0.048 | var=unknown
# [env 1] ep_len=  61 | R_mean=-0.031 | fwd=-0.222 | vel=-0.774 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.246 | phase_spd= 0.045 | var=unknown
# [env 3] ep_len=  59 | R_mean=-0.022 | fwd=-0.140 | vel=-0.490 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.254 | phase_spd= 0.049 | var=unknown
# [env 3] ep_len=  91 | R_mean=-0.017 | fwd=-0.109 | vel=-0.421 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.165 | phase_spd= 0.043 | var=unknown
# [env 0] ep_len= 252 | R_mean=-0.011 | fwd=-0.073 | vel=-0.288 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.060 | phase_spd= 0.045 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 121          |
# |    ep_rew_mean          | -3.61        |
# | time/                   |              |
# |    fps                  | 678          |
# |    iterations           | 9            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0070257215 |
# |    clip_fraction        | 0.0322       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.8        |
# |    explained_variance   | -0.106       |
# |    learning_rate        | 0.000298     |
# |    loss                 | -0.0891      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0156      |
# |    std                  | 0.997        |
# |    value_loss           | 0.151        |
# ------------------------------------------
# [env 1] ep_len= 186 | R_mean=-0.026 | fwd=-0.209 | vel=-0.722 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.081 | phase_spd= 0.046 | var=unknown
# [env 3] ep_len=  59 | R_mean=-0.082 | fwd=-0.692 | vel=-2.283 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.254 | phase_spd= 0.044 | var=unknown
# [env 0] ep_len= 195 | R_mean=-0.020 | fwd=-0.157 | vel=-0.551 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.077 | phase_spd= 0.045 | var=unknown
# [env 1] ep_len= 195 | R_mean=-0.016 | fwd=-0.120 | vel=-0.431 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.077 | phase_spd= 0.043 | var=unknown
# [env 2] ep_len= 430 | R_mean=-0.011 | fwd=-0.087 | vel=-0.323 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.035 | phase_spd= 0.045 | var=unknown
# [env 0] ep_len=  81 | R_mean=-0.024 | fwd=-0.166 | vel=-0.606 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.185 | phase_spd= 0.047 | var=unknown
# [env 2] ep_len=  64 | R_mean=-0.050 | fwd=-0.387 | vel=-1.302 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.234 | phase_spd= 0.045 | var=unknown
# [env 1] ep_len= 122 | R_mean=-0.016 | fwd=-0.109 | vel=-0.400 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.123 | phase_spd= 0.046 | var=unknown
# [env 3] ep_len= 332 | R_mean=-0.012 | fwd=-0.091 | vel=-0.347 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.045 | phase_spd= 0.046 | var=unknown
# [env 2] ep_len=  74 | R_mean=-0.040 | fwd=-0.299 | vel=-1.064 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.203 | phase_spd= 0.044 | var=unknown
# [env 2] ep_len=  70 | R_mean=-0.016 | fwd=-0.076 | vel=-0.320 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.214 | phase_spd= 0.040 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 131          |
# |    ep_rew_mean          | -3.49        |
# | time/                   |              |
# |    fps                  | 677          |
# |    iterations           | 10           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0045515187 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.8        |
# |    explained_variance   | -0.0274      |
# |    learning_rate        | 0.000297     |
# |    loss                 | -0.0996      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0123      |
# |    std                  | 1            |
# |    value_loss           | 0.13         |
# ------------------------------------------
# [env 3] ep_len= 173 | R_mean=-0.021 | fwd=-0.162 | vel=-0.572 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.087 | phase_spd= 0.042 | var=unknown
# [env 0] ep_len= 283 | R_mean=-0.018 | fwd=-0.137 | vel=-0.499 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.053 | phase_spd= 0.045 | var=unknown
# [env 0] ep_len= 202 | R_mean=-0.012 | fwd=-0.085 | vel=-0.316 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.074 | phase_spd= 0.044 | var=unknown
# [env 1] ep_len= 414 | R_mean=-0.013 | fwd=-0.096 | vel=-0.349 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.036 | phase_spd= 0.043 | var=unknown
# [env 3] ep_len= 270 | R_mean=-0.010 | fwd=-0.060 | vel=-0.255 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.056 | phase_spd= 0.043 | var=unknown
# [env 2] ep_len= 364 | R_mean=-0.010 | fwd=-0.073 | vel=-0.283 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.041 | phase_spd= 0.043 | var=unknown
# [env 0] ep_len=  94 | R_mean=-0.009 | fwd=-0.032 | vel=-0.162 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.160 | phase_spd= 0.044 | var=unknown
# [env 2] ep_len= 137 | R_mean=-0.030 | fwd=-0.229 | vel=-0.786 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.109 | phase_spd= 0.042 | var=unknown
# [env 0] ep_len= 143 | R_mean=-0.024 | fwd=-0.180 | vel=-0.641 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.105 | phase_spd= 0.044 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 145          |
# |    ep_rew_mean          | -3.52        |
# | time/                   |              |
# |    fps                  | 675          |
# |    iterations           | 11           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0070731733 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.8        |
# |    explained_variance   | -0.246       |
# |    learning_rate        | 0.000297     |
# |    loss                 | -0.114       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0159      |
# |    std                  | 1.01         |
# |    value_loss           | 0.0836       |
# ------------------------------------------
# [env 0] ep_len=  67 | R_mean=-0.018 | fwd=-0.094 | vel=-0.343 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.224 | phase_spd= 0.047 | var=unknown
# [env 3] ep_len= 279 | R_mean=-0.010 | fwd=-0.067 | vel=-0.247 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.054 | phase_spd= 0.046 | var=unknown
# [env 0] ep_len= 102 | R_mean=-0.022 | fwd=-0.151 | vel=-0.525 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.147 | phase_spd= 0.044 | var=unknown
# [env 2] ep_len= 220 | R_mean=-0.011 | fwd=-0.071 | vel=-0.277 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.068 | phase_spd= 0.046 | var=unknown
# [env 0] ep_len=  60 | R_mean=-0.045 | fwd=-0.326 | vel=-1.074 | imitat= 0.000 | alive= 0.100 | energy_p= 0.004 | fail= 0.250 | phase_spd= 0.045 | var=unknown
# [env 2] ep_len=  56 | R_mean=-0.048 | fwd=-0.348 | vel=-1.155 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.268 | phase_spd= 0.047 | var=unknown
# [env 3] ep_len= 173 | R_mean=-0.013 | fwd=-0.085 | vel=-0.314 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.087 | phase_spd= 0.040 | var=unknown
# [env 3] ep_len=   2 | R_mean= 0.018 | fwd= 0.221 | vel= 0.343 | imitat= 0.000 | alive= 0.100 | energy_p= 0.006 | fail= 0.000 | phase_spd= 0.077 | var=unknown
# [env 2] ep_len=  65 | R_mean=-0.046 | fwd=-0.335 | vel=-1.141 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.231 | phase_spd= 0.044 | var=unknown
# [env 0] ep_len=  79 | R_mean=-0.019 | fwd=-0.098 | vel=-0.429 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.190 | phase_spd= 0.042 | var=unknown
# [env 2] ep_len= 135 | R_mean=-0.024 | fwd=-0.169 | vel=-0.613 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.111 | phase_spd= 0.041 | var=unknown
# [env 2] ep_len=  64 | R_mean=-0.051 | fwd=-0.373 | vel=-1.269 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.234 | phase_spd= 0.045 | var=unknown
# [env 3] ep_len= 239 | R_mean=-0.013 | fwd=-0.082 | vel=-0.332 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.063 | phase_spd= 0.046 | var=unknown
# [env 0] ep_len= 209 | R_mean=-0.014 | fwd=-0.091 | vel=-0.359 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.072 | phase_spd= 0.042 | var=unknown
# [env 1] ep_len= 779 | R_mean=-0.008 | fwd=-0.055 | vel=-0.220 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.019 | phase_spd= 0.045 | var=unknown
# [sched] imitation_w=0.028, energy_w=0.00111
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 151          |
# |    ep_rew_mean          | -3.37        |
# | time/                   |              |
# |    fps                  | 670          |
# |    iterations           | 12           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0071970136 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.8        |
# |    explained_variance   | -0.244       |
# |    learning_rate        | 0.000297     |
# |    loss                 | -0.142       |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0187      |
# |    std                  | 1.01         |
# |    value_loss           | 0.0637       |
# ------------------------------------------
# [env 2] ep_len= 139 | R_mean=-0.026 | fwd=-0.180 | vel=-0.658 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.108 | phase_spd= 0.042 | var=unknown
# [env 3] ep_len= 220 | R_mean=-0.015 | fwd=-0.099 | vel=-0.364 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.068 | phase_spd= 0.044 | var=unknown
# [env 1] ep_len= 196 | R_mean=-0.022 | fwd=-0.162 | vel=-0.571 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.077 | phase_spd= 0.042 | var=unknown
# [env 2] ep_len= 199 | R_mean=-0.016 | fwd=-0.106 | vel=-0.402 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.075 | phase_spd= 0.048 | var=unknown
# [env 1] ep_len= 102 | R_mean=-0.032 | fwd=-0.223 | vel=-0.788 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.147 | phase_spd= 0.043 | var=unknown
# [env 1] ep_len=  94 | R_mean=-0.027 | fwd=-0.179 | vel=-0.634 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.160 | phase_spd= 0.050 | var=unknown
# [env 0] ep_len= 452 | R_mean=-0.012 | fwd=-0.091 | vel=-0.324 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.033 | phase_spd= 0.044 | var=unknown
# [env 3] ep_len= 235 | R_mean=-0.011 | fwd=-0.070 | vel=-0.264 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.064 | phase_spd= 0.042 | var=unknown
# [env 1] ep_len= 123 | R_mean=-0.019 | fwd=-0.120 | vel=-0.438 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.122 | phase_spd= 0.042 | var=unknown
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | -3.41       |
# | time/                   |             |
# |    fps                  | 674         |
# |    iterations           | 13          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.006071493 |
# |    clip_fraction        | 0.0244      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.8       |
# |    explained_variance   | -0.00295    |
# |    learning_rate        | 0.000296    |
# |    loss                 | -0.12       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 1.01        |
# |    value_loss           | 0.0744      |
# -----------------------------------------
# [env 3] ep_len= 172 | R_mean=-0.004 | fwd=-0.004 | vel=-0.065 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.087 | phase_spd= 0.040 | var=unknown
# [env 0] ep_len= 176 | R_mean=-0.009 | fwd=-0.050 | vel=-0.201 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.085 | phase_spd= 0.048 | var=unknown
# [env 0] ep_len=  73 | R_mean=-0.022 | fwd=-0.125 | vel=-0.453 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.205 | phase_spd= 0.047 | var=unknown
# [env 2] ep_len= 391 | R_mean=-0.010 | fwd=-0.069 | vel=-0.263 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.038 | phase_spd= 0.044 | var=unknown
# [env 0] ep_len=  66 | R_mean=-0.046 | fwd=-0.304 | vel=-1.096 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.227 | phase_spd= 0.041 | var=unknown
# [env 3] ep_len= 204 | R_mean=-0.019 | fwd=-0.127 | vel=-0.466 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.074 | phase_spd= 0.043 | var=unknown
# [env 1] ep_len= 301 | R_mean=-0.014 | fwd=-0.103 | vel=-0.364 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.050 | phase_spd= 0.044 | var=unknown
# [env 2] ep_len= 147 | R_mean=-0.026 | fwd=-0.179 | vel=-0.637 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.102 | phase_spd= 0.045 | var=unknown
# [env 0] ep_len= 223 | R_mean=-0.014 | fwd=-0.092 | vel=-0.338 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.067 | phase_spd= 0.043 | var=unknown
# [env 2] ep_len= 156 | R_mean=-0.015 | fwd=-0.089 | vel=-0.341 | imitat= 0.000 | alive= 0.100 | energy_p= 0.005 | fail= 0.096 | phase_spd= 0.043 | var=unknown
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 165        |
# |    ep_rew_mean          | -3.28      |
# | time/                   |            |
# |    fps                  | 666        |
# |    iterations           | 14         |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.00788436 |
# |    clip_fraction        | 0.0453     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.8      |
# |    explained_variance   | -0.0779    |
# |    learning_rate        | 0.000296   |
# |    loss                 | -0.131     |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0188    |
# |    std                  | 1.01       |
# ...
# |    entropy_loss         | -16.8       |
# |    explained_variance   | 0.205       |
# |    learning_rate        | 3e-05       |
# |    loss                 | -0.0153     |
# |    n_updates            | 9640        |
# |    policy_gradient_loss | -0.00615    |
# |    std                  | 1.98        |
# |    value_loss           | 0.358       |
# -----------------------------------------
# [env 1] ep_len= 995 | R_mean= 0.031 | fwd= 0.426 | vel= 0.565 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.040 | var=unknown
# [env 0] ep_len= 995 | R_mean= 0.029 | fwd= 0.399 | vel= 0.524 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.041 | var=unknown
# [env 1] ep_len= 402 | R_mean=-0.034 | fwd=-0.157 | vel=-0.951 | imitat= 0.000 | alive= 0.100 | energy_p= 0.047 | fail= 0.037 | phase_spd= 0.038 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 989          |
# |    ep_rew_mean          | 30           |
# | time/                   |              |
# |    fps                  | 631          |
# |    iterations           | 966          |
# |    time_elapsed         | 3133         |
# |    total_timesteps      | 1978368      |
# | train/                  |              |
# |    approx_kl            | 0.0031128926 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -16.8        |
# |    explained_variance   | 0.0511       |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.111       |
# |    n_updates            | 9650         |
# |    policy_gradient_loss | -0.00624     |
# |    std                  | 1.98         |
# |    value_loss           | 0.37         |
# ------------------------------------------
# [env 2] ep_len= 995 | R_mean= 0.031 | fwd= 0.430 | vel= 0.559 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.041 | var=unknown
# [env 3] ep_len= 995 | R_mean= 0.029 | fwd= 0.394 | vel= 0.525 | imitat= 0.000 | alive= 0.100 | energy_p= 0.047 | fail= 0.000 | phase_spd= 0.042 | var=unknown
# [env 0] ep_len= 995 | R_mean= 0.030 | fwd= 0.409 | vel= 0.539 | imitat= 0.000 | alive= 0.100 | energy_p= 0.049 | fail= 0.000 | phase_spd= 0.043 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 989          |
# |    ep_rew_mean          | 30           |
# | time/                   |              |
# |    fps                  | 631          |
# |    iterations           | 967          |
# |    time_elapsed         | 3136         |
# |    total_timesteps      | 1980416      |
# | train/                  |              |
# |    approx_kl            | 0.0041300915 |
# |    clip_fraction        | 0.0275       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -16.8        |
# |    explained_variance   | 0.61         |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.247        |
# |    n_updates            | 9660         |
# |    policy_gradient_loss | -0.0075      |
# |    std                  | 1.98         |
# |    value_loss           | 0.77         |
# ------------------------------------------
# [env 1] ep_len= 995 | R_mean= 0.030 | fwd= 0.416 | vel= 0.547 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.041 | var=unknown
# [sched] imitation_w=1.000, energy_w=0.00700
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 989          |
# |    ep_rew_mean          | 29.9         |
# | time/                   |              |
# |    fps                  | 631          |
# |    iterations           | 968          |
# |    time_elapsed         | 3139         |
# |    total_timesteps      | 1982464      |
# | train/                  |              |
# |    approx_kl            | 0.0035310448 |
# |    clip_fraction        | 0.0261       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -16.8        |
# |    explained_variance   | -0.0625      |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.075       |
# |    n_updates            | 9670         |
# |    policy_gradient_loss | -0.0055      |
# |    std                  | 1.98         |
# |    value_loss           | 0.492        |
# ------------------------------------------
# [env 2] ep_len= 895 | R_mean= 0.022 | fwd= 0.319 | vel= 0.397 | imitat= 0.000 | alive= 0.100 | energy_p= 0.047 | fail= 0.017 | phase_spd= 0.042 | var=unknown
# [env 3] ep_len= 995 | R_mean= 0.030 | fwd= 0.407 | vel= 0.539 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.040 | var=unknown
# [env 0] ep_len= 995 | R_mean= 0.030 | fwd= 0.407 | vel= 0.544 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.044 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 988          |
# |    ep_rew_mean          | 29.8         |
# | time/                   |              |
# |    fps                  | 631          |
# |    iterations           | 969          |
# |    time_elapsed         | 3142         |
# |    total_timesteps      | 1984512      |
# | train/                  |              |
# |    approx_kl            | 0.0035706807 |
# |    clip_fraction        | 0.0261       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -16.8        |
# |    explained_variance   | 0.413        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.116       |
# |    n_updates            | 9680         |
# |    policy_gradient_loss | -0.00595     |
# |    std                  | 1.98         |
# |    value_loss           | 0.192        |
# ------------------------------------------
# [env 1] ep_len= 995 | R_mean= 0.030 | fwd= 0.414 | vel= 0.553 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.041 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 988          |
# |    ep_rew_mean          | 29.7         |
# | time/                   |              |
# |    fps                  | 631          |
# |    iterations           | 970          |
# |    time_elapsed         | 3145         |
# |    total_timesteps      | 1986560      |
# | train/                  |              |
# |    approx_kl            | 0.0029341793 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -16.8        |
# |    explained_variance   | 0.355        |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.0237      |
# |    n_updates            | 9690         |
# |    policy_gradient_loss | -0.00657     |
# |    std                  | 1.98         |
# |    value_loss           | 0.387        |
# ------------------------------------------
# [env 2] ep_len= 995 | R_mean= 0.029 | fwd= 0.395 | vel= 0.520 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.040 | var=unknown
# [env 3] ep_len= 995 | R_mean= 0.030 | fwd= 0.422 | vel= 0.553 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.042 | var=unknown
# [env 0] ep_len= 995 | R_mean= 0.031 | fwd= 0.428 | vel= 0.572 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.041 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 988          |
# |    ep_rew_mean          | 29.7         |
# | time/                   |              |
# |    fps                  | 631          |
# |    iterations           | 971          |
# |    time_elapsed         | 3148         |
# |    total_timesteps      | 1988608      |
# | train/                  |              |
# |    approx_kl            | 0.0028999033 |
# |    clip_fraction        | 0.0206       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -16.8        |
# |    explained_variance   | 0.0189       |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.00372     |
# |    n_updates            | 9700         |
# |    policy_gradient_loss | -0.00524     |
# |    std                  | 1.98         |
# |    value_loss           | 0.194        |
# ------------------------------------------
# [env 1] ep_len= 995 | R_mean= 0.029 | fwd= 0.400 | vel= 0.535 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.041 | var=unknown
# [sched] imitation_w=1.000, energy_w=0.00700
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 988          |
# |    ep_rew_mean          | 29.7         |
# | time/                   |              |
# |    fps                  | 631          |
# |    iterations           | 972          |
# |    time_elapsed         | 3151         |
# |    total_timesteps      | 1990656      |
# | train/                  |              |
# |    approx_kl            | 0.0027376194 |
# |    clip_fraction        | 0.0181       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -16.8        |
# |    explained_variance   | 0.0447       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.14         |
# |    n_updates            | 9710         |
# |    policy_gradient_loss | -0.005       |
# |    std                  | 1.98         |
# |    value_loss           | 0.489        |
# ------------------------------------------
# [env 2] ep_len= 995 | R_mean= 0.031 | fwd= 0.428 | vel= 0.558 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.043 | var=unknown
# [env 3] ep_len= 995 | R_mean= 0.029 | fwd= 0.389 | vel= 0.525 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.042 | var=unknown
# [env 0] ep_len= 995 | R_mean= 0.030 | fwd= 0.409 | vel= 0.542 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.041 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 988          |
# |    ep_rew_mean          | 29.7         |
# | time/                   |              |
# |    fps                  | 631          |
# |    iterations           | 973          |
# |    time_elapsed         | 3154         |
# |    total_timesteps      | 1992704      |
# | train/                  |              |
# |    approx_kl            | 0.0025714517 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -16.8        |
# |    explained_variance   | 0.0255       |
# |    learning_rate        | 3e-05        |
# |    loss                 | -0.156       |
# |    n_updates            | 9720         |
# |    policy_gradient_loss | -0.00604     |
# |    std                  | 1.98         |
# |    value_loss           | 0.169        |
# ------------------------------------------
# [env 1] ep_len= 995 | R_mean= 0.033 | fwd= 0.447 | vel= 0.595 | imitat= 0.000 | alive= 0.100 | energy_p= 0.049 | fail= 0.000 | phase_spd= 0.043 | var=unknown
# [env 3] ep_len= 868 | R_mean= 0.025 | fwd= 0.364 | vel= 0.446 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.017 | phase_spd= 0.041 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 987          |
# |    ep_rew_mean          | 29.6         |
# | time/                   |              |
# |    fps                  | 631          |
# |    iterations           | 974          |
# |    time_elapsed         | 3157         |
# |    total_timesteps      | 1994752      |
# | train/                  |              |
# |    approx_kl            | 0.0024645394 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -16.8        |
# |    explained_variance   | 0.00346      |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.0574       |
# |    n_updates            | 9730         |
# |    policy_gradient_loss | -0.00398     |
# |    std                  | 1.98         |
# |    value_loss           | 0.482        |
# ------------------------------------------
# [env 2] ep_len= 995 | R_mean= 0.032 | fwd= 0.446 | vel= 0.580 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.042 | var=unknown
# [env 0] ep_len= 995 | R_mean= 0.031 | fwd= 0.434 | vel= 0.574 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.042 | var=unknown
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 987         |
# |    ep_rew_mean          | 29.6        |
# | time/                   |             |
# |    fps                  | 631         |
# |    iterations           | 975         |
# |    time_elapsed         | 3160        |
# |    total_timesteps      | 1996800     |
# | train/                  |             |
# |    approx_kl            | 0.002810303 |
# |    clip_fraction        | 0.0208      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -16.8       |
# |    explained_variance   | 0.0919      |
# |    learning_rate        | 3e-05       |
# |    loss                 | -0.124      |
# |    n_updates            | 9740        |
# |    policy_gradient_loss | -0.00758    |
# |    std                  | 1.98        |
# |    value_loss           | 0.264       |
# -----------------------------------------
# [env 1] ep_len= 995 | R_mean= 0.031 | fwd= 0.429 | vel= 0.570 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.041 | var=unknown
# [env 3] ep_len= 995 | R_mean= 0.029 | fwd= 0.395 | vel= 0.530 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.040 | var=unknown
# [env 2] ep_len= 995 | R_mean= 0.031 | fwd= 0.428 | vel= 0.567 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.042 | var=unknown
# [sched] imitation_w=1.000, energy_w=0.00700
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 987          |
# |    ep_rew_mean          | 29.6         |
# | time/                   |              |
# |    fps                  | 631          |
# |    iterations           | 976          |
# |    time_elapsed         | 3163         |
# |    total_timesteps      | 1998848      |
# | train/                  |              |
# |    approx_kl            | 0.0028338998 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -16.8        |
# |    explained_variance   | -0.0565      |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.0847       |
# |    n_updates            | 9750         |
# |    policy_gradient_loss | -0.00513     |
# |    std                  | 1.98         |
# |    value_loss           | 0.369        |
# ------------------------------------------
# [env 0] ep_len= 995 | R_mean= 0.028 | fwd= 0.385 | vel= 0.521 | imitat= 0.000 | alive= 0.100 | energy_p= 0.048 | fail= 0.000 | phase_spd= 0.041 | var=unknown
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 987          |
# |    ep_rew_mean          | 29.6         |
# | time/                   |              |
# |    fps                  | 631          |
# |    iterations           | 977          |
# |    time_elapsed         | 3166         |
# |    total_timesteps      | 2000896      |
# | train/                  |              |
# |    approx_kl            | 0.0031261127 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -16.8        |
# |    explained_variance   | -0.115       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.0216       |
# |    n_updates            | 9760         |
# |    policy_gradient_loss | -0.00546     |
# |    std                  | 1.98         |
# |    value_loss           | 0.498        |
# ------------------------------------------
# Training complete for quadrl_m3

# %%
##### Train Diffusion ####

import numpy as np
from Reinforcement import collect_quadruped_morph_trajectories
from Diffusion import train_diffusion
from Diffusion import QuadrupedMorphDiffusionDataset


var1_morph = [
    0.2, 0.25,  # FR leg, FR ankle
    0.2, 0.25,  # FL leg, FL ankle
    0.141421, 0.3,  # BL leg, BL ankle
    0.141421, 0.3,  # BR leg, BR ankle
]

var2_morph = [
    0.141421, 0.16,  # FR leg, FR ankle
    0.141421, 0.16,  # FL leg, FL ankle
    0.141421, 0.282843,  # BL leg, BL ankle
    0.141421, 0.282843,  # BR leg, BR ankle
]

var3_morph = [
    0.141421, 0.17,  # FR leg, FR ankle
    0.141421, 0.17,  # FL leg, FL ankle
    0.16, 0.15,  # BL leg, BL ankle
    0.16, 0.15,  # BR leg, BR ankle
]

var4_morph = [
    0.16, 0.3,  # FR leg, FR ankle
    0.141421, 0.28,  # FL leg, FL ankle
    0.141421, 0.28,  # BL leg, BL ankle
    0.141421, 0.28,  # BR leg, BR ankle
]

morph_specs = [
    ("./quadruped_var1.xml", var1_morph),
    ("./quadruped_var2.xml", var2_morph),
    ("./quadruped_var3.xml", var3_morph),
    ("./quadruped_var4.xml", var4_morph),
]


ppo_path1 = "quadrl_m0_ppo.zip"
ppo_path2 = "quadrl_m1_ppo.zip"
ppo_path3 = "quadrl_m2_ppo.zip"
ppo_path4 = "quadrl_m3_ppo.zip"
var1_plus = "quadrl_var1_ppo.zip"


#collect_quadruped_morph_trajectories(
#    ppo_path=var1_plus,
#    morph_specs=[morph_specs[0]],
#    episodes_per_morph=50,
#    max_steps_per_ep=1000,
#    out_path="quadruped_var1p_trajectories.npz")

#collect_quadruped_morph_trajectories(
#    ppo_path=ppo_path2,
#    morph_specs=[morph_specs[1]],
#    episodes_per_morph=50,
#    max_steps_per_ep=1000,
#    out_path="quadruped_var2_trajectories.npz")

#collect_quadruped_morph_trajectories(
#    ppo_path=ppo_path3,
#    morph_specs=[morph_specs[2]],
#    episodes_per_morph=50,
#    max_steps_per_ep=1000,
#    out_path="quadruped_var3_trajectories.npz")

#collect_quadruped_morph_trajectories(
#    ppo_path=ppo_path4,
#    morph_specs=[morph_specs[3]],
#    episodes_per_morph=50,
#    max_steps_per_ep=1000,
#    out_path="quadruped_var4_trajectories.npz")


re.merge_traj_files(["quadruped_var1_trajectories.npz", "quadruped_var2_trajectories.npz",
                     "quadruped_var3_trajectories.npz", "quadruped_var4_trajectories.npz"])

traj_file  = "quadruped_morph_trajectories.npz"  # produced by collect_quadruped_morph_trajectories

#standard obs indices for Ant joints
imitation_obs_indices = list(range(5, 13))

# call diffusion training
diff_model, loss_history = train_diffusion(
    traj_file=traj_file,
    past_len=10,
    future_len=200,
    num_epochs=20,
    batch_size=128,
    lr=1e-4,
    imitation_obs_indices=imitation_obs_indices,
    save_path="quadruped_morph_diffusion_weights.pt")
# Out:
# Merged shapes:
#   obs  : (87392, 97)
#   act  : (87392, 8)
#   rew  : (87392,)
#   morph: (87392, 8)
# Saved merged dataset to quadruped_morph_trajectories.npz
# Using device: cuda
# [QuadrupedDataset] obs_dim=97, morph_dim=8
# [QuadrupedDataset] target_dim=8
# [QuadrupedDataset] total samples possible=87182
#
# === Diffusion Model Summary ===
# obs_dim      : 8
# cond_dim     : 88
# future_len   : 200
# n_steps      : 100
# time_dim     : 256
# beta range   : (9.999999747378752e-05, 0.019999999552965164)
# alpha range  : (0.9800000190734863, 0.9998999834060669)
# alpha_bar[0] : 0.9998999834060669
# alpha_bar[-1]: 0.3635632395744324
# Parameters   : total=2,179,336  trainable=2,179,336
#
# --- UNet Channels ---
# down1: Conv1d(352, 256, kernel_size=(3,), stride=(1,), padding=(1,))
# down2: Conv1d(256, 512, kernel_size=(4,), stride=(2,), padding=(1,))
# mid  : Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,))
# up1  : ConvTranspose1d(512, 256, kernel_size=(4,), stride=(2,), padding=(1,))
# up2  : Conv1d(256, 8, kernel_size=(3,), stride=(1,), padding=(1,))
# ==========================
#
# Epoch 1/20 | Loss: 0.343260
#   grad_norm: 1.631137649412267
# Epoch 2/20 | Loss: 0.189232
#   grad_norm: 2.0361750253941864
# Epoch 3/20 | Loss: 0.174398
#   grad_norm: 1.7744001316605136
# Epoch 4/20 | Loss: 0.165160
#   grad_norm: 1.8493203830439597
# Epoch 5/20 | Loss: 0.158854
#   grad_norm: 1.1651172697311267
# Epoch 6/20 | Loss: 0.154901
#   grad_norm: 1.749275966314599
# Epoch 7/20 | Loss: 0.151218
#   grad_norm: 1.3959220156539232
# Epoch 8/20 | Loss: 0.148075
#   grad_norm: 1.6482403443660587
# Epoch 9/20 | Loss: 0.145228
#   grad_norm: 1.1410643031122163
# Epoch 10/20 | Loss: 0.143865
#   grad_norm: 1.2726344793336466
# Epoch 11/20 | Loss: 0.141686
#   grad_norm: 2.0371185594704
# Epoch 12/20 | Loss: 0.140490
#   grad_norm: 1.5219055316993035
# Epoch 13/20 | Loss: 0.138339
#   grad_norm: 1.3612963041523471
# Epoch 14/20 | Loss: 0.137186
#   grad_norm: 1.454689518082887
# Epoch 15/20 | Loss: 0.136592
#   grad_norm: 1.6669860925758258
# Epoch 16/20 | Loss: 0.134198
#   grad_norm: 1.164613681496121
# Epoch 17/20 | Loss: 0.133390
#   grad_norm: 1.5950720442924649
# Epoch 18/20 | Loss: 0.132286
#   grad_norm: 1.2315858519868925
# Epoch 19/20 | Loss: 0.131519
#   grad_norm: 2.326054654433392
# Epoch 20/20 | Loss: 0.131919
#   grad_norm: 1.7221220321953297
# Saved diffusion weights to: quadruped_morph_diffusion_weights.pt
